# %% [markdown]
# # Cursus: Automatic SageMaker (MODS) Pipeline Compiler
#
# The main contribution of this work is **Cursus**, a **compiler** that automatically generate **[MODS (Model Training Workflow Operation and Development System) Pipeline](https://w.amazon.com/bin/view/CMLS/Overview/MODS/)** base on two set of user inputs
# * The **Pipeline DAG (Directed Acylic Graph)**, which describe pipeline as a graph
# * The **Unified Config JSON**, which provides a central hub to extract all user inputs and their associated step information
#     * Run [demo_config](./demo_config.ipynb) first to generate the Unified Config JSON
#     * The config json will be saved in `./pipeling_config/xxx/` folder
#
# ![mods_pipeline_train_eval_calib](./demo/mods_pipeline_train_eval_calib.png)

# %%
#!pip install amzn-secure-ai-sandbox-workflow-python-sdk --ignore-installed

# %%
#!pip install amzn-mods-workflow-helper amzn-mods-python-sdk --upgrade

# %%
#!pip install --upgrade sagemaker

# %%
import os
import json
import pandas as pd
import pickle
import sys
import subprocess
from datetime import datetime

from pathlib import Path

# %%
from pydantic import BaseModel, Field, model_validator, field_validator
from typing import List, Optional, Dict, Any, Type, Union, Tuple

# %%
from collections import defaultdict, deque

# %%
import logging

# %%
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Environment Setup

# %%
from sagemaker import Session
from secure_ai_sandbox_python_lib.session import Session as SaisSession
# Out:
# 2025-11-02 20:21:47,838 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# 2025-11-02 20:21:48,122 - INFO - CA certs are provided via the AmazonCACerts installation at /home/ec2-user/.local/lib/python3.10/site-packages/amazoncerts

# %%
from mods_workflow_helper.utils.secure_session import create_secure_session_config
from mods_workflow_helper.sagemaker_pipeline_helper import SecurityConfig

from sagemaker.workflow.pipeline_context import PipelineSession

# %%
# Initialize session with team bucket
sais_session = SaisSession(".")

security_config = SecurityConfig(
    kms_key=sais_session.get_team_owned_bucket_kms_key(),
    security_group=sais_session.sandbox_vpc_security_group(),
    vpc_subnets=sais_session.sandbox_vpc_subnets(),
)
# Out:
# 2025-11-02 20:21:48,568 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# 2025-11-02 20:21:49,290 - INFO - successfully patched module botocore

# %%
sagemaker_config = create_secure_session_config(
    role_arn=PipelineSession().get_caller_identity_arn(),
    # If you are uploading to andes, use cradle_read_s3_bucket_name() and get_cradle_read_bucket_kms_key() respecitely
    bucket_name=sais_session.team_owned_s3_bucket_name(),
    kms_key=sais_session.get_team_owned_bucket_kms_key(),
    vpc_subnet_ids=sais_session.sandbox_vpc_subnets(),
    vpc_security_groups=[sais_session.sandbox_vpc_security_group()],
)
# Out:
# 2025-11-02 20:21:49,312 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# 2025-11-02 20:21:49,481 - INFO - There is no MODS workflow execution id provided, this is probably because you are running your pipeline outside of MODS.

# %%
pipeline_session = PipelineSession(
    default_bucket=sais_session.team_owned_s3_bucket_name(),
    sagemaker_config=sagemaker_config,
)  # IMPORTANT now the session uses the generated sagemaker_config
# Out:
# 2025-11-02 20:21:49,503 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %%
pipeline_session.config = sagemaker_config

# %%
bucket = sais_session.team_owned_s3_bucket_name()
bucket
# Out:
# 'sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um'

# %%
role = PipelineSession().get_caller_identity_arn()
role
# Out:
# 2025-11-02 20:21:50,031 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# 'arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1'

# %%
from pathlib import Path
import sys

# Get parent directory of current notebook
project_root = str(Path().absolute().parent.parent)
print(f"project root {project_root}")
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"add project root {project_root} into system")
# Out:
# project root /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src
# add project root /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src into system

# %% [markdown]
# ## Basic Information

# %%
region_list = ["NA", "EU", "FE"]

# %%
region_selection = 0

# %%
region = region_list[region_selection]
region
# Out:
# 'NA'

# %%
MODEL_CLASS = "xgboost"

# %%
service_name = "AtoZ"  # "BuyerAbuseCAPPDA" #

# %% [markdown]
# #### Config and Hyperparameter Information

# %%
current_dir = Path.cwd()
# config_dir = Path(current_dir) / 'pipeline_config' / f'config_{region}_{MODEL_CLASS}_v2'
config_dir = Path(current_dir) / "pipeline_config"
print(config_dir)
# Out:
# /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2

# %%
pipeline_config_name = f"config.json"  # f'config_{region}.json'
pipeline_config_name
# Out:
# 'config_NA_xgboost_AtoZ.json'

# %%
config_path = config_dir / pipeline_config_name

# %%
config_path
# Out:
# PosixPath('/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json')

# %% [markdown]
# ## Pipeline Imports

# %%
from enum import Enum
from pydantic import BaseModel

# %% [markdown]
# ## [Optional]: Test Config Load Functionality
#
# Please skip this section if you are not concern about the config information loaded

# %% [markdown]
# ### Hyperparameters

# %%
from cursus.steps.hyperparams.hyperparameters_xgboost import (
    XGBoostModelHyperparameters,
)

# %%
hyparam_path = config_dir / hyparam_filename
with open(hyparam_path, "r") as file:
    hyperparam_dict = json.load(file)

# %%
hyperparams = XGBoostModelHyperparameters(**hyperparam_dict)

# %%
hyperparams.num_classes
# Out:
# 2

# %%
hyperparams.is_binary
# Out:
# True

# %% [markdown]
# ### Import Configs

# %%
from cursus.core.base.config_base import BasePipelineConfig

# %%
from cursus.steps.configs.config_cradle_data_loading_step import (
    CradleDataLoadingConfig,
    MdsDataSourceConfig,
    EdxDataSourceConfig,
    DataSourceConfig,
    DataSourcesSpecificationConfig,
    JobSplitOptionsConfig,
    TransformSpecificationConfig,
    OutputSpecificationConfig,
    CradleJobSpecificationConfig,
)

# %%
from secure_ai_sandbox_workflow_python_sdk.utils.constants import (
    OUTPUT_TYPE_DATA,
    OUTPUT_TYPE_METADATA,
    OUTPUT_TYPE_SIGNATURE,
)

# %%
from cursus.steps.configs.config_processing_step_base import (
    ProcessingStepConfigBase,
)

# %%
from cursus.steps.configs.config_tabular_preprocessing_step import (
    TabularPreprocessingConfig,
)

# %%
from cursus.steps.configs.config_xgboost_training_step import (
    XGBoostTrainingConfig,
)

# %%
from cursus.steps.configs.config_model_calibration_step import (
    ModelCalibrationConfig,
)

# %%
from cursus.steps.configs.config_xgboost_model_eval_step import (
    XGBoostModelEvalConfig,
)

# %%
from cursus.steps.configs.config_package_step import (
    PackageConfig,
)

# %%
from cursus.steps.configs.config_registration_step import (
    RegistrationConfig,
)

# %%
from secure_ai_sandbox_workflow_python_sdk.mims_model_registration.mims_model_registration_processing_step import (
    MimsModelRegistrationProcessingStep,
)

# %%
from secure_ai_sandbox_workflow_python_sdk.mims_model_registration.mims_model_registration_processor import (
    MimsModelRegistrationProcessor,
)

# %%
from cursus.steps.configs.config_payload_step import (
    PayloadConfig,
)

# %% [markdown]
# ### Load Config

# %%
from cursus.steps.configs.utils import (
    serialize_config,
    merge_and_save_configs,
    load_configs,
    verify_configs,
)

# %%
CONFIG_CLASSES = {
    "BasePipelineConfig": BasePipelineConfig,
    "XGBoostTrainingConfig": XGBoostTrainingConfig,
    "ModelCalibrationConfig": ModelCalibrationConfig,
    "ProcessingStepConfigBase": ProcessingStepConfigBase,
    "PackageConfig": PackageConfig,
    "RegistrationConfig": RegistrationConfig,
    "PayloadConfig": PayloadConfig,
    "CradleDataLoadingConfig": CradleDataLoadingConfig,
    "TabularPreprocessingConfig": TabularPreprocessingConfig,
    "XGBoostModelEvalConfig": XGBoostModelEvalConfig,
}

# %%
config_path
# Out:
# PosixPath('/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json')

# %%
# Load configs
loaded_configs = load_configs(config_path, CONFIG_CLASSES)
# Out:
# 2025-11-02 20:21:50,739 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:50,740 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:50,741 - WARNING - Could not find class CradleJobSpecificationConfig
# 2025-11-02 20:21:50,741 - WARNING - Could not find class DataSourcesSpecificationConfig
# 2025-11-02 20:21:50,742 - WARNING - Could not find class DataSourceConfig
# 2025-11-02 20:21:50,742 - WARNING - Could not find class MdsDataSourceConfig
# 2025-11-02 20:21:50,743 - WARNING - Could not find class DataSourceConfig
# 2025-11-02 20:21:50,743 - WARNING - Could not find class EdxDataSourceConfig
# 2025-11-02 20:21:50,743 - WARNING - Could not find class OutputSpecificationConfig
# 2025-11-02 20:21:50,744 - WARNING - Could not find class TransformSpecificationConfig
# 2025-11-02 20:21:50,744 - WARNING - Could not find class JobSplitOptionsConfig
# 2025-11-02 20:21:50,744 - WARNING - Could not find class CradleJobSpecificationConfig
# 2025-11-02 20:21:50,745 - WARNING - Could not find class DataSourcesSpecificationConfig
# 2025-11-02 20:21:50,745 - WARNING - Could not find class DataSourceConfig
# 2025-11-02 20:21:50,745 - WARNING - Could not find class MdsDataSourceConfig
# 2025-11-02 20:21:50,747 - WARNING - Could not find class DataSourceConfig
# 2025-11-02 20:21:50,747 - WARNING - Could not find class EdxDataSourceConfig
# 2025-11-02 20:21:50,747 - WARNING - Could not find class OutputSpecificationConfig
# 2025-11-02 20:21:50,748 - WARNING - Could not find class TransformSpecificationConfig
# 2025-11-02 20:21:50,748 - WARNING - Could not find class JobSplitOptionsConfig
# 2025-11-02 20:21:50,749 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:50,749 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json with 10 specific configs
# 2025-11-02 20:21:50,751 - INFO - Creating additional config instance for CradleDataLoading_calibration (CradleDataLoadingConfig)
# 2025-11-02 20:21:50,751 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:21:50,751 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:21:50,752 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:21:50,752 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:21:50,753 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-02 20:21:50,806 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:50,816 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:50,841 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:50,842 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:50,842 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:50,891 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:50,895 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:50,920 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:50,921 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:50,921 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:50,923 - INFO - Creating additional config instance for CradleDataLoading_training (CradleDataLoadingConfig)
# 2025-11-02 20:21:50,972 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:50,977 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,001 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,002 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,002 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,051 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,056 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,081 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,081 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,082 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,083 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-11-02 20:21:51,132 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,136 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,161 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,162 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,162 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,211 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,216 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,241 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,241 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,241 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,242 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-11-02 20:21:51,291 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,296 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,321 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,321 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,321 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,370 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,375 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,400 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,401 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,401 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,401 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-11-02 20:21:51,450 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,455 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,480 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,480 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,481 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,530 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,535 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,559 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,560 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,560 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,561 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-11-02 20:21:51,610 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,615 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,640 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,640 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,640 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,689 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,694 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,719 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,719 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,720 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,721 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-11-02 20:21:51,770 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,775 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,800 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,800 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,800 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,849 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,854 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,879 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,879 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,880 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:51,880 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-11-02 20:21:51,929 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:51,934 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:51,959 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:51,959 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:51,960 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:52,009 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,014 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,038 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,039 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,039 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:52,040 - INFO - Creating additional config instance for XGBoostModelEval_calibration (XGBoostModelEvalConfig)
# 2025-11-02 20:21:52,089 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,094 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,119 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,119 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,119 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:52,168 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,173 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,198 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,198 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,199 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:52,199 - INFO - Creating additional config instance for XGBoostTraining (XGBoostTrainingConfig)
# 2025-11-02 20:21:52,248 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,253 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,278 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,278 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,279 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:52,328 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,333 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,357 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,358 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,358 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:52,359 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json

# %%
first_config = next(iter(loaded_configs.values()))

# %%
PIPELINE_VERSION = first_config.pipeline_version

# %%
PIPELINE_VERSION = first_config.pipeline_version

# %%
loaded_configs
# Out:
# {'CradleDataLoading_calibration': CradleDataLoadingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', job_type='calibration', data_sources_spec=DataSourcesSpecificationConfig(start_date='2025-04-17T00:00:00', end_date='2025-04-28T00:00:00', data_sources=[DataSourceConfig(data_source_name='RAW_MDS_NA', data_source_type='MDS', mds_data_source_properties=MdsDataSourceConfig(service_name='AtoZ', region='NA', output_schema=[{'field_name': 'objectId', 'field_type': 'STRING'}, {'field_name': 'transactionDate', 'field_type': 'STRING'}, {'field_name': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.comple ...
#  'CradleDataLoading_training': CradleDataLoadingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', job_type='training', data_sources_spec=DataSourcesSpecificationConfig(start_date='2025-01-01T00:00:00', end_date='2025-04-17T00:00:00', data_sources=[DataSourceConfig(data_source_name='RAW_MDS_NA', data_source_type='MDS', mds_data_source_properties=MdsDataSourceConfig(service_name='AtoZ', region='NA', output_schema=[{'field_name': 'objectId', 'field_type': 'STRING'}, {'field_name': 'transactionDate', 'field_type': 'STRING'}, {'field_name': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count', 'field_type': 'STRING'}, {'field_name': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days', 'field_type': 'STRING'}, {'field_name': 'Abuse.completed_mf ...
#  'ModelCalibration_calibration': ModelCalibrationConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='dockers/xgboost_atoz/scripts', processing_entry_point='model_calibration.py', processing_script_arguments=None, processing_framework_version='1.2-1', label_field='is_abuse', calibration_method='gam', monotonic_constraint=True, gam_splines=10, error_threshold=0.05, is_binary=True, num_classes=2, score_field='prob_class_1', score_field_prefix='prob_class_', multiclass_categories=[0, 1], job_type='calibration'),
#  'Package': PackageConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='dockers/xgboost_atoz/scripts', processing_entry_point='package.py', processing_script_arguments=None, processing_framework_version='1.2-1'),
#  'Payload': PayloadConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='dockers/xgboost_atoz/scripts', processing_entry_point='payload.py', processing_script_arguments=None, processing_framework_version='1.2-1', expected_tps=10, max_latency_in_millisecond=800, source_model_inference_content_types=['text/csv'], source_model_inference_response_types=['application/json'], default_numeric_value=0.0, default_text_value='DEFAULT_TEXT', special_field_values=None, max_acceptable_error_rate=0.2),
#  'Registration': RegistrationConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', model_owner='amzn1.abacus.team.djmdvixm5abr3p75c5ca', model_domain='AtoZ', model_objective='AtoZ_Claims_SM_Model_NA', framework='xgboost', inference_entry_point='xgboost_inference.py', source_model_inference_input_variable_list=[['Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days', 'NUMERIC'], ['Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days', 'NUMERIC'], ['Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days', 'NUMERIC'], ['Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count', 'NUMERIC'], ['Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days', 'NUMERIC'], ['Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days', 'NUMERIC'], ['Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days', 'NUMERIC'], ['Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_order_count_last_365_days', 'NUMERIC'], ['Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_amount_last_365_days', 'NUMERIC'], ['Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_count_last_365_days', 'NUMERIC'], ['Abuse.dnr_by_customer_marketplace.n_dnr_amount_si_last_365_days', 'NUMERIC'], ['Abuse.dnr_by_customer_marketplace.n_dnr_order_count_last_365_days', 'NUMERIC'], ['Abuse.dnr_by_customer_marketplace.n_dnr_unit_amount_last_365_days', 'NUMERIC'], ['Abuse.dnr_by_customer_marketplace.n_dnr_unit_count_last_365_days', 'NUMERIC'], ['Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_amount_last_365_days', 'NUMERIC'], ['Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_count_last_365_days', 'NUMERIC'], ['Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_amount_last_365_days', 'NU ...
#  'TabularPreprocessing_calibration': TabularPreprocessingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='dockers/xgboost_atoz/scripts', processing_entry_point='tabular_preprocessing.py', processing_script_arguments=None, processing_framework_version='1.2-1', job_type='calibration', label_name='is_abuse', train_ratio=0.7, test_val_ratio=0.5),
#  'TabularPreprocessing_training': TabularPreprocessingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='dockers/xgboost_atoz/scripts', processing_entry_point='tabular_preprocessing.py', processing_script_arguments=None, processing_framework_version='1.2-1', job_type='training', label_name='is_abuse', train_ratio=0.7, test_val_ratio=0.5),
#  'XGBoostModelEval_calibration': XGBoostModelEvalConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='dockers/xgboost_atoz/scripts', processing_entry_point='xgboost_model_eval.py', processing_script_arguments=None, processing_framework_version='1.2-1', id_name='order_id', label_name='is_abuse', job_type='calibration', eval_metric_choices=['auc', 'average_precision', 'f1_score'], xgboost_framework_version='1.5-1', comparison_mode=False, previous_score_field='', comparison_metrics='all', statistical_tests=True, comparison_plots=True),
#  'XGBoostTraining': XGBoostTrainingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='AtoZ', pipeline_version='1.3.1', model_class='xgboost', current_date='2025-11-02', framework_version='1.7-1', py_version='py3', source_dir='dockers/xgboost_atoz', enable_caching=False, project_root_folder='mods_pipeline_adapter', training_entry_point='xgboost_training.py', training_instance_type='ml.m5.12xlarge', training_instance_count=1, training_volume_size=800, skip_hyperparameters_s3_uri=True)}

# %%
len(loaded_configs)
# Out:
# 10

# %%
[str(k) for k in loaded_configs.keys()]
# Out:
# ['CradleDataLoading_calibration',
#  'CradleDataLoading_training',
#  'ModelCalibration_calibration',
#  'Package',
#  'Payload',
#  'Registration',
#  'TabularPreprocessing_calibration',
#  'TabularPreprocessing_training',
#  'XGBoostModelEval_calibration',
#  'XGBoostTraining']

# %%
print(str(loaded_configs["TabularPreprocessing_training"]))
# Out:
# 2025-11-02 20:21:52,399 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/dockers/xgboost_atoz/scripts
# 2025-11-02 20:21:52,400 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/dockers/xgboost_atoz/scripts
# 2025-11-02 20:21:52,400 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/dockers/xgboost_atoz
# 2025-11-02 20:21:52,401 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/dockers/xgboost_atoz
# 2025-11-02 20:21:52,402 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:21:52,402 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:21:52,403 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:21:52,403 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:21:52,403 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# === TabularPreprocessingConfig ===
#
# - Essential User Inputs -
# author: lukexie
# bucket: sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um
# job_type: training
# pipeline_version: 1.3.1
# project_root_folder: mods_pipeline_adapter
# region: NA
# role: arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1
# service_name: AtoZ
#
# - System Inputs -
# current_date: 2025-11-02
# enable_caching: False
# framework_version: 1.7-1
# label_name: is_abuse
# model_class: xgboost
# processing_entry_point: tabular_preprocessing.py
# processing_framework_version: 1.2-1
# processing_instance_count: 1
# processing_instance_type_large: ml.m5.12xlarge
# processing_instance_type_small: ml.m5.4xlarge
# processing_source_dir: dockers/xgboost_atoz/scripts
# processing_volume_size: 500
# py_version: py3
# source_dir: dockers/xgboost_atoz
# test_val_ratio: 0.5
# train_ratio: 0.7
# use_large_processing_instance: True
#
# - Derived Fields -
# aws_region: us-east-1
# effective_instance_type: ml.m5.12xlarge
# effective_source_dir: dockers/xgboost_atoz/scripts
# full_script_path: dockers/xgboost_atoz/scripts/tabular_preprocessing.py
# model_extra: {}
# model_fields_set: {'model_class', 'project_root_folder', 'processing_framework_version', 'processing_instance_type_small', 'processing_source_dir', 'framework_version', 'enable_caching', 'processing_instance_count', 'train_ratio', 'job_type', 'py_version', 'service_name', 'processing_entry_point', 'pipeline_version', 'region', 'label_name', 'test_val_ratio', 'bucket', 'use_large_processing_instance', 'processing_volume_size', 'processing_instance_type_large', 'author', 'current_date', 'role', 'source_dir'}
# pipeline_description: AtoZ xgboost Model NA
# pipeline_name: lukexie-AtoZ-xgboost-NA
# pipeline_s3_loc: s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/MODS/lukexie-AtoZ-xgboost-NA_1.3.1
# resolved_processing_source_dir: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/dockers/xgboost_atoz/scripts
# resolved_source_dir: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/dockers/xgboost_atoz
# script_contract: entry_point='tabular_preprocessing.py' expected_input_paths={'DATA': '/opt/ml/processing/input/data', 'SIGNATURE': '/opt/ml/processing/input/signature'} expected_output_paths={'processed_data': '/opt/ml/processing/output'} required_env_vars=['TRAIN_RATIO', 'TEST_VAL_RATIO'] optional_env_vars={'LABEL_FIELD': '', 'CATEGORICAL_COLUMNS': '', 'NUMERICAL_COLUMNS': '', 'TEXT_COLUMNS': '', 'DATE_COLUMNS': ''} expected_arguments={} framework_requirements={'pandas': '>=1.3.0', 'numpy': '>=1.21.0', 'scikit-learn': '>=1.0.0'} description='\n    Tabular preprocessing script that:\n    1. Combines data shards from input directory\n    2. Loads column signature for CSV/TSV files if provided\n    3. Cleans and processes label field\n    4. Splits data into train/test/val for training jobs\n    5. Outputs processed CSV files by split\n    \n    Contract aligned with actual script implementation:\n    - Inputs: \n      * DATA (required) - reads from /opt/ml/processing/input/data\n      * SIGNATURE (optional) - reads from /opt/ml/processing/input/signature\n    - Outputs: processed_data (primary) - writes to /opt/ml/processing/output\n    - Arguments: job_type (required) - defines processing mode (training/validation/testing)\n    \n    Script Implementation Details:\n    - Reads data shards (CSV, JSON, Parquet) from input/data directory\n    - Loads signature file containing column names for CSV/TSV files\n    - Supports gzipped files and various formats\n    - Uses signature column names for CSV/TSV files when available\n    - Processes labels (converts categorical to numeric if needed)\n    - Splits data based on job_type (training creates train/test/val splits)\n    - Outputs processed files to split subdirectories under /opt/ml/processing/output\n    \n    Signature File Format:\n    - CSV format with comma-separated column names\n    - Applied only to CSV/TSV files, ignored for JSON/Parquet formats\n    - Backward compatible - works without signature file\n    '
# script_path: dockers/xgboost_atoz/scripts/tabular_preprocessing.py
# step_catalog: <buyer_abuse_mods_template.cursus.step_catalog.step_catalog.StepCatalog object at 0x7fc2189022c0>

# %% [markdown]
# ## Import Packages

# %%
from abc import ABC, abstractmethod
from typing import Dict, List, Any, Optional, Type
from pathlib import Path
import logging
import os
import importlib

# %%
import sagemaker
from sagemaker import Session, TrainingInput
from sagemaker import image_uris, model_uris, script_uris
from sagemaker.processing import ProcessingOutput, ProcessingInput, FrameworkProcessor
from sagemaker.sklearn import SKLearnProcessor, SKLearn
from sagemaker.workflow.pipeline import Pipeline
from sagemaker.workflow.parameters import ParameterString
from sagemaker.image_uris import retrieve
from sagemaker.sklearn import SKLearnProcessor
from sagemaker.workflow.steps import CacheConfig  # Add this import
from sagemaker.workflow.model_step import ModelStep
from sagemaker.workflow.steps import (
    ProcessingStep,
    TrainingStep,
    TuningStep,
    TransformStep,
    Step,
)
from sagemaker.workflow.parameters import Parameter
from sagemaker.workflow.properties import Properties
from sagemaker.workflow.pipeline_context import PipelineSession  # Crucial import

# %% [markdown]
# ### MODS and SAIS Python SDK

# %%
from mods_workflow_core.utils.constants import (
    PIPELINE_EXECUTION_TEMP_DIR,
    KMS_ENCRYPTION_KEY_PARAM,
    PROCESSING_JOB_SHARED_NETWORK_CONFIG,
    SECURITY_GROUP_ID,
    VPC_SUBNET,
)

# %% [markdown]
# ### Pipeline DAG

# %%
from cursus.api.dag.base_dag import PipelineDAG

# %% [markdown]
# ### Pipeline Template Builder and AbstractPipelineTemplate

# %%
from cursus.core.assembler import PipelineAssembler
from cursus.core.assembler import PipelineTemplateBase

# %% [markdown]
# ## Demo: An End-to-End Pipeline based on PipelineDAG Compiler
# Let us use the following simpler DAG (without registration as example)
#
# ![mods_pipeline_train_eval_calib](./demo/mods_pipeline_train_eval_calib.png)
#
# In this demo there are several user input
# * the **Unified JSON file** in `config_path`
# * the **Registry Manager**: an object that handles the map between step logical name to `step.properties`
# * the **Dependency Resolver**: an object than handles the *automatic dependency resolution* between steps
# * the other fields
#     * `sagemaker_session`: pipelne session
#     * `role`: IAM Role
#     * `notebook_root`: track the root path
#
#
# In this pipeline template, we inherit from base class `PipelineTemplateBase`.
#
# The **major tasks** are
# * *`Config` Classes Import*
# * *Configuration Validation*
# * *Step Builder Retrieval and Step Builder Map Creation*
# * *Configuration Map Creation*
# * **Pipeline DAG Generation**: ideally, user should create this DAG and use it as input
# * **Automatic Pipeline Assemble**: Call `pipeline_assembler`

# %%
current_dir = Path.cwd()

# %%
# config_path = Path(current_dir) / 'pipeline_config' / f'config_{region}.json'
config_path
# Out:
# PosixPath('/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json')

# %% [markdown]
# ### DAG to Template Compiler

# %%
from cursus.api.dag.base_dag import PipelineDAG
from cursus.core.compiler.dag_compiler import (
    compile_dag_to_pipeline,
    PipelineDAGCompiler,
)
from cursus.core.compiler.validation import ConversionReport
from cursus.steps.configs.utils import load_configs

# %%
def create_xgboost_complete_e2e_dag() -> PipelineDAG:
    """
    Create a DAG matching the exact structure from demo/demo_pipeline.ipynb.

    This DAG represents a complete end-to-end workflow including training,
    calibration, packaging, registration, and evaluation of an XGBoost model.

    Returns:
        PipelineDAG: The directed acyclic graph for the pipeline
    """
    dag = PipelineDAG()

    # Add all nodes - exactly as in the demo notebook
    dag.add_node("CradleDataLoading_training")  # Data load for training
    dag.add_node("TabularPreprocessing_training")  # Tabular preprocessing for training
    dag.add_node("XGBoostTraining")  # XGBoost training step
    dag.add_node(
        "ModelCalibration_calibration"
    )  # Model calibration step with calibration variant
    dag.add_node("Package")  # Package step
    dag.add_node("Registration")  # MIMS registration step
    dag.add_node("Payload")  # Payload step
    dag.add_node("CradleDataLoading_calibration")  # Data load for calibration
    dag.add_node(
        "TabularPreprocessing_calibration"
    )  # Tabular preprocessing for calibration
    dag.add_node("XGBoostModelEval_calibration")  # Model evaluation step

    # Training flow
    dag.add_edge("CradleDataLoading_training", "TabularPreprocessing_training")
    dag.add_edge("TabularPreprocessing_training", "XGBoostTraining")

    # Calibration flow
    dag.add_edge("CradleDataLoading_calibration", "TabularPreprocessing_calibration")

    # Evaluation flow
    dag.add_edge("XGBoostTraining", "XGBoostModelEval_calibration")
    dag.add_edge("TabularPreprocessing_calibration", "XGBoostModelEval_calibration")

    # Model calibration flow - depends on model evaluation
    dag.add_edge("XGBoostModelEval_calibration", "ModelCalibration_calibration")

    # Output flow
    dag.add_edge("ModelCalibration_calibration", "Package")
    dag.add_edge("XGBoostTraining", "Package")  # Raw model is also input to packaging
    dag.add_edge("XGBoostTraining", "Payload")  # Payload test uses the raw model
    dag.add_edge("Package", "Registration")
    dag.add_edge("Payload", "Registration")

    logger.info(
        f"Created XGBoost complete E2E DAG with {len(dag.nodes)} nodes and {len(dag.edges)} edges"
    )
    return dag

# %%
dag = create_xgboost_complete_e2e_dag()
# Out:
# 2025-11-02 20:21:52,477 - INFO - Added node: CradleDataLoading_training
# 2025-11-02 20:21:52,478 - INFO - Added node: TabularPreprocessing_training
# 2025-11-02 20:21:52,478 - INFO - Added node: XGBoostTraining
# 2025-11-02 20:21:52,478 - INFO - Added node: ModelCalibration_calibration
# 2025-11-02 20:21:52,479 - INFO - Added node: Package
# 2025-11-02 20:21:52,479 - INFO - Added node: Registration
# 2025-11-02 20:21:52,479 - INFO - Added node: Payload
# 2025-11-02 20:21:52,480 - INFO - Added node: CradleDataLoading_calibration
# 2025-11-02 20:21:52,480 - INFO - Added node: TabularPreprocessing_calibration
# 2025-11-02 20:21:52,481 - INFO - Added node: XGBoostModelEval_calibration
# 2025-11-02 20:21:52,481 - INFO - Added edge: CradleDataLoading_training -> TabularPreprocessing_training
# 2025-11-02 20:21:52,482 - INFO - Added edge: TabularPreprocessing_training -> XGBoostTraining
# 2025-11-02 20:21:52,482 - INFO - Added edge: CradleDataLoading_calibration -> TabularPreprocessing_calibration
# 2025-11-02 20:21:52,482 - INFO - Added edge: XGBoostTraining -> XGBoostModelEval_calibration
# 2025-11-02 20:21:52,482 - INFO - Added edge: TabularPreprocessing_calibration -> XGBoostModelEval_calibration
# 2025-11-02 20:21:52,483 - INFO - Added edge: XGBoostModelEval_calibration -> ModelCalibration_calibration
# 2025-11-02 20:21:52,483 - INFO - Added edge: ModelCalibration_calibration -> Package
# 2025-11-02 20:21:52,483 - INFO - Added edge: XGBoostTraining -> Package
# 2025-11-02 20:21:52,484 - INFO - Added edge: XGBoostTraining -> Payload
# 2025-11-02 20:21:52,484 - INFO - Added edge: Package -> Registration
# 2025-11-02 20:21:52,484 - INFO - Added edge: Payload -> Registration
# 2025-11-02 20:21:52,485 - INFO - Created XGBoost complete E2E DAG with 10 nodes and 11 edges

# %%
pipeline_parameters = [
    PIPELINE_EXECUTION_TEMP_DIR,
    KMS_ENCRYPTION_KEY_PARAM,
    SECURITY_GROUP_ID,
    VPC_SUBNET,
]

# %%
dag_compiler = PipelineDAGCompiler(
    config_path=config_path,
    sagemaker_session=pipeline_session,
    role=role,
    pipeline_parameters=pipeline_parameters,
)
# Out:
# 2025-11-02 20:21:52,495 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:21:52,495 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:21:52,496 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:21:52,496 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:21:52,497 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-02 20:21:52,497 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:21:52,497 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:21:52,498 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:21:52,499 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:21:52,499 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully

# %% [markdown]
# ### Create a Pipeline

# %% [markdown]
# #### DAG Validation and Preview of Config Resolution

# %%
preview_only = True

# %%
if preview_only:
    preview = dag_compiler.preview_resolution(dag)
    logger.info("DAG node resolution preview:")
    for node, config_type in preview.node_config_map.items():
        confidence = preview.resolution_confidence.get(node, 0.0)
        logger.info(f"  {node} → {config_type} (confidence: {confidence:.2f})")

    if preview.recommendations:
        logger.info("Recommendations:")
        for recommendation in preview.recommendations:
            logger.info(f"  - {recommendation}")

    validation = dag_compiler.validate_dag_compatibility(dag)
    logger.info(f"DAG validation: {'VALID' if validation.is_valid else 'INVALID'}")
    if not validation.is_valid:
        if validation.missing_configs:
            logger.warning(f"Missing configs: {validation.missing_configs}")
        if validation.unresolvable_builders:
            logger.warning(f"Unresolvable builders: {validation.unresolvable_builders}")
        if validation.config_errors:
            logger.warning(f"Config errors: {validation.config_errors}")
# Out:
# 2025-11-02 20:21:52,508 - INFO - Previewing resolution for 10 DAG nodes
# 2025-11-02 20:21:52,508 - INFO - Creating template for DAG with 10 nodes
# 2025-11-02 20:21:52,509 - WARNING - Could not import config_class_detector, using fallback implementation
# 2025-11-02 20:21:52,509 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:21:52,510 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:21:52,510 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:21:52,511 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:21:52,511 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-02 20:21:52,560 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,565 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,590 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,591 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,591 - INFO - Successfully discovered 46 config classes using step catalog
# 2025-11-02 20:21:52,591 - INFO - Loading configs from: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:52,592 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:21:52,592 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:21:52,593 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:21:52,593 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:21:52,594 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-02 20:21:52,643 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,648 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,673 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,673 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,673 - INFO - Successfully discovered 46 config classes using step catalog
# 2025-11-02 20:21:52,674 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:52,675 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:52,677 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:52,677 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json with 10 specific configs
# 2025-11-02 20:21:52,678 - INFO - Creating additional config instance for CradleDataLoading_calibration (CradleDataLoadingConfig)
# 2025-11-02 20:21:52,728 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,732 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,757 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,758 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,758 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:52,808 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,812 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,837 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,838 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,838 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:52,839 - INFO - Creating additional config instance for CradleDataLoading_training (CradleDataLoadingConfig)
# 2025-11-02 20:21:52,888 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,893 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,918 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,919 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,919 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:52,968 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:52,973 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:52,998 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:52,998 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:52,999 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,000 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-11-02 20:21:53,049 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,054 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,079 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,079 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,080 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,129 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,133 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,158 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,159 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,159 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,160 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-11-02 20:21:53,209 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,214 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,239 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,239 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,239 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,289 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,294 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,319 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,319 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,320 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,320 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-11-02 20:21:53,370 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,374 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,399 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,400 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,400 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,449 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,454 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,479 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,479 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,480 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,480 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-11-02 20:21:53,530 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,534 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,559 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,560 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,560 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,609 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,614 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,639 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,639 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,640 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,640 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-11-02 20:21:53,690 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,695 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,720 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,720 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,720 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,770 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,774 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,799 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,800 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,800 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,800 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-11-02 20:21:53,850 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,855 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,880 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,880 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,880 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,930 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:53,934 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:53,959 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:53,960 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:53,960 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:53,961 - INFO - Creating additional config instance for XGBoostModelEval_calibration (XGBoostModelEvalConfig)
# 2025-11-02 20:21:54,010 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:54,015 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:54,040 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:54,040 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:54,040 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:54,090 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:54,094 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:54,119 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:54,120 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:54,120 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:54,121 - INFO - Creating additional config instance for XGBoostTraining (XGBoostTrainingConfig)
# 2025-11-02 20:21:54,170 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:54,175 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:54,200 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:54,200 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:54,200 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:54,250 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:54,254 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:54,279 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:54,280 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:54,280 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:54,280 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:54,282 - INFO - Loaded raw configuration data from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:54,282 - INFO - Initialized registry manager with workspace context: None
# 2025-11-02 20:21:54,283 - INFO - Created specification registry for context 'lukexie-AtoZ-xgboost-NA'
# 2025-11-02 20:21:54,283 - INFO - Created new workspace-aware registry for context 'lukexie-AtoZ-xgboost-NA'
# 2025-11-02 20:21:54,284 - INFO - Created registry manager for context: lukexie-AtoZ-xgboost-NA
# 2025-11-02 20:21:54,284 - INFO - Created dependency resolver for context: lukexie-AtoZ-xgboost-NA
# 2025-11-02 20:21:54,284 - INFO - Validating dynamic pipeline configuration
# 2025-11-02 20:21:54,285 - INFO - Resolving 10 DAG nodes to configurations
# 2025-11-02 20:21:54,285 - INFO - Using metadata from loaded configuration
# 2025-11-02 20:21:54,285 - INFO - Found exact key match for node 'CradleDataLoading_training'
# 2025-11-02 20:21:54,286 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-02 20:21:54,286 - INFO - Found exact key match for node 'XGBoostTraining'
# 2025-11-02 20:21:54,286 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-02 20:21:54,287 - INFO - Found exact key match for node 'Package'
# 2025-11-02 20:21:54,287 - INFO - Found exact key match for node 'Registration'
# 2025-11-02 20:21:54,288 - INFO - Found exact key match for node 'Payload'
# 2025-11-02 20:21:54,288 - INFO - Found exact key match for node 'CradleDataLoading_calibration'
# 2025-11-02 20:21:54,289 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-02 20:21:54,289 - INFO - Found exact key match for node 'XGBoostModelEval_calibration'
# 2025-11-02 20:21:54,289 - INFO - Successfully resolved all 10 nodes
# 2025-11-02 20:21:54,294 - INFO - Index built successfully in 0.004s with 84 steps
# 2025-11-02 20:21:54,323 - WARNING - Error loading class PercentileModelCalibrationStepBuilder from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/steps/builders/builder_percentile_model_calibration_step.py (relative module: ..steps.builders.builder_percentile_model_calibration_step): 1 validation error for ScriptContract
# expected_input_paths
#   Value error, Input path for calibration_config must start with /opt/ml/processing/input, got: /opt/ml/code/calibration [type=value_error, input_value={'evaluation_data': '/opt...pt/ml/code/calibration'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/value_error
# 2025-11-02 20:21:54,335 - INFO - Builder discovery complete: 24 builders found
# 2025-11-02 20:21:54,335 - WARNING - No builder class found for step: Base
# 2025-11-02 20:21:54,335 - WARNING - No builder class found for step: Base
# 2025-11-02 20:21:54,336 - WARNING - No builder class found for step: HyperparameterPrep
# 2025-11-02 20:21:54,336 - WARNING - No builder class found for step: HyperparameterPrep
# 2025-11-02 20:21:54,336 - WARNING - No builder class found for step: PercentileModelCalibration
# 2025-11-02 20:21:54,337 - WARNING - No builder class found for step: PercentileModelCalibration
# 2025-11-02 20:21:54,337 - WARNING - No builder class found for step: Processing
# 2025-11-02 20:21:54,337 - WARNING - No builder class found for step: Processing
# 2025-11-02 20:21:54,338 - WARNING - No builder class found for step: batch_transform_calibration
# 2025-11-02 20:21:54,338 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,339 - WARNING - No builder class found for step: batch_transform_calibration
# 2025-11-02 20:21:54,339 - INFO - Trying base step type 'batch_transform' for compound 'batch_transform_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,339 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,340 - WARNING - No builder class found for step: batch
# 2025-11-02 20:21:54,340 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,340 - WARNING - No builder class found for step: batch_transform_testing
# 2025-11-02 20:21:54,340 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,341 - WARNING - No builder class found for step: batch_transform_testing
# 2025-11-02 20:21:54,341 - INFO - Trying base step type 'batch_transform' for compound 'batch_transform_testing' (job_type: testing)
# 2025-11-02 20:21:54,341 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,342 - WARNING - No builder class found for step: batch
# 2025-11-02 20:21:54,342 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,342 - WARNING - No builder class found for step: batch_transform_training
# 2025-11-02 20:21:54,343 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,343 - WARNING - No builder class found for step: batch_transform_training
# 2025-11-02 20:21:54,343 - INFO - Trying base step type 'batch_transform' for compound 'batch_transform_training' (job_type: training)
# 2025-11-02 20:21:54,344 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,344 - WARNING - No builder class found for step: batch
# 2025-11-02 20:21:54,344 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,345 - WARNING - No builder class found for step: batch_transform_validation
# 2025-11-02 20:21:54,345 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,345 - WARNING - No builder class found for step: batch_transform_validation
# 2025-11-02 20:21:54,346 - INFO - Trying base step type 'batch_transform' for compound 'batch_transform_validation' (job_type: validation)
# 2025-11-02 20:21:54,346 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,346 - WARNING - No builder class found for step: batch
# 2025-11-02 20:21:54,347 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:54,347 - WARNING - No builder class found for step: cradle_data_loading_calibration
# 2025-11-02 20:21:54,347 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,347 - WARNING - No builder class found for step: cradle_data_loading_calibration
# 2025-11-02 20:21:54,348 - INFO - Trying base step type 'cradle_data_loading' for compound 'cradle_data_loading_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,348 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,348 - WARNING - No builder class found for step: cradle_data
# 2025-11-02 20:21:54,349 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,349 - WARNING - No builder class found for step: cradle_data_loading_testing
# 2025-11-02 20:21:54,349 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,350 - WARNING - No builder class found for step: cradle_data_loading_testing
# 2025-11-02 20:21:54,350 - INFO - Trying base step type 'cradle_data_loading' for compound 'cradle_data_loading_testing' (job_type: testing)
# 2025-11-02 20:21:54,350 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,351 - WARNING - No builder class found for step: cradle_data
# 2025-11-02 20:21:54,351 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,351 - WARNING - No builder class found for step: cradle_data_loading_training
# 2025-11-02 20:21:54,352 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,352 - WARNING - No builder class found for step: cradle_data_loading_training
# 2025-11-02 20:21:54,352 - INFO - Trying base step type 'cradle_data_loading' for compound 'cradle_data_loading_training' (job_type: training)
# 2025-11-02 20:21:54,353 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,353 - WARNING - No builder class found for step: cradle_data
# 2025-11-02 20:21:54,353 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,353 - WARNING - No builder class found for step: cradle_data_loading_validation
# 2025-11-02 20:21:54,354 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,354 - WARNING - No builder class found for step: cradle_data_loading_validation
# 2025-11-02 20:21:54,354 - INFO - Trying base step type 'cradle_data_loading' for compound 'cradle_data_loading_validation' (job_type: validation)
# 2025-11-02 20:21:54,355 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,355 - WARNING - No builder class found for step: cradle_data
# 2025-11-02 20:21:54,355 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:54,356 - WARNING - No builder class found for step: currency_conversion_calibration
# 2025-11-02 20:21:54,356 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,356 - WARNING - No builder class found for step: currency_conversion_calibration
# 2025-11-02 20:21:54,357 - INFO - Trying base step type 'currency_conversion' for compound 'currency_conversion_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,357 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,357 - WARNING - No builder class found for step: currency
# 2025-11-02 20:21:54,358 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,358 - WARNING - No builder class found for step: currency_conversion_testing
# 2025-11-02 20:21:54,358 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,358 - WARNING - No builder class found for step: currency_conversion_testing
# 2025-11-02 20:21:54,359 - INFO - Trying base step type 'currency_conversion' for compound 'currency_conversion_testing' (job_type: testing)
# 2025-11-02 20:21:54,359 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,359 - WARNING - No builder class found for step: currency
# 2025-11-02 20:21:54,360 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,360 - WARNING - No builder class found for step: currency_conversion_training
# 2025-11-02 20:21:54,366 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,366 - WARNING - No builder class found for step: currency_conversion_training
# 2025-11-02 20:21:54,367 - INFO - Trying base step type 'currency_conversion' for compound 'currency_conversion_training' (job_type: training)
# 2025-11-02 20:21:54,367 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,367 - WARNING - No builder class found for step: currency
# 2025-11-02 20:21:54,368 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,368 - WARNING - No builder class found for step: currency_conversion_validation
# 2025-11-02 20:21:54,368 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,369 - WARNING - No builder class found for step: currency_conversion_validation
# 2025-11-02 20:21:54,369 - INFO - Trying base step type 'currency_conversion' for compound 'currency_conversion_validation' (job_type: validation)
# 2025-11-02 20:21:54,369 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,370 - WARNING - No builder class found for step: currency
# 2025-11-02 20:21:54,370 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:54,370 - WARNING - No builder class found for step: dummy_data_loading_calibration
# 2025-11-02 20:21:54,371 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,372 - WARNING - No builder class found for step: dummy_data_loading_calibration
# 2025-11-02 20:21:54,372 - INFO - Trying base step type 'dummy_data_loading' for compound 'dummy_data_loading_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,372 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,373 - WARNING - No builder class found for step: dummy_data
# 2025-11-02 20:21:54,373 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,373 - WARNING - No builder class found for step: dummy_data_loading_testing
# 2025-11-02 20:21:54,374 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,374 - WARNING - No builder class found for step: dummy_data_loading_testing
# 2025-11-02 20:21:54,374 - INFO - Trying base step type 'dummy_data_loading' for compound 'dummy_data_loading_testing' (job_type: testing)
# 2025-11-02 20:21:54,375 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,376 - WARNING - No builder class found for step: dummy_data
# 2025-11-02 20:21:54,376 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,376 - WARNING - No builder class found for step: dummy_data_loading_training
# 2025-11-02 20:21:54,377 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,377 - WARNING - No builder class found for step: dummy_data_loading_training
# 2025-11-02 20:21:54,377 - INFO - Trying base step type 'dummy_data_loading' for compound 'dummy_data_loading_training' (job_type: training)
# 2025-11-02 20:21:54,378 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,378 - WARNING - No builder class found for step: dummy_data
# 2025-11-02 20:21:54,378 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,379 - WARNING - No builder class found for step: dummy_data_loading_validation
# 2025-11-02 20:21:54,379 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,379 - WARNING - No builder class found for step: dummy_data_loading_validation
# 2025-11-02 20:21:54,380 - INFO - Trying base step type 'dummy_data_loading' for compound 'dummy_data_loading_validation' (job_type: validation)
# 2025-11-02 20:21:54,380 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,380 - WARNING - No builder class found for step: dummy_data
# 2025-11-02 20:21:54,381 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:54,381 - WARNING - No builder class found for step: lightgbm_training
# 2025-11-02 20:21:54,381 - WARNING - No builder class found for step: lightgbm
# 2025-11-02 20:21:54,382 - WARNING - No builder class found for step: lightgbm_training
# 2025-11-02 20:21:54,382 - INFO - Trying base step type 'lightgbm' for compound 'lightgbm_training' (job_type: training)
# 2025-11-02 20:21:54,382 - WARNING - No builder class found for step: lightgbm
# 2025-11-02 20:21:54,382 - WARNING - No builder class found for step: lightgbm
# 2025-11-02 20:21:54,383 - WARNING - No builder class found for step: mims_registration
# 2025-11-02 20:21:54,383 - WARNING - No builder class found for step: mims
# 2025-11-02 20:21:54,383 - WARNING - No builder class found for step: mims_registration
# 2025-11-02 20:21:54,384 - INFO - Trying base step type 'mims' for compound 'mims_registration' (job_type: registration)
# 2025-11-02 20:21:54,384 - WARNING - No builder class found for step: mims
# 2025-11-02 20:21:54,384 - WARNING - No builder class found for step: mims
# 2025-11-02 20:21:54,385 - WARNING - No builder class found for step: missing_value_imputation_calibration
# 2025-11-02 20:21:54,385 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,385 - WARNING - No builder class found for step: missing_value_imputation_calibration
# 2025-11-02 20:21:54,386 - INFO - Trying base step type 'missing_value_imputation' for compound 'missing_value_imputation_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,386 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,386 - WARNING - No builder class found for step: missing_value
# 2025-11-02 20:21:54,387 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,387 - WARNING - No builder class found for step: missing_value_imputation_testing
# 2025-11-02 20:21:54,387 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,388 - WARNING - No builder class found for step: missing_value_imputation_testing
# 2025-11-02 20:21:54,388 - INFO - Trying base step type 'missing_value_imputation' for compound 'missing_value_imputation_testing' (job_type: testing)
# 2025-11-02 20:21:54,388 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,389 - WARNING - No builder class found for step: missing_value
# 2025-11-02 20:21:54,389 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,389 - WARNING - No builder class found for step: missing_value_imputation_training
# 2025-11-02 20:21:54,390 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,390 - WARNING - No builder class found for step: missing_value_imputation_training
# 2025-11-02 20:21:54,390 - INFO - Trying base step type 'missing_value_imputation' for compound 'missing_value_imputation_training' (job_type: training)
# 2025-11-02 20:21:54,391 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,391 - WARNING - No builder class found for step: missing_value
# 2025-11-02 20:21:54,391 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,392 - WARNING - No builder class found for step: missing_value_imputation_validation
# 2025-11-02 20:21:54,392 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,392 - WARNING - No builder class found for step: missing_value_imputation_validation
# 2025-11-02 20:21:54,393 - INFO - Trying base step type 'missing_value_imputation' for compound 'missing_value_imputation_validation' (job_type: validation)
# 2025-11-02 20:21:54,393 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,393 - WARNING - No builder class found for step: missing_value
# 2025-11-02 20:21:54,394 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:54,394 - WARNING - No builder class found for step: model_calibration_calibration
# 2025-11-02 20:21:54,394 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,395 - WARNING - No builder class found for step: model_calibration_calibration
# 2025-11-02 20:21:54,395 - INFO - Trying base step type 'model_calibration' for compound 'model_calibration_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,395 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,395 - WARNING - No builder class found for step: model
# 2025-11-02 20:21:54,396 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,396 - WARNING - No builder class found for step: model_calibration_testing
# 2025-11-02 20:21:54,396 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,397 - WARNING - No builder class found for step: model_calibration_testing
# 2025-11-02 20:21:54,397 - INFO - Trying base step type 'model_calibration' for compound 'model_calibration_testing' (job_type: testing)
# 2025-11-02 20:21:54,397 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,398 - WARNING - No builder class found for step: model
# 2025-11-02 20:21:54,398 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,398 - WARNING - No builder class found for step: model_calibration_training
# 2025-11-02 20:21:54,399 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,399 - WARNING - No builder class found for step: model_calibration_training
# 2025-11-02 20:21:54,399 - INFO - Trying base step type 'model_calibration' for compound 'model_calibration_training' (job_type: training)
# 2025-11-02 20:21:54,400 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,400 - WARNING - No builder class found for step: model
# 2025-11-02 20:21:54,400 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,400 - WARNING - No builder class found for step: model_calibration_validation
# 2025-11-02 20:21:54,401 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,401 - WARNING - No builder class found for step: model_calibration_validation
# 2025-11-02 20:21:54,401 - INFO - Trying base step type 'model_calibration' for compound 'model_calibration_validation' (job_type: validation)
# 2025-11-02 20:21:54,402 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,402 - WARNING - No builder class found for step: model
# 2025-11-02 20:21:54,402 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:54,403 - WARNING - No builder class found for step: package
# 2025-11-02 20:21:54,403 - WARNING - No builder class found for step: package
# 2025-11-02 20:21:54,403 - WARNING - No builder class found for step: payload
# 2025-11-02 20:21:54,404 - WARNING - No builder class found for step: payload
# 2025-11-02 20:21:54,404 - WARNING - No builder class found for step: pytorch_model
# 2025-11-02 20:21:54,404 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:54,405 - WARNING - No builder class found for step: pytorch_model
# 2025-11-02 20:21:54,405 - INFO - Trying base step type 'pytorch' for compound 'pytorch_model' (job_type: model)
# 2025-11-02 20:21:54,405 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:54,406 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:54,406 - WARNING - No builder class found for step: pytorch_training
# 2025-11-02 20:21:54,406 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:54,407 - WARNING - No builder class found for step: pytorch_training
# 2025-11-02 20:21:54,407 - INFO - Trying base step type 'pytorch' for compound 'pytorch_training' (job_type: training)
# 2025-11-02 20:21:54,407 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:54,408 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:54,408 - WARNING - No builder class found for step: registration
# 2025-11-02 20:21:54,408 - WARNING - No builder class found for step: registration
# 2025-11-02 20:21:54,409 - WARNING - No builder class found for step: risk_table_mapping_calibration
# 2025-11-02 20:21:54,409 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,409 - WARNING - No builder class found for step: risk_table_mapping_calibration
# 2025-11-02 20:21:54,410 - INFO - Trying base step type 'risk_table_mapping' for compound 'risk_table_mapping_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,410 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,410 - WARNING - No builder class found for step: risk_table
# 2025-11-02 20:21:54,410 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,411 - WARNING - No builder class found for step: risk_table_mapping_testing
# 2025-11-02 20:21:54,411 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,411 - WARNING - No builder class found for step: risk_table_mapping_testing
# 2025-11-02 20:21:54,412 - INFO - Trying base step type 'risk_table_mapping' for compound 'risk_table_mapping_testing' (job_type: testing)
# 2025-11-02 20:21:54,412 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,412 - WARNING - No builder class found for step: risk_table
# 2025-11-02 20:21:54,413 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,413 - WARNING - No builder class found for step: risk_table_mapping_training
# 2025-11-02 20:21:54,413 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,414 - WARNING - No builder class found for step: risk_table_mapping_training
# 2025-11-02 20:21:54,414 - INFO - Trying base step type 'risk_table_mapping' for compound 'risk_table_mapping_training' (job_type: training)
# 2025-11-02 20:21:54,414 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,415 - WARNING - No builder class found for step: risk_table
# 2025-11-02 20:21:54,415 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,415 - WARNING - No builder class found for step: risk_table_mapping_validation
# 2025-11-02 20:21:54,416 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,416 - WARNING - No builder class found for step: risk_table_mapping_validation
# 2025-11-02 20:21:54,416 - INFO - Trying base step type 'risk_table_mapping' for compound 'risk_table_mapping_validation' (job_type: validation)
# 2025-11-02 20:21:54,417 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,417 - WARNING - No builder class found for step: risk_table
# 2025-11-02 20:21:54,417 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:54,418 - WARNING - No builder class found for step: stratified_sampling_calibration
# 2025-11-02 20:21:54,418 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,418 - WARNING - No builder class found for step: stratified_sampling_calibration
# 2025-11-02 20:21:54,418 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,419 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,419 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:54,419 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,420 - WARNING - No builder class found for step: stratified_sampling_testing
# 2025-11-02 20:21:54,420 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,420 - WARNING - No builder class found for step: stratified_sampling_testing
# 2025-11-02 20:21:54,421 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_testing' (job_type: testing)
# 2025-11-02 20:21:54,421 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,421 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:54,422 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,422 - WARNING - No builder class found for step: stratified_sampling_training
# 2025-11-02 20:21:54,422 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,423 - WARNING - No builder class found for step: stratified_sampling_training
# 2025-11-02 20:21:54,423 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_training' (job_type: training)
# 2025-11-02 20:21:54,423 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,424 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:54,424 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,424 - WARNING - No builder class found for step: stratified_sampling_validation
# 2025-11-02 20:21:54,425 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,425 - WARNING - No builder class found for step: stratified_sampling_validation
# 2025-11-02 20:21:54,425 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_validation' (job_type: validation)
# 2025-11-02 20:21:54,426 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,426 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:54,426 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:54,426 - WARNING - No builder class found for step: tabular_preprocessing_calibration
# 2025-11-02 20:21:54,427 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,427 - WARNING - No builder class found for step: tabular_preprocessing_calibration
# 2025-11-02 20:21:54,427 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,428 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,428 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:54,428 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,429 - WARNING - No builder class found for step: tabular_preprocessing_testing
# 2025-11-02 20:21:54,429 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,429 - WARNING - No builder class found for step: tabular_preprocessing_testing
# 2025-11-02 20:21:54,430 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_testing' (job_type: testing)
# 2025-11-02 20:21:54,430 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,430 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:54,431 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,431 - WARNING - No builder class found for step: tabular_preprocessing_training
# 2025-11-02 20:21:54,431 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,432 - WARNING - No builder class found for step: tabular_preprocessing_training
# 2025-11-02 20:21:54,432 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_training' (job_type: training)
# 2025-11-02 20:21:54,432 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,433 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:54,433 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,433 - WARNING - No builder class found for step: tabular_preprocessing_validation
# 2025-11-02 20:21:54,433 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,434 - WARNING - No builder class found for step: tabular_preprocessing_validation
# 2025-11-02 20:21:54,434 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_validation' (job_type: validation)
# 2025-11-02 20:21:54,434 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,435 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:54,435 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:54,435 - WARNING - No builder class found for step: temporal_feature_engineering_calibration
# 2025-11-02 20:21:54,436 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,436 - WARNING - No builder class found for step: temporal_feature_engineering_calibration
# 2025-11-02 20:21:54,436 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,437 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,437 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:54,437 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,438 - WARNING - No builder class found for step: temporal_feature_engineering_testing
# 2025-11-02 20:21:54,438 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,438 - WARNING - No builder class found for step: temporal_feature_engineering_testing
# 2025-11-02 20:21:54,439 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_testing' (job_type: testing)
# 2025-11-02 20:21:54,439 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,439 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:54,439 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,440 - WARNING - No builder class found for step: temporal_feature_engineering_training
# 2025-11-02 20:21:54,440 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,440 - WARNING - No builder class found for step: temporal_feature_engineering_training
# 2025-11-02 20:21:54,441 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_training' (job_type: training)
# 2025-11-02 20:21:54,441 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,441 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:54,442 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,442 - WARNING - No builder class found for step: temporal_feature_engineering_validation
# 2025-11-02 20:21:54,442 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,443 - WARNING - No builder class found for step: temporal_feature_engineering_validation
# 2025-11-02 20:21:54,443 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_validation' (job_type: validation)
# 2025-11-02 20:21:54,443 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,444 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:54,444 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:54,444 - WARNING - No builder class found for step: temporal_sequence_normalization_calibration
# 2025-11-02 20:21:54,445 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:54,445 - WARNING - No builder class found for step: temporal_sequence_normalization_calibration
# 2025-11-02 20:21:54,445 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_calibration' (job_type: calibration)
# 2025-11-02 20:21:54,446 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:54,446 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:21:54,446 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:54,446 - WARNING - No builder class found for step: temporal_sequence_normalization_testing
# ...
# 2025-11-02 20:21:56,289 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:56,290 - WARNING - No builder class found for step: stratified_sampling_testing
# 2025-11-02 20:21:56,290 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_testing' (job_type: testing)
# 2025-11-02 20:21:56,290 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:56,290 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:56,291 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:56,291 - WARNING - No builder class found for step: stratified_sampling_training
# 2025-11-02 20:21:56,291 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:56,292 - WARNING - No builder class found for step: stratified_sampling_training
# 2025-11-02 20:21:56,292 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_training' (job_type: training)
# 2025-11-02 20:21:56,292 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:56,293 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:56,293 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:56,293 - WARNING - No builder class found for step: stratified_sampling_validation
# 2025-11-02 20:21:56,294 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:56,294 - WARNING - No builder class found for step: stratified_sampling_validation
# 2025-11-02 20:21:56,294 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_validation' (job_type: validation)
# 2025-11-02 20:21:56,294 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:56,295 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:56,295 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:56,295 - WARNING - No builder class found for step: tabular_preprocessing_calibration
# 2025-11-02 20:21:56,296 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,296 - WARNING - No builder class found for step: tabular_preprocessing_calibration
# 2025-11-02 20:21:56,296 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_calibration' (job_type: calibration)
# 2025-11-02 20:21:56,297 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,297 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:56,297 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,297 - WARNING - No builder class found for step: tabular_preprocessing_testing
# 2025-11-02 20:21:56,298 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,298 - WARNING - No builder class found for step: tabular_preprocessing_testing
# 2025-11-02 20:21:56,298 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_testing' (job_type: testing)
# 2025-11-02 20:21:56,299 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,299 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:56,299 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,300 - WARNING - No builder class found for step: tabular_preprocessing_training
# 2025-11-02 20:21:56,300 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,300 - WARNING - No builder class found for step: tabular_preprocessing_training
# 2025-11-02 20:21:56,300 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_training' (job_type: training)
# 2025-11-02 20:21:56,301 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,301 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:56,301 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,302 - WARNING - No builder class found for step: tabular_preprocessing_validation
# 2025-11-02 20:21:56,302 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,302 - WARNING - No builder class found for step: tabular_preprocessing_validation
# 2025-11-02 20:21:56,303 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_validation' (job_type: validation)
# 2025-11-02 20:21:56,303 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,303 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:56,304 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:56,304 - WARNING - No builder class found for step: temporal_feature_engineering_calibration
# 2025-11-02 20:21:56,304 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,304 - WARNING - No builder class found for step: temporal_feature_engineering_calibration
# 2025-11-02 20:21:56,305 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_calibration' (job_type: calibration)
# 2025-11-02 20:21:56,305 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,305 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:56,306 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,306 - WARNING - No builder class found for step: temporal_feature_engineering_testing
# 2025-11-02 20:21:56,306 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,307 - WARNING - No builder class found for step: temporal_feature_engineering_testing
# 2025-11-02 20:21:56,307 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_testing' (job_type: testing)
# 2025-11-02 20:21:56,307 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,308 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:56,308 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,308 - WARNING - No builder class found for step: temporal_feature_engineering_training
# 2025-11-02 20:21:56,308 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,309 - WARNING - No builder class found for step: temporal_feature_engineering_training
# 2025-11-02 20:21:56,309 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_training' (job_type: training)
# 2025-11-02 20:21:56,309 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,310 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:56,310 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,310 - WARNING - No builder class found for step: temporal_feature_engineering_validation
# 2025-11-02 20:21:56,311 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,311 - WARNING - No builder class found for step: temporal_feature_engineering_validation
# 2025-11-02 20:21:56,311 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_validation' (job_type: validation)
# 2025-11-02 20:21:56,312 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,312 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:56,312 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:56,312 - WARNING - No builder class found for step: temporal_sequence_normalization_calibration
# 2025-11-02 20:21:56,313 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,313 - WARNING - No builder class found for step: temporal_sequence_normalization_calibration
# 2025-11-02 20:21:56,313 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_calibration' (job_type: calibration)
# 2025-11-02 20:21:56,314 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,314 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:21:56,314 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,315 - WARNING - No builder class found for step: temporal_sequence_normalization_testing
# 2025-11-02 20:21:56,315 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,315 - WARNING - No builder class found for step: temporal_sequence_normalization_testing
# 2025-11-02 20:21:56,316 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_testing' (job_type: testing)
# 2025-11-02 20:21:56,316 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,316 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:21:56,316 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,317 - WARNING - No builder class found for step: temporal_sequence_normalization_training
# 2025-11-02 20:21:56,317 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,317 - WARNING - No builder class found for step: temporal_sequence_normalization_training
# 2025-11-02 20:21:56,318 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_training' (job_type: training)
# 2025-11-02 20:21:56,318 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,318 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:21:56,319 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,319 - WARNING - No builder class found for step: temporal_sequence_normalization_validation
# 2025-11-02 20:21:56,319 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,320 - WARNING - No builder class found for step: temporal_sequence_normalization_validation
# 2025-11-02 20:21:56,320 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_validation' (job_type: validation)
# 2025-11-02 20:21:56,320 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,320 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:21:56,321 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:56,321 - WARNING - No builder class found for step: training_script
# 2025-11-02 20:21:56,321 - WARNING - No builder class found for step: training
# 2025-11-02 20:21:56,322 - WARNING - No builder class found for step: training_script
# 2025-11-02 20:21:56,322 - INFO - Trying base step type 'training' for compound 'training_script' (job_type: script)
# 2025-11-02 20:21:56,322 - WARNING - No builder class found for step: training
# 2025-11-02 20:21:56,323 - WARNING - No builder class found for step: training
# 2025-11-02 20:21:56,323 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:21:56,323 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:21:56,324 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:21:56,324 - INFO - Trying base step type 'xgboost' for compound 'xgboost_model' (job_type: model)
# 2025-11-02 20:21:56,324 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:21:56,324 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:21:56,325 - WARNING - No builder class found for step: xgboost_model_eval
# 2025-11-02 20:21:56,325 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:21:56,325 - WARNING - No builder class found for step: xgboost_model_eval
# 2025-11-02 20:21:56,326 - INFO - Trying base step type 'xgboost_model' for compound 'xgboost_model_eval' (job_type: eval)
# 2025-11-02 20:21:56,326 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:21:56,326 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:21:56,327 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:21:56,327 - WARNING - No builder class found for step: xgboost_model_inference
# 2025-11-02 20:21:56,327 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:21:56,328 - WARNING - No builder class found for step: xgboost_model_inference
# 2025-11-02 20:21:56,328 - INFO - Trying base step type 'xgboost_model' for compound 'xgboost_model_inference' (job_type: inference)
# 2025-11-02 20:21:56,328 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:21:56,328 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:21:56,329 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:21:56,329 - WARNING - No builder class found for step: xgboost_training
# 2025-11-02 20:21:56,341 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:21:56,341 - WARNING - No builder class found for step: xgboost_training
# 2025-11-02 20:21:56,342 - INFO - Trying base step type 'xgboost' for compound 'xgboost_training' (job_type: training)
# 2025-11-02 20:21:56,342 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:21:56,342 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:21:56,343 - INFO - Using 29 registered step builders from StepCatalog
# 2025-11-02 20:21:56,343 - WARNING - No builder class found for step: CradleDataLoading_training
# 2025-11-02 20:21:56,343 - INFO - Successfully loaded builder class using base name 'CradleDataLoading' for 'CradleDataLoading_training': CradleDataLoadingStepBuilder
# 2025-11-02 20:21:56,344 - WARNING - No builder class found for step: TabularPreprocessing_training
# 2025-11-02 20:21:56,344 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-11-02 20:21:56,345 - WARNING - No builder class found for step: ModelCalibration_calibration
# 2025-11-02 20:21:56,345 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-11-02 20:21:56,346 - WARNING - No builder class found for step: CradleDataLoading_calibration
# 2025-11-02 20:21:56,346 - INFO - Successfully loaded builder class using base name 'CradleDataLoading' for 'CradleDataLoading_calibration': CradleDataLoadingStepBuilder
# 2025-11-02 20:21:56,346 - WARNING - No builder class found for step: TabularPreprocessing_calibration
# 2025-11-02 20:21:56,346 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-11-02 20:21:56,347 - WARNING - No builder class found for step: XGBoostModelEval_calibration
# 2025-11-02 20:21:56,347 - INFO - Successfully loaded builder class using base name 'XGBoostModelEval' for 'XGBoostModelEval_calibration': XGBoostModelEvalStepBuilder
# 2025-11-02 20:21:56,348 - INFO - Configuration validation passed successfully
# 2025-11-02 20:21:56,348 - INFO - Pipeline name 'lukexie-AtoZ-xgboost-NA-1.3.1-pipeline' sanitized to 'lukexie-AtoZ-xgboost-NA-1-3-1-pipeline' to conform to SageMaker constraints
# 2025-11-02 20:21:56,348 - INFO - Initialized template for: lukexie-AtoZ-xgboost-NA-1-3-1-pipeline
# 2025-11-02 20:21:56,349 - INFO - Successfully created template
# 2025-11-02 20:21:56,349 - INFO - Validation completed: ✅ Validation passed
# 2025-11-02 20:21:56,350 - INFO - DAG validation: VALID

# %% [markdown]
# ### Put it Together: Pipeline Generation from DAG

# %%
# Convert DAG to pipeline and get report
try:
    logger.info(f"Converting DAG to pipeline")
    template_pipeline, report = dag_compiler.compile_with_report(dag=dag)

    # Log report summary
    logger.info(f"Conversion complete: {report.summary()}")
    for node, details in report.resolution_details.items():
        logger.info(f"  {node} → {details['config_type']} ({details['builder_type']})")

    # Log pipeline creation details
    logger.info(f"Pipeline '{template_pipeline.name}' created successfully")
    logger.info(
        f"Pipeline ARN: {template_pipeline.arn if hasattr(template_pipeline, 'arn') else 'Not available until upserted'}"
    )
    logger.info("To upsert the pipeline, call pipeline.upsert()")
except Exception as e:
    logger.error(f"Failed to convert DAG to pipeline: {e}")
    raise
# Out:
# 2025-11-02 20:21:56,355 - INFO - Converting DAG to pipeline
# 2025-11-02 20:21:56,356 - INFO - Compiling DAG with detailed reporting
# 2025-11-02 20:21:56,356 - INFO - Compiling DAG with 10 nodes to pipeline
# 2025-11-02 20:21:56,357 - INFO - Creating template for DAG with 10 nodes
# 2025-11-02 20:21:56,357 - INFO - Loading configs from: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:56,357 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:21:56,358 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:21:56,359 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:21:56,359 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:21:56,359 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-02 20:21:56,409 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:56,414 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:56,440 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:56,440 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:56,441 - INFO - Successfully discovered 46 config classes using step catalog
# 2025-11-02 20:21:56,441 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:56,442 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:56,444 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:56,444 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json with 10 specific configs
# 2025-11-02 20:21:56,445 - INFO - Creating additional config instance for CradleDataLoading_calibration (CradleDataLoadingConfig)
# 2025-11-02 20:21:56,495 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:56,500 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:56,526 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:56,526 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:56,526 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:56,576 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:56,581 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:56,606 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:56,606 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:56,607 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:56,608 - INFO - Creating additional config instance for CradleDataLoading_training (CradleDataLoadingConfig)
# 2025-11-02 20:21:56,657 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:56,662 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:56,687 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:56,687 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:56,688 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:56,737 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:56,742 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:56,767 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:56,767 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:56,768 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:56,769 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-11-02 20:21:56,818 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:56,823 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:56,848 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:56,849 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:56,849 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:56,898 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:56,903 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:56,928 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:56,928 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:56,929 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:56,929 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-11-02 20:21:56,979 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:56,984 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,009 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,009 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,009 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,059 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,064 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,089 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,089 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,090 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,090 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-11-02 20:21:57,140 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,144 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,169 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,170 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,170 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,219 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,224 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,249 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,250 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,250 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,250 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-11-02 20:21:57,300 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,305 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,330 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,330 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,330 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,380 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,385 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,410 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,410 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,410 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,411 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-11-02 20:21:57,461 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,466 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,491 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,491 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,491 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,541 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,546 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,571 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,571 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,571 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,572 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-11-02 20:21:57,621 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,626 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,651 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,651 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,652 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,701 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,706 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,731 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,731 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,732 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,732 - INFO - Creating additional config instance for XGBoostModelEval_calibration (XGBoostModelEvalConfig)
# 2025-11-02 20:21:57,782 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,787 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,812 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,812 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,812 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,862 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,867 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,892 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,892 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,892 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:57,893 - INFO - Creating additional config instance for XGBoostTraining (XGBoostTrainingConfig)
# 2025-11-02 20:21:57,943 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:57,947 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:57,972 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:57,973 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:57,973 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:58,023 - INFO - Discovered 36 core config classes
# 2025-11-02 20:21:58,027 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:21:58,052 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:21:58,053 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:21:58,053 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:21:58,053 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:58,055 - INFO - Loaded raw configuration data from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:21:58,055 - INFO - Initialized registry manager with workspace context: None
# 2025-11-02 20:21:58,055 - INFO - Created specification registry for context 'lukexie-AtoZ-xgboost-NA'
# 2025-11-02 20:21:58,056 - INFO - Created new workspace-aware registry for context 'lukexie-AtoZ-xgboost-NA'
# 2025-11-02 20:21:58,056 - INFO - Created registry manager for context: lukexie-AtoZ-xgboost-NA
# 2025-11-02 20:21:58,057 - INFO - Created dependency resolver for context: lukexie-AtoZ-xgboost-NA
# 2025-11-02 20:21:58,057 - INFO - Skipping configuration validation (requested)
# 2025-11-02 20:21:58,057 - INFO - Pipeline name 'lukexie-AtoZ-xgboost-NA-1.3.1-pipeline' sanitized to 'lukexie-AtoZ-xgboost-NA-1-3-1-pipeline' to conform to SageMaker constraints
# 2025-11-02 20:21:58,058 - INFO - Initialized template for: lukexie-AtoZ-xgboost-NA-1-3-1-pipeline
# 2025-11-02 20:21:58,058 - INFO - Successfully created template
# 2025-11-02 20:21:58,058 - INFO - Pipeline name 'lukexie-AtoZ-xgboost-NA-1.3.1-pipeline' sanitized to 'lukexie-AtoZ-xgboost-NA-1-3-1-pipeline' to conform to SageMaker constraints
# 2025-11-02 20:21:58,059 - INFO - Generating pipeline: lukexie-AtoZ-xgboost-NA-1-3-1-pipeline
# 2025-11-02 20:21:58,059 - INFO - Resolving 10 DAG nodes to configurations
# 2025-11-02 20:21:58,059 - INFO - Using metadata from loaded configuration
# 2025-11-02 20:21:58,060 - INFO - Found exact key match for node 'CradleDataLoading_training'
# 2025-11-02 20:21:58,060 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-02 20:21:58,060 - INFO - Found exact key match for node 'XGBoostTraining'
# 2025-11-02 20:21:58,061 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-02 20:21:58,061 - INFO - Found exact key match for node 'Package'
# 2025-11-02 20:21:58,061 - INFO - Found exact key match for node 'Registration'
# 2025-11-02 20:21:58,062 - INFO - Found exact key match for node 'Payload'
# 2025-11-02 20:21:58,062 - INFO - Found exact key match for node 'CradleDataLoading_calibration'
# 2025-11-02 20:21:58,062 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-02 20:21:58,062 - INFO - Found exact key match for node 'XGBoostModelEval_calibration'
# 2025-11-02 20:21:58,063 - INFO - Successfully resolved all 10 nodes
# 2025-11-02 20:21:58,063 - WARNING - No builder class found for step: Base
# 2025-11-02 20:21:58,063 - WARNING - No builder class found for step: Base
# 2025-11-02 20:21:58,064 - WARNING - No builder class found for step: HyperparameterPrep
# 2025-11-02 20:21:58,066 - WARNING - No builder class found for step: HyperparameterPrep
# 2025-11-02 20:21:58,066 - WARNING - No builder class found for step: PercentileModelCalibration
# 2025-11-02 20:21:58,067 - WARNING - No builder class found for step: PercentileModelCalibration
# 2025-11-02 20:21:58,067 - WARNING - No builder class found for step: Processing
# 2025-11-02 20:21:58,067 - WARNING - No builder class found for step: Processing
# 2025-11-02 20:21:58,068 - WARNING - No builder class found for step: batch_transform_calibration
# 2025-11-02 20:21:58,068 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,068 - WARNING - No builder class found for step: batch_transform_calibration
# 2025-11-02 20:21:58,068 - INFO - Trying base step type 'batch_transform' for compound 'batch_transform_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,069 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,069 - WARNING - No builder class found for step: batch
# 2025-11-02 20:21:58,069 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,070 - WARNING - No builder class found for step: batch_transform_testing
# 2025-11-02 20:21:58,070 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,070 - WARNING - No builder class found for step: batch_transform_testing
# 2025-11-02 20:21:58,071 - INFO - Trying base step type 'batch_transform' for compound 'batch_transform_testing' (job_type: testing)
# 2025-11-02 20:21:58,072 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,072 - WARNING - No builder class found for step: batch
# 2025-11-02 20:21:58,073 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,073 - WARNING - No builder class found for step: batch_transform_training
# 2025-11-02 20:21:58,073 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,074 - WARNING - No builder class found for step: batch_transform_training
# 2025-11-02 20:21:58,074 - INFO - Trying base step type 'batch_transform' for compound 'batch_transform_training' (job_type: training)
# 2025-11-02 20:21:58,074 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,075 - WARNING - No builder class found for step: batch
# 2025-11-02 20:21:58,075 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,075 - WARNING - No builder class found for step: batch_transform_validation
# 2025-11-02 20:21:58,075 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,076 - WARNING - No builder class found for step: batch_transform_validation
# 2025-11-02 20:21:58,076 - INFO - Trying base step type 'batch_transform' for compound 'batch_transform_validation' (job_type: validation)
# 2025-11-02 20:21:58,076 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,077 - WARNING - No builder class found for step: batch
# 2025-11-02 20:21:58,077 - WARNING - No builder class found for step: batch_transform
# 2025-11-02 20:21:58,077 - WARNING - No builder class found for step: cradle_data_loading_calibration
# 2025-11-02 20:21:58,078 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,078 - WARNING - No builder class found for step: cradle_data_loading_calibration
# 2025-11-02 20:21:58,078 - INFO - Trying base step type 'cradle_data_loading' for compound 'cradle_data_loading_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,079 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,079 - WARNING - No builder class found for step: cradle_data
# 2025-11-02 20:21:58,079 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,079 - WARNING - No builder class found for step: cradle_data_loading_testing
# 2025-11-02 20:21:58,080 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,080 - WARNING - No builder class found for step: cradle_data_loading_testing
# 2025-11-02 20:21:58,080 - INFO - Trying base step type 'cradle_data_loading' for compound 'cradle_data_loading_testing' (job_type: testing)
# 2025-11-02 20:21:58,081 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,081 - WARNING - No builder class found for step: cradle_data
# 2025-11-02 20:21:58,081 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,082 - WARNING - No builder class found for step: cradle_data_loading_training
# 2025-11-02 20:21:58,082 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,082 - WARNING - No builder class found for step: cradle_data_loading_training
# 2025-11-02 20:21:58,082 - INFO - Trying base step type 'cradle_data_loading' for compound 'cradle_data_loading_training' (job_type: training)
# 2025-11-02 20:21:58,083 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,083 - WARNING - No builder class found for step: cradle_data
# 2025-11-02 20:21:58,083 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,086 - WARNING - No builder class found for step: cradle_data_loading_validation
# 2025-11-02 20:21:58,087 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,087 - WARNING - No builder class found for step: cradle_data_loading_validation
# 2025-11-02 20:21:58,087 - INFO - Trying base step type 'cradle_data_loading' for compound 'cradle_data_loading_validation' (job_type: validation)
# 2025-11-02 20:21:58,088 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,088 - WARNING - No builder class found for step: cradle_data
# 2025-11-02 20:21:58,088 - WARNING - No builder class found for step: cradle_data_loading
# 2025-11-02 20:21:58,089 - WARNING - No builder class found for step: currency_conversion_calibration
# 2025-11-02 20:21:58,089 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,089 - WARNING - No builder class found for step: currency_conversion_calibration
# 2025-11-02 20:21:58,089 - INFO - Trying base step type 'currency_conversion' for compound 'currency_conversion_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,090 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,090 - WARNING - No builder class found for step: currency
# 2025-11-02 20:21:58,090 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,091 - WARNING - No builder class found for step: currency_conversion_testing
# 2025-11-02 20:21:58,091 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,091 - WARNING - No builder class found for step: currency_conversion_testing
# 2025-11-02 20:21:58,092 - INFO - Trying base step type 'currency_conversion' for compound 'currency_conversion_testing' (job_type: testing)
# 2025-11-02 20:21:58,092 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,092 - WARNING - No builder class found for step: currency
# 2025-11-02 20:21:58,092 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,093 - WARNING - No builder class found for step: currency_conversion_training
# 2025-11-02 20:21:58,093 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,093 - WARNING - No builder class found for step: currency_conversion_training
# 2025-11-02 20:21:58,094 - INFO - Trying base step type 'currency_conversion' for compound 'currency_conversion_training' (job_type: training)
# 2025-11-02 20:21:58,094 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,094 - WARNING - No builder class found for step: currency
# 2025-11-02 20:21:58,095 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,095 - WARNING - No builder class found for step: currency_conversion_validation
# 2025-11-02 20:21:58,095 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,095 - WARNING - No builder class found for step: currency_conversion_validation
# 2025-11-02 20:21:58,096 - INFO - Trying base step type 'currency_conversion' for compound 'currency_conversion_validation' (job_type: validation)
# 2025-11-02 20:21:58,096 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,096 - WARNING - No builder class found for step: currency
# 2025-11-02 20:21:58,097 - WARNING - No builder class found for step: currency_conversion
# 2025-11-02 20:21:58,097 - WARNING - No builder class found for step: dummy_data_loading_calibration
# 2025-11-02 20:21:58,097 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,098 - WARNING - No builder class found for step: dummy_data_loading_calibration
# 2025-11-02 20:21:58,098 - INFO - Trying base step type 'dummy_data_loading' for compound 'dummy_data_loading_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,098 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,099 - WARNING - No builder class found for step: dummy_data
# 2025-11-02 20:21:58,099 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,099 - WARNING - No builder class found for step: dummy_data_loading_testing
# 2025-11-02 20:21:58,099 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,100 - WARNING - No builder class found for step: dummy_data_loading_testing
# 2025-11-02 20:21:58,100 - INFO - Trying base step type 'dummy_data_loading' for compound 'dummy_data_loading_testing' (job_type: testing)
# 2025-11-02 20:21:58,100 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,101 - WARNING - No builder class found for step: dummy_data
# 2025-11-02 20:21:58,101 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,101 - WARNING - No builder class found for step: dummy_data_loading_training
# 2025-11-02 20:21:58,102 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,102 - WARNING - No builder class found for step: dummy_data_loading_training
# 2025-11-02 20:21:58,102 - INFO - Trying base step type 'dummy_data_loading' for compound 'dummy_data_loading_training' (job_type: training)
# 2025-11-02 20:21:58,102 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,103 - WARNING - No builder class found for step: dummy_data
# 2025-11-02 20:21:58,103 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,103 - WARNING - No builder class found for step: dummy_data_loading_validation
# 2025-11-02 20:21:58,104 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,104 - WARNING - No builder class found for step: dummy_data_loading_validation
# 2025-11-02 20:21:58,104 - INFO - Trying base step type 'dummy_data_loading' for compound 'dummy_data_loading_validation' (job_type: validation)
# 2025-11-02 20:21:58,105 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,105 - WARNING - No builder class found for step: dummy_data
# 2025-11-02 20:21:58,105 - WARNING - No builder class found for step: dummy_data_loading
# 2025-11-02 20:21:58,106 - WARNING - No builder class found for step: lightgbm_training
# 2025-11-02 20:21:58,106 - WARNING - No builder class found for step: lightgbm
# 2025-11-02 20:21:58,111 - WARNING - No builder class found for step: lightgbm_training
# 2025-11-02 20:21:58,111 - INFO - Trying base step type 'lightgbm' for compound 'lightgbm_training' (job_type: training)
# 2025-11-02 20:21:58,111 - WARNING - No builder class found for step: lightgbm
# 2025-11-02 20:21:58,112 - WARNING - No builder class found for step: lightgbm
# 2025-11-02 20:21:58,112 - WARNING - No builder class found for step: mims_registration
# 2025-11-02 20:21:58,113 - WARNING - No builder class found for step: mims
# 2025-11-02 20:21:58,113 - WARNING - No builder class found for step: mims_registration
# 2025-11-02 20:21:58,113 - INFO - Trying base step type 'mims' for compound 'mims_registration' (job_type: registration)
# 2025-11-02 20:21:58,114 - WARNING - No builder class found for step: mims
# 2025-11-02 20:21:58,114 - WARNING - No builder class found for step: mims
# 2025-11-02 20:21:58,114 - WARNING - No builder class found for step: missing_value_imputation_calibration
# 2025-11-02 20:21:58,114 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,115 - WARNING - No builder class found for step: missing_value_imputation_calibration
# 2025-11-02 20:21:58,115 - INFO - Trying base step type 'missing_value_imputation' for compound 'missing_value_imputation_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,115 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,116 - WARNING - No builder class found for step: missing_value
# 2025-11-02 20:21:58,116 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,116 - WARNING - No builder class found for step: missing_value_imputation_testing
# 2025-11-02 20:21:58,117 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,117 - WARNING - No builder class found for step: missing_value_imputation_testing
# 2025-11-02 20:21:58,117 - INFO - Trying base step type 'missing_value_imputation' for compound 'missing_value_imputation_testing' (job_type: testing)
# 2025-11-02 20:21:58,118 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,118 - WARNING - No builder class found for step: missing_value
# 2025-11-02 20:21:58,118 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,118 - WARNING - No builder class found for step: missing_value_imputation_training
# 2025-11-02 20:21:58,119 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,119 - WARNING - No builder class found for step: missing_value_imputation_training
# 2025-11-02 20:21:58,119 - INFO - Trying base step type 'missing_value_imputation' for compound 'missing_value_imputation_training' (job_type: training)
# 2025-11-02 20:21:58,120 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,120 - WARNING - No builder class found for step: missing_value
# 2025-11-02 20:21:58,120 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,121 - WARNING - No builder class found for step: missing_value_imputation_validation
# 2025-11-02 20:21:58,121 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,121 - WARNING - No builder class found for step: missing_value_imputation_validation
# 2025-11-02 20:21:58,122 - INFO - Trying base step type 'missing_value_imputation' for compound 'missing_value_imputation_validation' (job_type: validation)
# 2025-11-02 20:21:58,122 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,122 - WARNING - No builder class found for step: missing_value
# 2025-11-02 20:21:58,122 - WARNING - No builder class found for step: missing_value_imputation
# 2025-11-02 20:21:58,123 - WARNING - No builder class found for step: model_calibration_calibration
# 2025-11-02 20:21:58,123 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,123 - WARNING - No builder class found for step: model_calibration_calibration
# 2025-11-02 20:21:58,124 - INFO - Trying base step type 'model_calibration' for compound 'model_calibration_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,124 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,124 - WARNING - No builder class found for step: model
# 2025-11-02 20:21:58,125 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,125 - WARNING - No builder class found for step: model_calibration_testing
# 2025-11-02 20:21:58,125 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,125 - WARNING - No builder class found for step: model_calibration_testing
# 2025-11-02 20:21:58,126 - INFO - Trying base step type 'model_calibration' for compound 'model_calibration_testing' (job_type: testing)
# 2025-11-02 20:21:58,126 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,126 - WARNING - No builder class found for step: model
# 2025-11-02 20:21:58,127 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,127 - WARNING - No builder class found for step: model_calibration_training
# 2025-11-02 20:21:58,127 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,128 - WARNING - No builder class found for step: model_calibration_training
# 2025-11-02 20:21:58,128 - INFO - Trying base step type 'model_calibration' for compound 'model_calibration_training' (job_type: training)
# 2025-11-02 20:21:58,128 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,128 - WARNING - No builder class found for step: model
# 2025-11-02 20:21:58,129 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,129 - WARNING - No builder class found for step: model_calibration_validation
# 2025-11-02 20:21:58,129 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,130 - WARNING - No builder class found for step: model_calibration_validation
# 2025-11-02 20:21:58,130 - INFO - Trying base step type 'model_calibration' for compound 'model_calibration_validation' (job_type: validation)
# 2025-11-02 20:21:58,130 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,131 - WARNING - No builder class found for step: model
# 2025-11-02 20:21:58,131 - WARNING - No builder class found for step: model_calibration
# 2025-11-02 20:21:58,131 - WARNING - No builder class found for step: package
# 2025-11-02 20:21:58,132 - WARNING - No builder class found for step: package
# 2025-11-02 20:21:58,132 - WARNING - No builder class found for step: payload
# 2025-11-02 20:21:58,132 - WARNING - No builder class found for step: payload
# 2025-11-02 20:21:58,132 - WARNING - No builder class found for step: pytorch_model
# 2025-11-02 20:21:58,133 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:58,133 - WARNING - No builder class found for step: pytorch_model
# 2025-11-02 20:21:58,133 - INFO - Trying base step type 'pytorch' for compound 'pytorch_model' (job_type: model)
# 2025-11-02 20:21:58,134 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:58,134 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:58,134 - WARNING - No builder class found for step: pytorch_training
# 2025-11-02 20:21:58,135 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:58,135 - WARNING - No builder class found for step: pytorch_training
# 2025-11-02 20:21:58,135 - INFO - Trying base step type 'pytorch' for compound 'pytorch_training' (job_type: training)
# 2025-11-02 20:21:58,135 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:58,136 - WARNING - No builder class found for step: pytorch
# 2025-11-02 20:21:58,136 - WARNING - No builder class found for step: registration
# 2025-11-02 20:21:58,136 - WARNING - No builder class found for step: registration
# 2025-11-02 20:21:58,137 - WARNING - No builder class found for step: risk_table_mapping_calibration
# 2025-11-02 20:21:58,137 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,137 - WARNING - No builder class found for step: risk_table_mapping_calibration
# 2025-11-02 20:21:58,138 - INFO - Trying base step type 'risk_table_mapping' for compound 'risk_table_mapping_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,144 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,144 - WARNING - No builder class found for step: risk_table
# 2025-11-02 20:21:58,144 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,145 - WARNING - No builder class found for step: risk_table_mapping_testing
# 2025-11-02 20:21:58,145 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,145 - WARNING - No builder class found for step: risk_table_mapping_testing
# 2025-11-02 20:21:58,146 - INFO - Trying base step type 'risk_table_mapping' for compound 'risk_table_mapping_testing' (job_type: testing)
# 2025-11-02 20:21:58,146 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,146 - WARNING - No builder class found for step: risk_table
# 2025-11-02 20:21:58,147 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,147 - WARNING - No builder class found for step: risk_table_mapping_training
# 2025-11-02 20:21:58,147 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,148 - WARNING - No builder class found for step: risk_table_mapping_training
# 2025-11-02 20:21:58,148 - INFO - Trying base step type 'risk_table_mapping' for compound 'risk_table_mapping_training' (job_type: training)
# 2025-11-02 20:21:58,148 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,148 - WARNING - No builder class found for step: risk_table
# 2025-11-02 20:21:58,149 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,149 - WARNING - No builder class found for step: risk_table_mapping_validation
# 2025-11-02 20:21:58,149 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,150 - WARNING - No builder class found for step: risk_table_mapping_validation
# 2025-11-02 20:21:58,150 - INFO - Trying base step type 'risk_table_mapping' for compound 'risk_table_mapping_validation' (job_type: validation)
# 2025-11-02 20:21:58,150 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,151 - WARNING - No builder class found for step: risk_table
# 2025-11-02 20:21:58,151 - WARNING - No builder class found for step: risk_table_mapping
# 2025-11-02 20:21:58,151 - WARNING - No builder class found for step: stratified_sampling_calibration
# 2025-11-02 20:21:58,152 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,152 - WARNING - No builder class found for step: stratified_sampling_calibration
# 2025-11-02 20:21:58,153 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,153 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,155 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:58,155 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,156 - WARNING - No builder class found for step: stratified_sampling_testing
# 2025-11-02 20:21:58,156 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,156 - WARNING - No builder class found for step: stratified_sampling_testing
# 2025-11-02 20:21:58,156 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_testing' (job_type: testing)
# 2025-11-02 20:21:58,157 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,157 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:58,157 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,158 - WARNING - No builder class found for step: stratified_sampling_training
# 2025-11-02 20:21:58,158 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,158 - WARNING - No builder class found for step: stratified_sampling_training
# 2025-11-02 20:21:58,159 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_training' (job_type: training)
# 2025-11-02 20:21:58,159 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,159 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:58,159 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,160 - WARNING - No builder class found for step: stratified_sampling_validation
# 2025-11-02 20:21:58,160 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,160 - WARNING - No builder class found for step: stratified_sampling_validation
# 2025-11-02 20:21:58,161 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_validation' (job_type: validation)
# 2025-11-02 20:21:58,161 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,161 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:21:58,162 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:21:58,162 - WARNING - No builder class found for step: tabular_preprocessing_calibration
# 2025-11-02 20:21:58,162 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,162 - WARNING - No builder class found for step: tabular_preprocessing_calibration
# 2025-11-02 20:21:58,163 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,163 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,163 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:58,164 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,164 - WARNING - No builder class found for step: tabular_preprocessing_testing
# 2025-11-02 20:21:58,164 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,165 - WARNING - No builder class found for step: tabular_preprocessing_testing
# 2025-11-02 20:21:58,165 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_testing' (job_type: testing)
# 2025-11-02 20:21:58,165 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,166 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:58,166 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,166 - WARNING - No builder class found for step: tabular_preprocessing_training
# 2025-11-02 20:21:58,166 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,167 - WARNING - No builder class found for step: tabular_preprocessing_training
# 2025-11-02 20:21:58,167 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_training' (job_type: training)
# 2025-11-02 20:21:58,167 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,168 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:58,168 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,168 - WARNING - No builder class found for step: tabular_preprocessing_validation
# 2025-11-02 20:21:58,169 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,169 - WARNING - No builder class found for step: tabular_preprocessing_validation
# 2025-11-02 20:21:58,169 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_validation' (job_type: validation)
# 2025-11-02 20:21:58,169 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,170 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:21:58,170 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:21:58,170 - WARNING - No builder class found for step: temporal_feature_engineering_calibration
# 2025-11-02 20:21:58,171 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,171 - WARNING - No builder class found for step: temporal_feature_engineering_calibration
# 2025-11-02 20:21:58,171 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,172 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,172 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:58,172 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,172 - WARNING - No builder class found for step: temporal_feature_engineering_testing
# 2025-11-02 20:21:58,173 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,173 - WARNING - No builder class found for step: temporal_feature_engineering_testing
# 2025-11-02 20:21:58,173 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_testing' (job_type: testing)
# 2025-11-02 20:21:58,174 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,174 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:58,174 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,175 - WARNING - No builder class found for step: temporal_feature_engineering_training
# 2025-11-02 20:21:58,175 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,175 - WARNING - No builder class found for step: temporal_feature_engineering_training
# 2025-11-02 20:21:58,176 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_training' (job_type: training)
# 2025-11-02 20:21:58,176 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,176 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:58,176 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,177 - WARNING - No builder class found for step: temporal_feature_engineering_validation
# 2025-11-02 20:21:58,177 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,177 - WARNING - No builder class found for step: temporal_feature_engineering_validation
# 2025-11-02 20:21:58,178 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_validation' (job_type: validation)
# 2025-11-02 20:21:58,178 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,178 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:21:58,179 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:21:58,179 - WARNING - No builder class found for step: temporal_sequence_normalization_calibration
# 2025-11-02 20:21:58,179 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:58,179 - WARNING - No builder class found for step: temporal_sequence_normalization_calibration
# 2025-11-02 20:21:58,180 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_calibration' (job_type: calibration)
# 2025-11-02 20:21:58,180 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:58,180 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:21:58,181 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:58,187 - WARNING - No builder class found for step: temporal_sequence_normalization_testing
# 2025-11-02 20:21:58,187 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:58,188 - WARNING - No builder class found for step: temporal_sequence_normalization_testing
# 2025-11-02 20:21:58,188 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_testing' (job_type: testing)
# 2025-11-02 20:21:58,188 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:58,189 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:21:58,189 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:58,189 - WARNING - No builder class found for step: temporal_sequence_normalization_training
# 2025-11-02 20:21:58,190 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:21:58,190 - WARNING - No builder class found for step: temporal_sequence_normalization_training
# 2025-11-02 20:21:58,190 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_training' (job_type: training)
# ...
# 2025-11-02 20:22:11,752 - INFO - Trying base step type 'stratified_sampling' for compound 'stratified_sampling_validation' (job_type: validation)
# 2025-11-02 20:22:11,753 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:22:11,753 - WARNING - No builder class found for step: stratified
# 2025-11-02 20:22:11,753 - WARNING - No builder class found for step: stratified_sampling
# 2025-11-02 20:22:11,754 - WARNING - No builder class found for step: tabular_preprocessing_calibration
# 2025-11-02 20:22:11,754 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,754 - WARNING - No builder class found for step: tabular_preprocessing_calibration
# 2025-11-02 20:22:11,755 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_calibration' (job_type: calibration)
# 2025-11-02 20:22:11,755 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,755 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:22:11,755 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,756 - WARNING - No builder class found for step: tabular_preprocessing_testing
# 2025-11-02 20:22:11,756 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,756 - WARNING - No builder class found for step: tabular_preprocessing_testing
# 2025-11-02 20:22:11,757 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_testing' (job_type: testing)
# 2025-11-02 20:22:11,757 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,757 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:22:11,758 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,758 - WARNING - No builder class found for step: tabular_preprocessing_training
# 2025-11-02 20:22:11,758 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,759 - WARNING - No builder class found for step: tabular_preprocessing_training
# 2025-11-02 20:22:11,759 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_training' (job_type: training)
# 2025-11-02 20:22:11,759 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,759 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:22:11,760 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,760 - WARNING - No builder class found for step: tabular_preprocessing_validation
# 2025-11-02 20:22:11,760 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,761 - WARNING - No builder class found for step: tabular_preprocessing_validation
# 2025-11-02 20:22:11,761 - INFO - Trying base step type 'tabular_preprocessing' for compound 'tabular_preprocessing_validation' (job_type: validation)
# 2025-11-02 20:22:11,761 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,762 - WARNING - No builder class found for step: tabular
# 2025-11-02 20:22:11,762 - WARNING - No builder class found for step: tabular_preprocessing
# 2025-11-02 20:22:11,762 - WARNING - No builder class found for step: temporal_feature_engineering_calibration
# 2025-11-02 20:22:11,762 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,763 - WARNING - No builder class found for step: temporal_feature_engineering_calibration
# 2025-11-02 20:22:11,763 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_calibration' (job_type: calibration)
# 2025-11-02 20:22:11,763 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,764 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:22:11,764 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,764 - WARNING - No builder class found for step: temporal_feature_engineering_testing
# 2025-11-02 20:22:11,765 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,765 - WARNING - No builder class found for step: temporal_feature_engineering_testing
# 2025-11-02 20:22:11,765 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_testing' (job_type: testing)
# 2025-11-02 20:22:11,765 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,766 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:22:11,766 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,766 - WARNING - No builder class found for step: temporal_feature_engineering_training
# 2025-11-02 20:22:11,767 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,767 - WARNING - No builder class found for step: temporal_feature_engineering_training
# 2025-11-02 20:22:11,767 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_training' (job_type: training)
# 2025-11-02 20:22:11,768 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,768 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:22:11,768 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,768 - WARNING - No builder class found for step: temporal_feature_engineering_validation
# 2025-11-02 20:22:11,769 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,769 - WARNING - No builder class found for step: temporal_feature_engineering_validation
# 2025-11-02 20:22:11,769 - INFO - Trying base step type 'temporal_feature_engineering' for compound 'temporal_feature_engineering_validation' (job_type: validation)
# 2025-11-02 20:22:11,770 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,770 - WARNING - No builder class found for step: temporal_feature
# 2025-11-02 20:22:11,770 - WARNING - No builder class found for step: temporal_feature_engineering
# 2025-11-02 20:22:11,771 - WARNING - No builder class found for step: temporal_sequence_normalization_calibration
# 2025-11-02 20:22:11,771 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,771 - WARNING - No builder class found for step: temporal_sequence_normalization_calibration
# 2025-11-02 20:22:11,772 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_calibration' (job_type: calibration)
# 2025-11-02 20:22:11,772 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,779 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:22:11,779 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,780 - WARNING - No builder class found for step: temporal_sequence_normalization_testing
# 2025-11-02 20:22:11,780 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,780 - WARNING - No builder class found for step: temporal_sequence_normalization_testing
# 2025-11-02 20:22:11,781 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_testing' (job_type: testing)
# 2025-11-02 20:22:11,781 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,781 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:22:11,782 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,782 - WARNING - No builder class found for step: temporal_sequence_normalization_training
# 2025-11-02 20:22:11,782 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,782 - WARNING - No builder class found for step: temporal_sequence_normalization_training
# 2025-11-02 20:22:11,783 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_training' (job_type: training)
# 2025-11-02 20:22:11,783 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,783 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:22:11,784 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,784 - WARNING - No builder class found for step: temporal_sequence_normalization_validation
# 2025-11-02 20:22:11,784 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,785 - WARNING - No builder class found for step: temporal_sequence_normalization_validation
# 2025-11-02 20:22:11,785 - INFO - Trying base step type 'temporal_sequence_normalization' for compound 'temporal_sequence_normalization_validation' (job_type: validation)
# 2025-11-02 20:22:11,785 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,785 - WARNING - No builder class found for step: temporal_sequence
# 2025-11-02 20:22:11,786 - WARNING - No builder class found for step: temporal_sequence_normalization
# 2025-11-02 20:22:11,786 - WARNING - No builder class found for step: training_script
# 2025-11-02 20:22:11,788 - WARNING - No builder class found for step: training
# 2025-11-02 20:22:11,788 - WARNING - No builder class found for step: training_script
# 2025-11-02 20:22:11,789 - INFO - Trying base step type 'training' for compound 'training_script' (job_type: script)
# 2025-11-02 20:22:11,789 - WARNING - No builder class found for step: training
# 2025-11-02 20:22:11,789 - WARNING - No builder class found for step: training
# 2025-11-02 20:22:11,790 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:22:11,790 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:22:11,790 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:22:11,791 - INFO - Trying base step type 'xgboost' for compound 'xgboost_model' (job_type: model)
# 2025-11-02 20:22:11,791 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:22:11,791 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:22:11,791 - WARNING - No builder class found for step: xgboost_model_eval
# 2025-11-02 20:22:11,792 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:22:11,792 - WARNING - No builder class found for step: xgboost_model_eval
# 2025-11-02 20:22:11,792 - INFO - Trying base step type 'xgboost_model' for compound 'xgboost_model_eval' (job_type: eval)
# 2025-11-02 20:22:11,793 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:22:11,793 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:22:11,793 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:22:11,794 - WARNING - No builder class found for step: xgboost_model_inference
# 2025-11-02 20:22:11,794 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:22:11,794 - WARNING - No builder class found for step: xgboost_model_inference
# 2025-11-02 20:22:11,795 - INFO - Trying base step type 'xgboost_model' for compound 'xgboost_model_inference' (job_type: inference)
# 2025-11-02 20:22:11,795 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:22:11,795 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:22:11,796 - WARNING - No builder class found for step: xgboost_model
# 2025-11-02 20:22:11,796 - WARNING - No builder class found for step: xgboost_training
# 2025-11-02 20:22:11,796 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:22:11,796 - WARNING - No builder class found for step: xgboost_training
# 2025-11-02 20:22:11,797 - INFO - Trying base step type 'xgboost' for compound 'xgboost_training' (job_type: training)
# 2025-11-02 20:22:11,797 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:22:11,797 - WARNING - No builder class found for step: xgboost
# 2025-11-02 20:22:11,798 - INFO - Using 29 registered step builders from StepCatalog
# 2025-11-02 20:22:11,798 - WARNING - No builder class found for step: CradleDataLoading_training
# 2025-11-02 20:22:11,798 - INFO - Successfully loaded builder class using base name 'CradleDataLoading' for 'CradleDataLoading_training': CradleDataLoadingStepBuilder
# 2025-11-02 20:22:11,799 - WARNING - No builder class found for step: TabularPreprocessing_training
# 2025-11-02 20:22:11,799 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-11-02 20:22:11,802 - WARNING - No builder class found for step: ModelCalibration_calibration
# 2025-11-02 20:22:11,802 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-11-02 20:22:11,803 - WARNING - No builder class found for step: CradleDataLoading_calibration
# 2025-11-02 20:22:11,803 - INFO - Successfully loaded builder class using base name 'CradleDataLoading' for 'CradleDataLoading_calibration': CradleDataLoadingStepBuilder
# 2025-11-02 20:22:11,804 - WARNING - No builder class found for step: TabularPreprocessing_calibration
# 2025-11-02 20:22:11,804 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-11-02 20:22:11,804 - WARNING - No builder class found for step: XGBoostModelEval_calibration
# 2025-11-02 20:22:11,805 - INFO - Successfully loaded builder class using base name 'XGBoostModelEval' for 'XGBoostModelEval_calibration': XGBoostModelEvalStepBuilder
# 2025-11-02 20:22:11,805 - INFO - Configuration validation passed successfully
# 2025-11-02 20:22:11,806 - INFO - Pipeline name 'lukexie-AtoZ-xgboost-NA-1.3.1-pipeline' sanitized to 'lukexie-AtoZ-xgboost-NA-1-3-1-pipeline' to conform to SageMaker constraints
# 2025-11-02 20:22:11,806 - INFO - Initialized template for: lukexie-AtoZ-xgboost-NA-1-3-1-pipeline
# 2025-11-02 20:22:11,806 - INFO - Successfully created template
# 2025-11-02 20:22:11,807 - INFO - Using metadata.config_types mapping with 10 entries
# 2025-11-02 20:22:11,807 - INFO - Found exact key match for node 'CradleDataLoading_training'
# 2025-11-02 20:22:11,807 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-02 20:22:11,807 - INFO - Found exact key match for node 'XGBoostTraining'
# 2025-11-02 20:22:11,808 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-02 20:22:11,808 - INFO - Found exact key match for node 'Package'
# 2025-11-02 20:22:11,808 - INFO - Found exact key match for node 'Registration'
# 2025-11-02 20:22:11,809 - INFO - Found exact key match for node 'Payload'
# 2025-11-02 20:22:11,809 - INFO - Found exact key match for node 'CradleDataLoading_calibration'
# 2025-11-02 20:22:11,809 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-02 20:22:11,810 - INFO - Found exact key match for node 'XGBoostModelEval_calibration'
# 2025-11-02 20:22:11,810 - ERROR - Failed to generate resolution preview: 0
# 2025-11-02 20:22:11,810 - INFO - Compilation completed with report: Pipeline 'lukexie-AtoZ-xgboost-NA-1-3-1-pipeline' created successfully with 10 steps (avg confidence: 0.00)
# 2025-11-02 20:22:11,811 - INFO - Conversion complete: Pipeline 'lukexie-AtoZ-xgboost-NA-1-3-1-pipeline' created successfully with 10 steps (avg confidence: 0.00)
# 2025-11-02 20:22:11,813 - INFO - Pipeline 'lukexie-AtoZ-xgboost-NA-1-3-1-pipeline' created successfully
# 2025-11-02 20:22:11,813 - INFO - Pipeline ARN: Not available until upserted
# 2025-11-02 20:22:11,813 - INFO - To upsert the pipeline, call pipeline.upsert()

# %% [markdown]
# ### Pipeline Template
#
# After the pipeline is generated, we can retrieve the pipeline template

# %%
pipeline_template_builder = dag_compiler.get_last_template()

# %% [markdown]
# ## Prepare for Execution Document

# %%
from mods_workflow_helper.sagemaker_pipeline_helper import (
    SagemakerPipelineHelper,
    SecurityConfig,
)

# %%
default_execution_doc = SagemakerPipelineHelper.get_pipeline_default_execution_document(
    template_pipeline
)
test_execution_doc = default_execution_doc

# %%
print(json.dumps(test_execution_doc, indent=2))
# Out:
# {
#   "PIPELINE_STEP_CONFIGS": {
#     "CradleDataLoading-Training": {
#       "STEP_CONFIG": {
#         "dataSources": {
#           "dataSources": [
#             {
#               "dataSourceName": "RAW_MDS",
#               "dataSourceType": "MDS",
#               "mdsDataSourceProperties": {
#                 "serviceName": "MDS_DATA_SET_NAME_IN_STRING",
#                 "orgId": "MDS_ORG_UNIT_IN_STRING",
#                 "region": "MDS_REGION/NA/EU/FE",
#                 "useHourlyEdxDataSet": false,
#                 "outputSchema": [
#                   {
#                     "fieldName": "OUTPUT_FIELD_NAME",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "orderId",
#                     "fieldType": "STRING"
#                   }
#                 ]
#               }
#             },
#             {
#               "dataSourceName": "TAGS",
#               "dataSourceType": "ANDES",
#               "andesDataSourceProperties": {
#                 "provider": "26b27bde-3847-49c6-a07c-0289c17d9c33",
#                 "tableName": "fraud-tags-na"
#               }
#             }
#           ],
#           "startDate": "2021-09-01T11:00:00",
#           "endDate": "2021-09-02T11:00:00"
#         },
#         "transformSpecification": {
#           "transformSQL": "\n        select RAW_MDS.*, IS_FRD from RAW_MDS left join TAGS on RAW_MDS.objectId=TAGS.ORDER_ID  \n        AND TAGS.ORDER_DAY_TIMESTAMP >= TO_TIMESTAMP('${startDate}', 'yyyy-MM-dd')  \n        AND TAGS.ORDER_DAY_TIMESTAMP <= TO_TIMESTAMP('${endDate}', 'yyyy-MM-dd')\n        ",
#           "jobSplitOptions": {
#             "splitJob": false,
#             "daysPerSplit": 1,
#             "mergeSql": "\n                select * from INPUT\n            "
#           }
#         },
#         "outputSpecification": {
#           "outputSchema": [
#             "OUTPUT_FIELD_NAME",
#             "orderId",
#             "IS_FRD"
#           ],
#           "outputPath": "s3://sandboxuserdependency-miaoqi-personals3bucket-6e6w5i9g07xu/mds_download_output/6c34b329-5178-43a0-82c9-a4d42e850ac6",
#           "outputFormat": "PARQUET",
#           "outputSaveMode": "ERRORIFEXISTS",
#           "outputFileCount": 0,
#           "keepDotInOutputSchema": true
#         },
#         "cradleJobSpecification": {
#           "clusterType": "LARGE",
#           "cradleAccount": "CMLS-RED",
#           "extraSparkJobArguments": "",
#           "jobRetryCount": 0
#         }
#       },
#       "STEP_TYPE": [
#         "WORKFLOW_INPUT",
#         "CradleDataLoadingStep"
#       ]
#     },
#     "CradleDataLoading-Calibration": {
#       "STEP_CONFIG": {
#         "dataSources": {
#           "dataSources": [
#             {
#               "dataSourceName": "RAW_MDS",
#               "dataSourceType": "MDS",
#               "mdsDataSourceProperties": {
#                 "serviceName": "MDS_DATA_SET_NAME_IN_STRING",
#                 "orgId": "MDS_ORG_UNIT_IN_STRING",
#                 "region": "MDS_REGION/NA/EU/FE",
#                 "useHourlyEdxDataSet": false,
#                 "outputSchema": [
#                   {
#                     "fieldName": "OUTPUT_FIELD_NAME",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "orderId",
#                     "fieldType": "STRING"
#                   }
#                 ]
#               }
#             },
#             {
#               "dataSourceName": "TAGS",
#               "dataSourceType": "ANDES",
#               "andesDataSourceProperties": {
#                 "provider": "26b27bde-3847-49c6-a07c-0289c17d9c33",
#                 "tableName": "fraud-tags-na"
#               }
#             }
#           ],
#           "startDate": "2021-09-01T11:00:00",
#           "endDate": "2021-09-02T11:00:00"
#         },
#         "transformSpecification": {
#           "transformSQL": "\n        select RAW_MDS.*, IS_FRD from RAW_MDS left join TAGS on RAW_MDS.objectId=TAGS.ORDER_ID  \n        AND TAGS.ORDER_DAY_TIMESTAMP >= TO_TIMESTAMP('${startDate}', 'yyyy-MM-dd')  \n        AND TAGS.ORDER_DAY_TIMESTAMP <= TO_TIMESTAMP('${endDate}', 'yyyy-MM-dd')\n        ",
#           "jobSplitOptions": {
#             "splitJob": false,
#             "daysPerSplit": 1,
#             "mergeSql": "\n                select * from INPUT\n            "
#           }
#         },
#         "outputSpecification": {
#           "outputSchema": [
#             "OUTPUT_FIELD_NAME",
#             "orderId",
#             "IS_FRD"
#           ],
#           "outputPath": "s3://sandboxuserdependency-miaoqi-personals3bucket-6e6w5i9g07xu/mds_download_output/6c34b329-5178-43a0-82c9-a4d42e850ac6",
#           "outputFormat": "PARQUET",
#           "outputSaveMode": "ERRORIFEXISTS",
#           "outputFileCount": 0,
#           "keepDotInOutputSchema": true
#         },
#         "cradleJobSpecification": {
#           "clusterType": "LARGE",
#           "cradleAccount": "CMLS-RED",
#           "extraSparkJobArguments": "",
#           "jobRetryCount": 0
#         }
#       },
#       "STEP_TYPE": [
#         "WORKFLOW_INPUT",
#         "CradleDataLoadingStep"
#       ]
#     },
#     "XGBoostTraining": {
#       "STEP_CONFIG": {},
#       "STEP_TYPE": "TRAINING_STEP"
#     },
#     "Registration-NA": {
#       "STEP_CONFIG": {
#         "model_domain": "The domain to register your model in (this is where you will find your model on DAWS)",
#         "model_objective": "The objective to register your model in (this is where you will find your model on DAWS)",
#         "source_model_inference_content_types": "Provide a list of types (application/json and text/csv are currently supported) for the content. Ex) ['text/csv']",
#         "source_model_inference_response_types": "Provide a list of types (application/json and text/csv are currently supported) for the response. Ex) ['application/json']",
#         "source_model_inference_input_variable_list": "Provide a dictionary mapping the variable name to the variable type (variable types supported are 'TEXT' and 'NUMERIC') for both input and output vars. Ex) {'INVAR': 'TEXT'}",
#         "source_model_inference_output_variable_list": "Provide a dictionary mapping the variable name to the variable type (variable types supported are 'TEXT' and 'NUMERIC') for both input and output vars. Ex) {'OUTVAR': 'NUMERIC'}",
#         "model_registration_region": "The region that your SageMaker model will be registered in, valid values are NA/EU/FE",
#         "model_owner": "The team id of the team that owns this model. This can be found at https://permissions.amazon.com/ by searching for your team name to get the team id.",
#         "source_model_inference_image_arn": "The image arn for your trained model to be registered. This can be found by calling model.image_uri on a created model or estimator.model_uri/estimator.image_uri on an Estimator object.",
#         "source_model_region": "Optional: The region your model was trained in and the model artifacts are located in. Default is 'us-east-1'",
#         "source_model_environment_variable_map": "Optional: You can provide a dictionary of environment variables to be associated with your model. Ex) {'SAGEMAKER_CONTAINER_LOG_LEVEL': '20'}",
#         "load_testing_info_map": "Optional: You can provide a dictionary of load testing parameters. All the parameters listed are required if providing the load testing map. Ex) {'samplePayloadS3Bucket': 'mods-personal-bucket', 'samplePayloadS3Key': 'sample_payload.csv', 'expectedTPS': '2000', 'maxLatencyInMillisecond': '50', 'instanceTypeList': ['ml.m5.xlarge', 'ml.m5d.2xlarge']}"
#       },
#       "STEP_TYPE": [
#         "PROCESSING_STEP",
#         "MimsModelRegistrationProcessingStep"
#       ]
#     }
#   },
#   "PIPELINE_ADDITIONAL_PARAMS": {}
# }

# %%
# with open(config_dir / 'sample_exe_doc.json', 'w') as f:
#    json.dump(default_execution_doc, f, indent=2)

# %% [markdown]
# ### Fill in Execution Doc

# %%
from cursus.mods.exe_doc.generator import ExecutionDocumentGenerator

# %%
exe_doc_generator = ExecutionDocumentGenerator(
    config_path=config_path,
    sagemaker_session=pipeline_session,
    role=role,
)
# Out:
# 2025-11-02 20:22:12,055 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:22:12,055 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:22:12,056 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:22:12,056 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:22:12,057 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-02 20:22:12,058 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:22:12,058 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:22:12,059 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:22:12,059 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:22:12,059 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-02 20:22:12,112 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,122 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,147 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,147 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,148 - INFO - Successfully discovered 46 config classes using step catalog
# 2025-11-02 20:22:12,148 - INFO - Discovered 46 config classes using step catalog
# 2025-11-02 20:22:12,149 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:22:12,149 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:22:12,152 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:22:12,152 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json with 10 specific configs
# 2025-11-02 20:22:12,153 - INFO - Creating additional config instance for CradleDataLoading_calibration (CradleDataLoadingConfig)
# 2025-11-02 20:22:12,153 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-11-02 20:22:12,154 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-02 20:22:12,154 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-02 20:22:12,155 - INFO - ✅ Registry info loaded: 28 steps
# 2025-11-02 20:22:12,155 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-02 20:22:12,204 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,208 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,233 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,234 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,234 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,283 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,288 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,312 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,313 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,313 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,314 - INFO - Creating additional config instance for CradleDataLoading_training (CradleDataLoadingConfig)
# 2025-11-02 20:22:12,363 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,368 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,393 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,393 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,394 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,442 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,447 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,472 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,472 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,473 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,474 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-11-02 20:22:12,523 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,527 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,552 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,552 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,553 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,602 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,607 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,631 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,632 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,632 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,633 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-11-02 20:22:12,682 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,687 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,711 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,712 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,712 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,761 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,766 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,791 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,791 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,791 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,792 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-11-02 20:22:12,841 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,846 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,870 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,871 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,871 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,920 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:12,925 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:12,950 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:12,950 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:12,950 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:12,951 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-11-02 20:22:13,000 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,005 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,030 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,030 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,030 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,079 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,084 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,109 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,109 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,110 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,110 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-11-02 20:22:13,159 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,164 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,189 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,189 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,190 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,239 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,243 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,268 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,268 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,269 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,269 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-11-02 20:22:13,319 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,323 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,348 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,349 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,349 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,398 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,403 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,427 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,428 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,428 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,429 - INFO - Creating additional config instance for XGBoostModelEval_calibration (XGBoostModelEvalConfig)
# 2025-11-02 20:22:13,478 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,483 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,507 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,508 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,508 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,557 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,562 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,587 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,587 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,587 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,588 - INFO - Creating additional config instance for XGBoostTraining (XGBoostTrainingConfig)
# 2025-11-02 20:22:13,637 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,642 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,667 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,667 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,667 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,716 - INFO - Discovered 36 core config classes
# 2025-11-02 20:22:13,721 - INFO - Discovered 3 core hyperparameter classes
# 2025-11-02 20:22:13,746 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-02 20:22:13,746 - INFO - Built complete config classes: 46 total (36 config + 10 hyperparameter auto-discovered)
# 2025-11-02 20:22:13,747 - INFO - Discovered 46 config classes via step catalog
# 2025-11-02 20:22:13,747 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:22:13,748 - INFO - Loaded 10 configurations from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/config_NA_xgboost_AtoZ.json
# 2025-11-02 20:22:13,748 - INFO - Initialized ExecutionDocumentGenerator with 10 configurations

# %%
execution_doc_fill = exe_doc_generator.fill_execution_document(
    dag=dag, execution_document=test_execution_doc
)
# Out:
# 2025-11-02 20:22:13,752 - INFO - Starting execution document generation for DAG with 10 nodes
# 2025-11-02 20:22:13,752 - INFO - Found exact key match for node 'CradleDataLoading_training'
# 2025-11-02 20:22:13,753 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-02 20:22:13,753 - INFO - Found exact key match for node 'XGBoostTraining'
# 2025-11-02 20:22:13,754 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-02 20:22:13,754 - INFO - Found exact key match for node 'Package'
# 2025-11-02 20:22:13,754 - INFO - Found exact key match for node 'Registration'
# 2025-11-02 20:22:13,755 - INFO - Found exact key match for node 'Payload'
# 2025-11-02 20:22:13,755 - INFO - Found exact key match for node 'CradleDataLoading_calibration'
# 2025-11-02 20:22:13,755 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-02 20:22:13,756 - INFO - Found exact key match for node 'XGBoostModelEval_calibration'
# 2025-11-02 20:22:13,756 - INFO - Found 3 relevant steps: ['CradleDataLoading_training', 'Registration', 'CradleDataLoading_calibration']
# 2025-11-02 20:22:13,757 - INFO - Found exact key match for node 'CradleDataLoading_training'
# 2025-11-02 20:22:13,757 - INFO - Found exact key match for node 'Registration'
# 2025-11-02 20:22:13,757 - INFO - Found exact key match for node 'CradleDataLoading_calibration'
# 2025-11-02 20:22:13,758 - INFO - Processing 2 cradle steps: ['CradleDataLoading_training', 'CradleDataLoading_calibration']
# 2025-11-02 20:22:13,758 - INFO - Found exact key match for node 'CradleDataLoading_training'
# 2025-11-02 20:22:13,758 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-02 20:22:13,759 - INFO - Found exact key match for node 'XGBoostTraining'
# 2025-11-02 20:22:13,759 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-02 20:22:13,760 - INFO - Found exact key match for node 'Package'
# 2025-11-02 20:22:13,760 - INFO - Found exact key match for node 'Registration'
# 2025-11-02 20:22:13,760 - INFO - Found exact key match for node 'Payload'
# 2025-11-02 20:22:13,761 - INFO - Found exact key match for node 'CradleDataLoading_calibration'
# 2025-11-02 20:22:13,762 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-02 20:22:13,762 - INFO - Found exact key match for node 'XGBoostModelEval_calibration'
# 2025-11-02 20:22:13,762 - INFO - Found exact key match for node 'CradleDataLoading_training'
# 2025-11-02 20:22:13,763 - INFO - Extracting Cradle execution document config for step: CradleDataLoading_training
# 2025-11-02 20:22:13,766 - INFO - Successfully extracted Cradle config for step: CradleDataLoading_training
# 2025-11-02 20:22:13,766 - INFO - Updated execution config for Cradle step: CradleDataLoading-Training
# 2025-11-02 20:22:13,766 - INFO - Found exact key match for node 'CradleDataLoading_calibration'
# 2025-11-02 20:22:13,767 - INFO - Extracting Cradle execution document config for step: CradleDataLoading_calibration
# 2025-11-02 20:22:13,769 - INFO - Successfully extracted Cradle config for step: CradleDataLoading_calibration
# 2025-11-02 20:22:13,769 - INFO - Updated execution config for Cradle step: CradleDataLoading-Calibration
# 2025-11-02 20:22:13,770 - INFO - Found exact key match for node 'CradleDataLoading_training'
# 2025-11-02 20:22:13,770 - INFO - Found exact key match for node 'Registration'
# 2025-11-02 20:22:13,771 - INFO - Found exact key match for node 'CradleDataLoading_calibration'
# 2025-11-02 20:22:13,771 - INFO - Processing 1 registration steps: ['Registration']
# 2025-11-02 20:22:13,771 - INFO - Found registration configuration: RegistrationConfig
# 2025-11-02 20:22:13,771 - INFO - Found exact key match for node 'CradleDataLoading_training'
# 2025-11-02 20:22:13,772 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-02 20:22:13,772 - INFO - Found exact key match for node 'XGBoostTraining'
# 2025-11-02 20:22:13,772 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-02 20:22:13,773 - INFO - Found exact key match for node 'Package'
# 2025-11-02 20:22:13,773 - INFO - Found exact key match for node 'Registration'
# 2025-11-02 20:22:13,773 - INFO - Found registration step by config type: Registration
# 2025-11-02 20:22:13,774 - INFO - Found exact key match for node 'Payload'
# 2025-11-02 20:22:13,774 - INFO - Found exact key match for node 'CradleDataLoading_calibration'
# 2025-11-02 20:22:13,774 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-02 20:22:13,775 - INFO - Found exact key match for node 'XGBoostModelEval_calibration'
# 2025-11-02 20:22:13,776 - INFO - Ignoring unnecessary Python version: py3.
# 2025-11-02 20:22:13,795 - INFO - Ignoring unnecessary instance type: ml.m5.large.
# 2025-11-02 20:22:13,795 - INFO - Retrieved image URI: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1
# 2025-11-02 20:22:13,796 - INFO - Created execution config for registration step: Registration-NA
# 2025-11-02 20:22:13,796 - INFO - Successfully generated execution document

# %%
# execution_doc_fill = pipeline_builder.fill_execution_document(test_execution_doc)

# %%
# Fill in the execution document using the stored requests
# execution_doc_fill_2 = xgboost_train_eval_pipeline_template_builder.fill_execution_document(test_execution_doc)

# %%
print(json.dumps(execution_doc_fill, indent=2))
# Out:
# {
#   "PIPELINE_STEP_CONFIGS": {
#     "CradleDataLoading-Training": {
#       "STEP_CONFIG": {
#         "dataSources": {
#           "dataSources": [
#             {
#               "dataSourceName": "RAW_MDS_NA",
#               "dataSourceType": "MDS",
#               "mdsDataSourceProperties": {
#                 "serviceName": "AtoZ",
#                 "orgId": "0",
#                 "region": "NA",
#                 "useHourlyEdxDataSet": false,
#                 "outputSchema": [
#                   {
#                     "fieldName": "objectId",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "transactionDate",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.dnr_by_customer_marketplace.n_dnr_amount_si_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.dnr_by_customer_marketplace.n_dnr_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.dnr_by_customer_marketplace.n_dnr_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.dnr_by_customer_marketplace.n_dnr_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_diff_refunds_si_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_notr_refunds_si_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_refunds_si_by_customer_marketplace.n_mfn_refund_amount_si_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.order_to_execution_time_from_eventvariables.n_order_to_execution",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_delivered",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_available_for_pickup",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_partial_delivered",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_undeliverable",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_returning",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_returned",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "COMP_DAYOB",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimAmount_value",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimantInfo_allClaimCount365day",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimantInfo_lifetimeClaimCount",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimantInfo_pendingClaimCount",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "PAYMETH",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claim_reason",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimantInfo_status",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "shipments_status",
#                     "fieldType": "STRING"
#                   }
#                 ]
#               }
#             },
#             {
#               "dataSourceName": "TAGS",
#               "dataSourceType": "EDX",
#               "edxDataSourceProperties": {
#                 "edxArn": "arn:amazon:edx:iad::manifest/trms-abuse-analytics/qingyuye-notr-exp/atoz-tag/[\"24292902\",2025-01-01T00:00:00Z,2025-04-17T00:00:00Z,\"NA\"]",
#                 "schemaOverrides": [
#                   {
#                     "fieldName": "order_id",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "marketplace_id",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "tag_date",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "is_abuse",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "abuse_type",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "concession_type",
#                     "fieldType": "STRING"
#                   }
#                 ]
#               }
#             }
#           ],
#           "startDate": "2025-01-01T00:00:00",
#           "endDate": "2025-04-17T00:00:00"
#         },
#         "transformSpecification": {
#           "transformSQL": "\nSELECT\n    Abuse__DOT__abuse_fap_action_by_customer_inline_transform_na__DOT__n_claims_solicit_count_last_365_days,\n    Abuse__DOT__abuse_fap_action_by_customer_inline_transform_na__DOT__n_claims_warn_count_last_365_days,\n    Abuse__DOT__abuse_fap_action_by_customer_inline_transform_na__DOT__n_concession_solicit_count_last_365_days,\n    Abuse__DOT__abuse_fap_action_by_customer_inline_transform_na__DOT__n_concession_warn_count_last_365_days,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_max_buyer_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_max_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_max_seller_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_message_count_with_diff_topic_si,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_message_count_with_notr_topic_si,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_message_count_with_return_keywords_si,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_buyer_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_buyer_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_seller_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_seller_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_total_buyer_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_total_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_total_seller_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_total_topic_count,\n    Abuse__DOT__completed_afn_orders_by_customer_marketplace__DOT__n_afn_order_count_last_365_days,\n    Abuse__DOT__completed_afn_orders_by_customer_marketplace__DOT__n_afn_unit_amount_last_365_days,\n    Abuse__DOT__completed_afn_orders_by_customer_marketplace__DOT__n_afn_unit_count_last_365_days,\n    Abuse__DOT__completed_mfn_orders_by_customer_marketplace__DOT__n_mfn_order_count_last_365_days,\n    Abuse__DOT__completed_mfn_orders_by_customer_marketplace__DOT__n_mfn_unit_amount_last_365_days,\n    Abuse__DOT__completed_mfn_orders_by_customer_marketplace__DOT__n_mfn_unit_count_last_365_days,\n    Abuse__DOT__dnr_by_customer_marketplace__DOT__n_dnr_amount_si_last_365_days,\n    Abuse__DOT__dnr_by_customer_marketplace__DOT__n_dnr_order_count_last_365_days,\n    Abuse__DOT__dnr_by_customer_marketplace__DOT__n_dnr_unit_amount_last_365_days,\n    Abuse__DOT__dnr_by_customer_marketplace__DOT__n_dnr_unit_count_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_claims_amount_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_claims_count_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_diff_claims_amount_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_diff_claims_count_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_notr_claims_amount_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_notr_claims_count_last_365_days,\n    Abuse__DOT__mfn_categorized_refunds_by_customer_marketplace__DOT__n_mfn_diff_refunds_order_count_last_365_days,\n    Abuse__DOT__mfn_categorized_refunds_by_customer_marketplace__DOT__n_mfn_diff_refunds_unit_amount_last_365_days,\n    Abuse__DOT__mfn_categorized_refunds_by_customer_marketp ...
#           "jobSplitOptions": {
#             "splitJob": false,
#             "daysPerSplit": 7,
#             "mergeSql": "\nselect * from INPUT\n"
#           }
#         },
#         "outputSpecification": {
#           "outputSchema": [
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days",
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days",
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days",
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count",
#             "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days",
#             "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days",
#             "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days",
#             "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_order_count_last_365_days",
#             "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_amount_last_365_days",
#             "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_count_last_365_days",
#             "Abuse.dnr_by_customer_marketplace.n_dnr_amount_si_last_365_days",
#             "Abuse.dnr_by_customer_marketplace.n_dnr_order_count_last_365_days",
#             "Abuse.dnr_by_customer_marketplace.n_dnr_unit_amount_last_365_days",
#             "Abuse.dnr_by_customer_marketplace.n_dnr_unit_count_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_amount_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_count_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_amount_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_count_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_amount_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_order_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_amount_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_order_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_amount_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_diff_refunds_si_365_days",
#             "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_notr_refunds_si_365_days",
#             "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_order_count_last_365_days",
#             "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_amount_last_365_days",
#             "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_count_last_365_days",
#             "Abuse.mfn_refunds_si_by_customer_marketplace.n_mfn_refund_amount_si_last_365_days",
#             "Abuse.order_to_execution_time_from_eventvariables.n_order_to_execution",
#             "Abuse.shiptrack_flag_by_order.n_any_available_for_pickup",
#             "Abuse.shiptrack_flag_by_order.n_any_delivered",
#             "Abuse.shiptrack_flag_by_order.n_any_partial_delivered",
#             "Abuse.shiptrack_flag_by_order.n_any_returned",
#             "Abuse.shiptrack_flag_by_order.n_any_returning",
#             "Abuse.shiptrack_flag_by_order.n_any_undeliverable",
#             "COMP_DAYOB",
#             "PAYMETH",
#             "abuse_type",
#             "claimAmount_value",
#             "claim_reason",
#             "claimantInfo_allClaimCount365day",
#             "claimantInfo_lifetimeClaimCount",
#             "claimantInfo_pendingClaimCount",
#             "claimantInfo_status",
#             "concession_type",
#             "is_abuse",
#             "marketplace_id",
#             "objectId",
#             "order_id",
#             "shipments_status",
#             "tag_date",
#             "transactionDate"
#           ],
#           "outputPath": "s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/MODS/lukexie-AtoZ-xgboost-NA_1.3.1/data-load/training",
#           "outputFormat": "PARQUET",
#           "outputSaveMode": "ERRORIFEXISTS",
#           "outputFileCount": 0,
#           "keepDotInOutputSchema": false,
#           "includeHeaderInS3Output": true
#         },
#         "cradleJobSpecification": {
#           "clusterType": "MEDIUM",
#           "cradleAccount": "BRP-ML-Abuse",
#           "extraSparkJobArguments": "",
#           "jobRetryCount": 1
#         }
#       },
#       "STEP_TYPE": [
#         "WORKFLOW_INPUT",
#         "CradleDataLoadingStep"
#       ]
#     },
#     "CradleDataLoading-Calibration": {
#       "STEP_CONFIG": {
#         "dataSources": {
#           "dataSources": [
#             {
#               "dataSourceName": "RAW_MDS_NA",
#               "dataSourceType": "MDS",
#               "mdsDataSourceProperties": {
#                 "serviceName": "AtoZ",
#                 "orgId": "0",
#                 "region": "NA",
#                 "useHourlyEdxDataSet": false,
#                 "outputSchema": [
#                   {
#                     "fieldName": "objectId",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "transactionDate",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.dnr_by_customer_marketplace.n_dnr_amount_si_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.dnr_by_customer_marketplace.n_dnr_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.dnr_by_customer_marketplace.n_dnr_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.dnr_by_customer_marketplace.n_dnr_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_diff_refunds_si_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_notr_refunds_si_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_order_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_amount_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_count_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.mfn_refunds_si_by_customer_marketplace.n_mfn_refund_amount_si_last_365_days",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.order_to_execution_time_from_eventvariables.n_order_to_execution",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_delivered",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_available_for_pickup",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_partial_delivered",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_undeliverable",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_returning",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "Abuse.shiptrack_flag_by_order.n_any_returned",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "COMP_DAYOB",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimAmount_value",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimantInfo_allClaimCount365day",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimantInfo_lifetimeClaimCount",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimantInfo_pendingClaimCount",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "PAYMETH",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claim_reason",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "claimantInfo_status",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "shipments_status",
#                     "fieldType": "STRING"
#                   }
#                 ]
#               }
#             },
#             {
#               "dataSourceName": "TAGS",
#               "dataSourceType": "EDX",
#               "edxDataSourceProperties": {
#                 "edxArn": "arn:amazon:edx:iad::manifest/trms-abuse-analytics/qingyuye-notr-exp/atoz-tag/[\"24292902\",2025-04-17T00:00:00Z,2025-04-28T00:00:00Z,\"NA\"]",
#                 "schemaOverrides": [
#                   {
#                     "fieldName": "order_id",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "marketplace_id",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "tag_date",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "is_abuse",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "abuse_type",
#                     "fieldType": "STRING"
#                   },
#                   {
#                     "fieldName": "concession_type",
#                     "fieldType": "STRING"
#                   }
#                 ]
#               }
#             }
#           ],
#           "startDate": "2025-04-17T00:00:00",
#           "endDate": "2025-04-28T00:00:00"
#         },
#         "transformSpecification": {
#           "transformSQL": "\nSELECT\n    Abuse__DOT__abuse_fap_action_by_customer_inline_transform_na__DOT__n_claims_solicit_count_last_365_days,\n    Abuse__DOT__abuse_fap_action_by_customer_inline_transform_na__DOT__n_claims_warn_count_last_365_days,\n    Abuse__DOT__abuse_fap_action_by_customer_inline_transform_na__DOT__n_concession_solicit_count_last_365_days,\n    Abuse__DOT__abuse_fap_action_by_customer_inline_transform_na__DOT__n_concession_warn_count_last_365_days,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_max_buyer_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_max_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_max_seller_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_message_count_with_diff_topic_si,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_message_count_with_notr_topic_si,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_message_count_with_return_keywords_si,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_buyer_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_buyer_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_seller_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_min_seller_order_message_time_gap,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_total_buyer_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_total_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_total_seller_message_count,\n    Abuse__DOT__bsm_stats_for_evaluated_mfn_concessions_by_customer_na__DOT__n_total_topic_count,\n    Abuse__DOT__completed_afn_orders_by_customer_marketplace__DOT__n_afn_order_count_last_365_days,\n    Abuse__DOT__completed_afn_orders_by_customer_marketplace__DOT__n_afn_unit_amount_last_365_days,\n    Abuse__DOT__completed_afn_orders_by_customer_marketplace__DOT__n_afn_unit_count_last_365_days,\n    Abuse__DOT__completed_mfn_orders_by_customer_marketplace__DOT__n_mfn_order_count_last_365_days,\n    Abuse__DOT__completed_mfn_orders_by_customer_marketplace__DOT__n_mfn_unit_amount_last_365_days,\n    Abuse__DOT__completed_mfn_orders_by_customer_marketplace__DOT__n_mfn_unit_count_last_365_days,\n    Abuse__DOT__dnr_by_customer_marketplace__DOT__n_dnr_amount_si_last_365_days,\n    Abuse__DOT__dnr_by_customer_marketplace__DOT__n_dnr_order_count_last_365_days,\n    Abuse__DOT__dnr_by_customer_marketplace__DOT__n_dnr_unit_amount_last_365_days,\n    Abuse__DOT__dnr_by_customer_marketplace__DOT__n_dnr_unit_count_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_claims_amount_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_claims_count_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_diff_claims_amount_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_diff_claims_count_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_notr_claims_amount_last_365_days,\n    Abuse__DOT__mfn_a2z_claims_by_customer_na__DOT__n_mfn_notr_claims_count_last_365_days,\n    Abuse__DOT__mfn_categorized_refunds_by_customer_marketplace__DOT__n_mfn_diff_refunds_order_count_last_365_days,\n    Abuse__DOT__mfn_categorized_refunds_by_customer_marketplace__DOT__n_mfn_diff_refunds_unit_amount_last_365_days,\n    Abuse__DOT__mfn_categorized_refunds_by_customer_marketp ...
#           "jobSplitOptions": {
#             "splitJob": false,
#             "daysPerSplit": 7,
#             "mergeSql": "\nselect * from INPUT\n"
#           }
#         },
#         "outputSpecification": {
#           "outputSchema": [
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days",
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days",
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days",
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count",
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count",
#             "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days",
#             "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days",
#             "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days",
#             "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_order_count_last_365_days",
#             "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_amount_last_365_days",
#             "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_count_last_365_days",
#             "Abuse.dnr_by_customer_marketplace.n_dnr_amount_si_last_365_days",
#             "Abuse.dnr_by_customer_marketplace.n_dnr_order_count_last_365_days",
#             "Abuse.dnr_by_customer_marketplace.n_dnr_unit_amount_last_365_days",
#             "Abuse.dnr_by_customer_marketplace.n_dnr_unit_count_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_amount_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_count_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_amount_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_count_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_amount_last_365_days",
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_order_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_amount_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_order_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_amount_last_365_days",
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_count_last_365_days",
#             "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_diff_refunds_si_365_days",
#             "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_notr_refunds_si_365_days",
#             "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_order_count_last_365_days",
#             "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_amount_last_365_days",
#             "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_count_last_365_days",
#             "Abuse.mfn_refunds_si_by_customer_marketplace.n_mfn_refund_amount_si_last_365_days",
#             "Abuse.order_to_execution_time_from_eventvariables.n_order_to_execution",
#             "Abuse.shiptrack_flag_by_order.n_any_available_for_pickup",
#             "Abuse.shiptrack_flag_by_order.n_any_delivered",
#             "Abuse.shiptrack_flag_by_order.n_any_partial_delivered",
#             "Abuse.shiptrack_flag_by_order.n_any_returned",
#             "Abuse.shiptrack_flag_by_order.n_any_returning",
#             "Abuse.shiptrack_flag_by_order.n_any_undeliverable",
#             "COMP_DAYOB",
#             "PAYMETH",
#             "abuse_type",
#             "claimAmount_value",
#             "claim_reason",
#             "claimantInfo_allClaimCount365day",
#             "claimantInfo_lifetimeClaimCount",
#             "claimantInfo_pendingClaimCount",
#             "claimantInfo_status",
#             "concession_type",
#             "is_abuse",
#             "marketplace_id",
#             "objectId",
#             "order_id",
#             "shipments_status",
#             "tag_date",
#             "transactionDate"
#           ],
#           "outputPath": "s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/MODS/lukexie-AtoZ-xgboost-NA_1.3.1/data-load/calibration",
#           "outputFormat": "PARQUET",
#           "outputSaveMode": "ERRORIFEXISTS",
#           "outputFileCount": 0,
#           "keepDotInOutputSchema": false,
#           "includeHeaderInS3Output": true
#         },
#         "cradleJobSpecification": {
#           "clusterType": "MEDIUM",
#           "cradleAccount": "BRP-ML-Abuse",
#           "extraSparkJobArguments": "",
#           "jobRetryCount": 1
#         }
#       },
#       "STEP_TYPE": [
#         "WORKFLOW_INPUT",
#         "CradleDataLoadingStep"
#       ]
#     },
#     "XGBoostTraining": {
#       "STEP_CONFIG": {},
#       "STEP_TYPE": "TRAINING_STEP"
#     },
#     "Registration-NA": {
#       "STEP_CONFIG": {
#         "source_model_inference_image_arn": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1",
#         "model_domain": "AtoZ",
#         "model_objective": "AtoZ_Claims_SM_Model_NA",
#         "source_model_inference_content_types": [
#           "text/csv"
#         ],
#         "source_model_inference_response_types": [
#           "application/json"
#         ],
#         "source_model_inference_input_variable_list": [
#           [
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_order_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_amount_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.dnr_by_customer_marketplace.n_dnr_amount_si_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.dnr_by_customer_marketplace.n_dnr_order_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.dnr_by_customer_marketplace.n_dnr_unit_amount_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.dnr_by_customer_marketplace.n_dnr_unit_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_amount_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_amount_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_amount_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_order_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_amount_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_diff_refunds_unit_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_order_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_amount_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_categorized_refunds_by_customer_marketplace.n_mfn_notr_refunds_unit_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_diff_refunds_si_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_categorized_refunds_si_by_customer_marketplace.n_mfn_notr_refunds_si_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_order_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_amount_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_refunds_by_customer_marketplace.n_mfn_refund_unit_count_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.mfn_refunds_si_by_customer_marketplace.n_mfn_refund_amount_si_last_365_days",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.order_to_execution_time_from_eventvariables.n_order_to_execution",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.shiptrack_flag_by_order.n_any_delivered",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.shiptrack_flag_by_order.n_any_available_for_pickup",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.shiptrack_flag_by_order.n_any_partial_delivered",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.shiptrack_flag_by_order.n_any_undeliverable",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.shiptrack_flag_by_order.n_any_returning",
#             "NUMERIC"
#           ],
#           [
#             "Abuse.shiptrack_flag_by_order.n_any_returned",
#             "NUMERIC"
#           ],
#           [
#             "COMP_DAYOB",
#             "NUMERIC"
#           ],
#           [
#             "claimAmount_value",
#             "NUMERIC"
#           ],
#           [
#             "claimantInfo_allClaimCount365day",
#             "NUMERIC"
#           ],
#           [
#             "claimantInfo_lifetimeClaimCount",
#             "NUMERIC"
#           ],
#           [
#             "claimantInfo_pendingClaimCount",
#             "NUMERIC"
#           ],
#           [
#             "PAYMETH",
#             "TEXT"
#           ],
#           [
#             "claim_reason",
#             "TEXT"
#           ],
#           [
#             "claimantInfo_status",
#             "TEXT"
#           ],
#           [
#             "shipments_status",
#             "TEXT"
#           ]
#         ],
#         "source_model_inference_output_variable_list": {
#           "calibrated-score": "NUMERIC",
#           "custom-output-label": "TEXT",
#           "legacy-score": "NUMERIC",
#           "score-percentile": "NUMERIC"
#         },
#         "source_model_region": "us-east-1",
#         "model_owner": "amzn1.abacus.team.djmdvixm5abr3p75c5ca",
#         "model_registration_region": "NA",
#         "source_model_environment_variable_map": {
#           "SAGEMAKER_CONTAINER_LOG_LEVEL": "20",
#           "SAGEMAKER_PROGRAM": "xgboost_inference.py",
#           "SAGEMAKER_REGION": "us-east-1",
#           "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#         },
#         "load_testing_info_map": {
#           "sample_payload_s3_bucket": "sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um",
#           "expected_tps": 10,
#           "max_latency_in_millisecond": 800,
#           "max_acceptable_error_rate": 0.2,
#           "instance_type_list": [
#             "ml.m5.4xlarge"
#           ]
#         }
#       },
#       "STEP_TYPE": [
#         "PROCESSING_STEP",
#         "MimsModelRegistrationProcessingStep"
#       ]
#     }
#   },
#   "PIPELINE_ADDITIONAL_PARAMS": {}
# }

# %%
test_execution_doc = execution_doc_fill.copy()

# %% [markdown]
# ### Save Execution Doc locally

# %%
PIPELINE_NAME = first_config.pipeline_name

# %%
PIPELINE_VERSION = first_config.pipeline_version

# %%
exe_doc_json_filename = f"execute_doc.json"
exe_doc_file_path = config_dir / exe_doc_json_filename
exe_doc_file_path
# Out:
# PosixPath('/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/mods_pipeline_adapter/pipeline_config/config_NA_xgboost_AtoZ_v2/execute_doc_lukexie-AtoZ-xgboost-NA_1.3.1.json')

# %%
with open(exe_doc_file_path, "w") as f:
    json.dump(test_execution_doc, f, indent=2)

# %% [markdown]
# ## Execute Pipeline

# %% [markdown]
# ### Start Execution

# %%
from mods_workflow_helper.sagemaker_pipeline_helper import SagemakerPipelineHelper

# %%
security_config

# %%
template_pipeline

# %%
SagemakerPipelineHelper.start_pipeline_execution(
    pipeline=template_pipeline,
    secure_config=security_config,
    sagemaker_session=pipeline_session,
    preparation_space_local_root="/tmp",
    pipeline_execution_document=test_execution_doc,
)
# Out:
# 2025-11-02 20:22:14,256 - INFO - Apply execution document provided config {'dataSources': {'dataSources': [{'dataSourceName': 'RAW_MDS_NA', 'dataSourceType': 'MDS', 'mdsDataSourceProperties': {'serviceName': 'AtoZ', 'orgId': '0', 'region': 'NA', 'useHourlyEdxDataSet': False, 'outputSchema': [{'fieldName': 'objectId', 'fieldType': 'STRING'}, {'fieldName': 'transactionDate', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_order_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_amount_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.dnr_by_customer_marketplace.n_dnr_amount_si_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.dnr_by_customer_marketplace.n_dnr_order_count_last_365_days', 'fieldType': 'STRING'} ...
# 2025-11-02 20:22:14,300 - INFO - Apply execution document provided config {'dataSources': {'dataSources': [{'dataSourceName': 'RAW_MDS_NA', 'dataSourceType': 'MDS', 'mdsDataSourceProperties': {'serviceName': 'AtoZ', 'orgId': '0', 'region': 'NA', 'useHourlyEdxDataSet': False, 'outputSchema': [{'fieldName': 'objectId', 'fieldType': 'STRING'}, {'fieldName': 'transactionDate', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_order_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_amount_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_count_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.dnr_by_customer_marketplace.n_dnr_amount_si_last_365_days', 'fieldType': 'STRING'}, {'fieldName': 'Abuse.dnr_by_customer_marketplace.n_dnr_order_count_last_365_days', 'fieldType': 'STRING'} ...
# 2025-11-02 20:22:14,300 - INFO - Apply execution document provided config {} for step XGBoostTraining.
# 2025-11-02 20:22:14,344 - INFO - Apply execution document provided config {'source_model_inference_image_arn': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1', 'model_domain': 'AtoZ', 'model_objective': 'AtoZ_Claims_SM_Model_NA', 'source_model_inference_content_types': ['text/csv'], 'source_model_inference_response_types': ['application/json'], 'source_model_inference_input_variable_list': [['Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_solicit_count_last_365_days', 'NUMERIC'], ['Abuse.abuse_fap_action_by_customer_inline_transform_na.n_claims_warn_count_last_365_days', 'NUMERIC'], ['Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_solicit_count_last_365_days', 'NUMERIC'], ['Abuse.abuse_fap_action_by_customer_inline_transform_na.n_concession_warn_count_last_365_days', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_buyer_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_max_seller_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_diff_topic_si', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_notr_topic_si', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_message_count_with_return_keywords_si', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_buyer_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_min_seller_order_message_time_gap', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_buyer_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_seller_message_count', 'NUMERIC'], ['Abuse.bsm_stats_for_evaluated_mfn_concessions_by_customer_na.n_total_topic_count', 'NUMERIC'], ['Abuse.completed_afn_orders_by_customer_marketplace.n_afn_order_count_last_365_days', 'NUMERIC'], ['Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_amount_last_365_days', 'NUMERIC'], ['Abuse.completed_afn_orders_by_customer_marketplace.n_afn_unit_count_last_365_days', 'NUMERIC'], ['Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_order_count_last_365_days', 'NUMERIC'], ['Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_amount_last_365_days', 'NUMERIC'], ['Abuse.completed_mfn_orders_by_customer_marketplace.n_mfn_unit_count_last_365_days', 'NUMERIC'], ['Abuse.dnr_by_customer_marketplace.n_dnr_amount_si_last_365_days', 'NUMERIC'], ['Abuse.dnr_by_customer_marketplace.n_dnr_order_count_last_365_days', 'NUMERIC'], ['Abuse.dnr_by_customer_marketplace.n_dnr_unit_amount_last_365_days', 'NUMERIC'], ['Abuse.dnr_by_customer_marketplace.n_dnr_unit_count_last_365_days', 'NUMERIC'], ['Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_amount_last_365_days', 'NUMERIC'], ['Abuse.mfn_a2z_claims_by_customer_na.n_mfn_claims_count_last_365_days', 'NUMERIC'], ['Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_amount_last_365_days', 'NUMERIC'], ['Abuse.mfn_a2z_claims_by_customer_na.n_mfn_diff_claims_count_last_365_days', 'NUMERIC'], ['Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_amount_last_365_days', 'NUMERIC'], ['Abuse.mfn_a2z_claims_by_customer_na.n_mfn_notr_claims_count_last_365_days ...
# 2025-11-02 20:22:15,130 - INFO - Final Pipeline execution parameters applied: {'KMS_ENCRYPTION_KEY_PARAM': 'arn:aws:kms:us-east-1:601857636239:key/5e32d636-8848-43ba-bd1f-f1a1c9a06982', 'VPC_SUBNET': 'subnet-0e484e4a41446ca78', 'SECURITY_GROUP_ID': 'sg-0f97baad9c44ab543', 'EXECUTION_S3_PREFIX': 's3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-AtoZ-xgboost-NA-1-3-1-pipeline-2025-11-02-20-22-13'}
# 2025-11-02 20:22:15,526 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:15,527 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:15,586 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:15,632 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:15,799 - WARNING - Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.ResourceConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.SecurityGroupIds
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.Environment
# 2025-11-02 20:22:17,097 - INFO - Uploaded None to s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-AtoZ-xgboost-NA-1-3-1-pipeline/code/e6dd1b40ca4b4ef235b0940d813485204c87df865b03f2333573a6ebfe55b4b0/sourcedir.tar.gz
# 2025-11-02 20:22:17,137 - INFO - runproc.sh uploaded to s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-AtoZ-xgboost-NA-1-3-1-pipeline/code/2928aabd7485c9308faf4c80d554ec758f920d573b466e45a4f26d294f827af0/runproc.sh
# 2025-11-02 20:22:18,122 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:18,178 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:18,229 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:19,826 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:19,827 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:19,829 - INFO - Add currentOwnerAlias tag to the request for operation: CreatePipeline.
# 2025-11-02 20:22:19,830 - INFO - A creation operation CreatePipeline is detected. Apply owner tag to the request.
# 2025-11-02 20:22:20,295 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:20,296 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:20,369 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:20,408 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:20,523 - WARNING - Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.ResourceConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.SecurityGroupIds
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.Environment
# 2025-11-02 20:22:21,840 - INFO - Uploaded None to s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-AtoZ-xgboost-NA-1-3-1-pipeline/code/e6dd1b40ca4b4ef235b0940d813485204c87df865b03f2333573a6ebfe55b4b0/sourcedir.tar.gz
# 2025-11-02 20:22:21,884 - INFO - runproc.sh uploaded to s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-AtoZ-xgboost-NA-1-3-1-pipeline/code/2928aabd7485c9308faf4c80d554ec758f920d573b466e45a4f26d294f827af0/runproc.sh
# 2025-11-02 20:22:22,873 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:22,956 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:23,004 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:23,067 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:23,068 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-11-02 20:22:23,070 - WARNING - A modification operation UpdatePipeline is detected. Please make sure the resource to be modified is owned or initially created by you; Otherwise your request will be denied by target service due to lack of permission.
# _PipelineExecution(arn='arn:aws:sagemaker:us-east-1:601857636239:pipeline/lukexie-atoz-xgboost-na-1-3-1-pipeline/execution/zcu1n8wihz3s', sagemaker_session=<sagemaker.workflow.pipeline_context.PipelineSession object at 0x7fc22052a890>)

# %% [markdown]
# ### Handle the CTI of MMS

# %% [markdown]
# ```python
# from secure_ai_sandbox_python_lib.session import Session
#
# ############ Initialize sandbox_session
# sandbox_session = Session(session_folder='/tmp/temp_folder', retail_region='NA')
#
# ############# Create the MIMS resource
# mims = sandbox_session.resource('MIMSModelRegistrar')
#
# model_domain='AtoZ' # The registered Domain
# model_objective='ContactRiskPDAModelNA'
# cti_category='IT Dev'
# cti_type='Abuse Prevention'
# cti_item='APSAnalytics'
#
# response = mims.update_objective_cti(model_domain=model_domain,
#                                      model_objective=model_objective,
#                                      cti_category=cti_category,
#                                      cti_type=cti_type,
#                                      cti_item=cti_item)
# print(response)
# ```
