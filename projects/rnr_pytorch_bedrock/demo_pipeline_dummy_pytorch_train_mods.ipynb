# %% [markdown]
# # Cursus: Automatic SageMaker (MODS) Pipeline Compiler
#
# The main contribution of this work is **Cursus**, a **compiler** that automatically generate **[MODS (Model Training Workflow Operation and Development System) Pipeline](https://w.amazon.com/bin/view/CMLS/Overview/MODS/)** base on two set of user inputs
# * The **Pipeline DAG (Directed Acylic Graph)**, which describe pipeline as a graph
# * The **Unified Config JSON**, which provides a central hub to extract all user inputs and their associated step information
#     * Run [demo_config](./demo_config.ipynb) first to generate the Unified Config JSON
#     * The config json will be saved in `./pipeling_config/xxx/` folder
#
# ![mods_pipeline_train_eval_calib](./demo/mods_pipeline_train_eval_calib.png)

# %%
#!pip uninstall -y rpds-py
#!pip install rpds-py --force-reinstall

# %%
#!pip install amzn-secure-ai-sandbox-workflow-python-sdk --ignore-installed

# %%
#!pip install amzn-mods-workflow-helper amzn-mods-python-sdk --upgrade

# %%
import os
import json
import pandas as pd
import pickle
import sys
import subprocess
from datetime import datetime

from pathlib import Path

# %%
from pydantic import BaseModel, Field, model_validator, field_validator
from typing import List, Optional, Dict, Any, Type, Union, Tuple

# %%
from collections import defaultdict, deque

# %%
import logging

# %%
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Environment Setup

# %%
from sagemaker import Session
from secure_ai_sandbox_python_lib.session import Session as SaisSession
# Out:
# 2025-12-02 07:09:25,760 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# 2025-12-02 07:09:26,153 - INFO - CA certs are provided via the AmazonCACerts installation at /home/ec2-user/.local/lib/python3.10/site-packages/amazoncerts

# %%
from mods_workflow_helper.utils.secure_session import create_secure_session_config
from mods_workflow_helper.sagemaker_pipeline_helper import SecurityConfig

from sagemaker.workflow.pipeline_context import PipelineSession

# %%
# Initialize session with team bucket
sais_session = SaisSession(".")

security_config = SecurityConfig(
    kms_key=sais_session.get_team_owned_bucket_kms_key(),
    security_group=sais_session.sandbox_vpc_security_group(),
    vpc_subnets=sais_session.sandbox_vpc_subnets(),
)
# Out:
# 2025-12-02 07:09:26,751 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# 2025-12-02 07:09:27,574 - INFO - successfully patched module botocore

# %%
sagemaker_config = create_secure_session_config(
    role_arn=PipelineSession().get_caller_identity_arn(),
    # If you are uploading to andes, use cradle_read_s3_bucket_name() and get_cradle_read_bucket_kms_key() respecitely
    bucket_name=sais_session.team_owned_s3_bucket_name(),
    kms_key=sais_session.get_team_owned_bucket_kms_key(),
    vpc_subnet_ids=sais_session.sandbox_vpc_subnets(),
    vpc_security_groups=[sais_session.sandbox_vpc_security_group()],
)
# Out:
# 2025-12-02 07:09:27,595 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# 2025-12-02 07:09:27,975 - INFO - There is no MODS workflow execution id provided, this is probably because you are running your pipeline outside of MODS.

# %%
pipeline_session = PipelineSession(
    default_bucket=sais_session.team_owned_s3_bucket_name(),
    sagemaker_config=sagemaker_config,
)  # IMPORTANT now the session uses the generated sagemaker_config
# Out:
# 2025-12-02 07:09:27,996 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %%
pipeline_session.config = sagemaker_config

# %%
bucket = sais_session.team_owned_s3_bucket_name()
bucket
# Out:
# 'sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um'

# %%
role = PipelineSession().get_caller_identity_arn()
role
# Out:
# 2025-12-02 07:09:28,545 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# 'arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1'

# %%
from pathlib import Path
import sys

# Get parent directory of current notebook
project_root = str(Path().absolute().parent)
print(f"project root {project_root}")
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"add project root {project_root} into system")
# Out:
# project root /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template
# add project root /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template into system

# %% [markdown]
# ## Basic Information

# %%
region_list = ["NA", "EU", "FE"]

# %%
region_selection = 0

# %%
region = region_list[region_selection]
region
# Out:
# 'NA'

# %%
MODEL_CLASS = "pytorch"

# %%
service_name = "BuyerAbuseRnR"

# %% [markdown]
# #### Config and Hyperparameter Information

# %%
current_dir = Path.cwd()
config_dir = Path(current_dir) / "pipeline_config"
print(config_dir)
# Out:
# /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config

# %%
# hyparam_filename = f'hyperparameters_{region}_{MODEL_CLASS}.json' #'hyperparameters.json'

# %%
pipeline_config_name = f"config.json"  # f'config_{region}.json'
pipeline_config_name
# Out:
# 'config.json'

# %%
config_path = config_dir / pipeline_config_name

# %%
config_path
# Out:
# PosixPath('/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json')

# %% [markdown]
# ## Pipeline Imports

# %%
from enum import Enum
from pydantic import BaseModel

# %% [markdown]
# ## [Optional]: Test Config Load Functionality
#
# Please skip this section if you are not concern about the config information loaded

# %% [markdown]
# ### Hyperparameters

# %%
# from cursus.steps.hyperparams.hyperparameters_xgboost import XGBoostModelHyperparameters

# %%
# hyparam_path = config_dir / hyparam_filename
# with open(hyparam_path, 'r') as file:
#    hyperparam_dict = json.load(file)

# %%
# hyperparams = XGBoostModelHyperparameters(**hyperparam_dict)

# %%
# hyperparams.num_classes

# %%
# hyperparams.is_binary

# %% [markdown]
# ### Import Configs

# %%
from cursus.core.base.config_base import BasePipelineConfig

# %%
# from cursus.steps.configs.config_cradle_data_loading_step import (CradleDataLoadingConfig,
#                                                    MdsDataSourceConfig,
#                                                    EdxDataSourceConfig,
#                                                    DataSourceConfig,
#                                                    DataSourcesSpecificationConfig,
#                                                    JobSplitOptionsConfig,
#                                                    TransformSpecificationConfig,
#                                                    OutputSpecificationConfig,
#                                                    CradleJobSpecificationConfig
#                                                   )

# %%
from cursus.steps.configs.config_dummy_data_loading_step import DummyDataLoadingConfig
from cursus.steps.configs.config_tabular_preprocessing_step import (
    TabularPreprocessingConfig,
)
from cursus.steps.configs.config_pytorch_training_step import PyTorchTrainingConfig
from cursus.steps.configs.config_pytorch_model_eval_step import PyTorchModelEvalConfig
from cursus.steps.configs.config_model_calibration_step import ModelCalibrationConfig
from cursus.steps.configs.config_package_step import PackageConfig
from cursus.steps.configs.config_payload_step import PayloadConfig
from cursus.steps.configs.config_package_step import PackageConfig
from cursus.steps.configs.config_payload_step import PayloadConfig
from cursus.steps.configs.config_registration_step import RegistrationConfig

# %% [markdown]
# ### Load Config

# %%
from cursus.steps.configs.utils import (
    serialize_config,
    merge_and_save_configs,
    load_configs,
    verify_configs,
)

# %%
CONFIG_CLASSES = {
    "DummyDataLoadingConfig": DummyDataLoadingConfig,
    "TabularPreprocessingConfig": TabularPreprocessingConfig,
    "PyTorchTrainingConfig": PyTorchTrainingConfig,
    "PyTorchModelEvalConfig": PyTorchModelEvalConfig,
    "ModelCalibrationConfig": ModelCalibrationConfig,
    "PackageConfig": PackageConfig,
    "PayloadConfig": PayloadConfig,
    "RegistrationConfig": RegistrationConfig,
}

# %%
config_path
# Out:
# PosixPath('/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json')

# %%
# Load configs
loaded_configs = load_configs(config_path, CONFIG_CLASSES)
# Out:
# 2025-12-02 07:09:29,609 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:29,609 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:29,610 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:29,610 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json with 10 specific configs
# 2025-12-02 07:09:29,611 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-12-02 07:09:29,612 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,612 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,613 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:29,613 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,614 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:29,614 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,614 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,615 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:29,615 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,616 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:29,725 - INFO - Discovered 63 core config classes
# 2025-12-02 07:09:29,734 - INFO - Discovered 5 core hyperparameter classes
# 2025-12-02 07:09:29,762 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-12-02 07:09:29,763 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,764 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,764 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-12-02 07:09:29,765 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,765 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,766 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-12-02 07:09:29,766 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,767 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,768 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-12-02 07:09:29,768 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,769 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,769 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-12-02 07:09:29,770 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,770 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,771 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-12-02 07:09:29,771 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:29,772 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:29,772 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-12-02 07:09:29,773 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-12-02 07:09:29,774 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-12-02 07:09:29,775 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,775 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,776 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-12-02 07:09:29,776 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,777 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,777 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json

# %%
loaded_configs
# Out:
# {'DummyDataLoading_calibration': DummyDataLoadingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='dockers/scripts', processing_entry_point='dummy_data_loading.py', processing_script_arguments=None, processing_framework_version='1.2-1', data_source='/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/processed_data/test', job_type='calibration', max_file_size_mb=1000, supported_formats=['csv', 'parquet', 'json', 'jsonl'], write_data_shards=True, shard_size=10000, output_format='PARQUET'),
#  'DummyDataLoading_training': DummyDataLoadingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='dockers/scripts', processing_entry_point='dummy_data_loading.py', processing_script_arguments=None, processing_framework_version='1.2-1', data_source='/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/processed_data/', job_type='training', max_file_size_mb=1000, supported_formats=['csv', 'parquet', 'json', 'jsonl'], write_data_shards=True, shard_size=10000, output_format='PARQUET'),
#  'ModelCalibration_calibration': ModelCalibrationConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='dockers/scripts', processing_entry_point='model_calibration.py', processing_script_arguments=None, processing_framework_version='1.2-1', label_field='llm_reversal_flag', score_field='prob_class_1', score_fields=None, calibration_method='gam', monotonic_constraint=True, gam_splines=10, error_threshold=0.05, is_binary=True, num_classes=2, score_field_prefix='prob_class_', calibration_sample_points=1000, multiclass_categories=[0, 1], job_type='calibration'),
#  'Package': PackageConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='dockers/scripts', processing_entry_point='package.py', processing_script_arguments=None, processing_framework_version='1.2-1'),
#  'Payload': PayloadConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='dockers/scripts', processing_entry_point='payload.py', processing_script_arguments=None, processing_framework_version='1.2-1', expected_tps=10, max_latency_in_millisecond=800, source_model_inference_content_types=['text/csv'], source_model_inference_response_types=['application/json'], default_numeric_value=0.0, default_text_value='DEFAULT_TEXT', field_defaults={'dialogue': '[bom] [Arrival Time]: 2025-06-11 [BUYER]: I need my refund. [eom]', 'shiptrack_event_history_by_order': '[bom] [Shipment ID]: [eom] [bom] [Ship Track Event Code]: EVENT_503 [Ship Track Event]: Pickup scheduled with Carrier. [eom]'}, custom_payload_path=None, max_acceptable_error_rate=0.2),
#  'PyTorchModelEval_calibration': PyTorchModelEvalConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.p3.16xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='dockers', processing_entry_point='pytorch_model_eval.py', processing_script_arguments=None, processing_framework_version='2.1.2', id_name='order_id', label_name='llm_reversal_flag', job_type='calibration', eval_metric_choices=['auroc', 'average_precision', 'f1_score'], ca_repository_arn='arn:aws:codeartifact:us-west-2:149122183214:repository/amazon/secure-pypi', comparison_mode=False, previous_score_field='', comparison_metrics='all', statistical_tests=True, comparison_plots=True),
#  'PyTorchTraining': PyTorchTrainingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', training_entry_point='pytorch_training.py', training_instance_type='ml.p3.16xlarge', training_instance_count=1, training_volume_size=800, ca_repository_arn='arn:aws:codeartifact:us-west-2:149122183214:repository/amazon/secure-pypi', skip_hyperparameters_s3_uri=True, hyperparameters=None),
#  'Registration': RegistrationConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', model_owner='amzn1.abacus.team.djmdvixm5abr3p75c5ca', model_domain='BuyerSellerMessaging', model_objective='RnR_BSM_Model_NA', framework='pytorch', inference_entry_point='pytorch_inference_handler.py', source_model_inference_input_variable_list=[['net_conc_amt', 'NUMERIC'], ['ttm_conc_amt', 'NUMERIC'], ['ttm_conc_count', 'NUMERIC'], ['concsi', 'NUMERIC'], ['deliverable_flag', 'NUMERIC'], ['undeliverable_flag', 'NUMERIC'], ['unique_message_count', 'NUMERIC'], ['total_ship_track_events_by_order', 'NUMERIC'], ['total_unique_ship_track_events_by_order', 'NUMERIC'], ['dialogue', 'TEXT'], ['shiptrack_event_history_by_order', 'TEXT']], inference_instance_type='ml.m5.large', source_model_inference_content_types=['text/csv'], source_model_inference_response_types=['application/json'], source_model_inference_output_variable_list={'calibrated-score': 'NUMERIC', 'custom-output-label': 'TEXT', 'legacy-score': 'NUMERIC', 'score-percentile': 'NUMERIC'}),
#  'TabularPreprocessing_calibration': TabularPreprocessingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='dockers/scripts', processing_entry_point='tabular_preprocessing.py', processing_script_arguments=None, processing_framework_version='1.2-1', job_type='calibration', label_name=None, train_ratio=0.7, test_val_ratio=0.5, output_format='Parquet'),
#  'TabularPreprocessing_training': TabularPreprocessingConfig(author='lukexie', bucket='sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', role='arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1', region='NA', service_name='BuyerAbuseRnR', pipeline_version='1.0.0', model_class='pytorch', current_date='2025-12-02', framework_version='2.1.0', py_version='py310', source_dir='dockers', enable_caching=False, use_secure_pypi=True, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='dockers/scripts', processing_entry_point='tabular_preprocessing.py', processing_script_arguments=None, processing_framework_version='1.2-1', job_type='training', label_name='llm_reversal_flag', train_ratio=0.7, test_val_ratio=0.5, output_format='Parquet')}

# %%
len(loaded_configs)
# Out:
# 10

# %%
[str(k) for k in loaded_configs.keys()]
# Out:
# ['DummyDataLoading_calibration',
#  'DummyDataLoading_training',
#  'ModelCalibration_calibration',
#  'Package',
#  'Payload',
#  'PyTorchModelEval_calibration',
#  'PyTorchTraining',
#  'Registration',
#  'TabularPreprocessing_calibration',
#  'TabularPreprocessing_training']

# %%
first_config = next(iter(loaded_configs.values()))

# %%
PIPELINE_VERSION = first_config.pipeline_version

# %%
PIPELINE_DESCRIPTION = first_config.pipeline_description

# %%
PIPELINE_NAME = first_config.pipeline_name

# %% [markdown]
# ## Parameter Setup

# %%
from mods_workflow_core.utils.constants import (
    PIPELINE_EXECUTION_TEMP_DIR,
    KMS_ENCRYPTION_KEY_PARAM,
    PROCESSING_JOB_SHARED_NETWORK_CONFIG,
    SECURITY_GROUP_ID,
    VPC_SUBNET,
)

# %% [markdown]
# ### Execution Id

# %%
execution_id = datetime.now().strftime("%Y%m%d%H%M%S")

# %% [markdown]
# ## Import Packages

# %%
from abc import ABC, abstractmethod
from typing import Dict, List, Any, Optional, Type
from pathlib import Path
import logging
import os
import importlib

# %%
import sagemaker
from sagemaker import Session
from sagemaker.workflow.pipeline import Pipeline
from sagemaker.workflow.parameters import ParameterString
from sagemaker.workflow.parameters import Parameter
from sagemaker.workflow.properties import Properties
from sagemaker.workflow.pipeline_context import PipelineSession  # Crucial import

# %% [markdown]
# ## Demo: An End-to-End Pipeline based on PipelineDAG Compiler
# Let us use the following simpler DAG (without registration as example)
#
#
# In this demo there are several user input
# * the **Unified JSON file** in `config_path`
# * the **Registry Manager**: an object that handles the map between step logical name to `step.properties`
# * the **Dependency Resolver**: an object than handles the *automatic dependency resolution* between steps
# * the other fields
#     * `sagemaker_session`: pipelne session
#     * `role`: IAM Role
#     * `notebook_root`: track the root path
#
#
# In this pipeline template, we inherit from base class `PipelineTemplateBase`.
#
# The **major tasks** are
# * *`Config` Classes Import*
# * *Configuration Validation*
# * *Step Builder Retrieval and Step Builder Map Creation*
# * *Configuration Map Creation*
# * **Pipeline DAG Generation**: ideally, user should create this DAG and use it as input
# * **Automatic Pipeline Assemble**: Call `pipeline_assembler`

# %% [markdown]
# ### DAG to Template Compiler

# %%
from cursus.api.dag.base_dag import PipelineDAG
from cursus.core.compiler.dag_compiler import (
    compile_dag_to_pipeline,
    PipelineDAGCompiler,
)
from cursus.core.compiler.validation import ConversionReport
from cursus.steps.configs.utils import load_configs

# %%
def create_dummy_pytorch_training_dag() -> PipelineDAG:
    """
    Create a DAG for Bedrock Batch-enhanced PyTorch E2E pipeline with Label Ruleset steps.

    This DAG represents a complete end-to-end workflow that uses:
    1. Bedrock prompt template generation and batch processing for LLM-enhanced data
    2. Label ruleset generation and execution for transparent label transformation
    3. PyTorch training, followed by calibration, packaging, and registration

    The label ruleset steps sit between Bedrock processing and training/evaluation,
    providing transparent, rule-based label transformation that's easy to modify.

    Returns:
        PipelineDAG: The directed acyclic graph for the pipeline
    """
    dag = PipelineDAG()

    # Add all nodes - matching the structure from demo_config.ipynb
    dag.add_node("DummyDataLoading_training")  # Training data loading
    dag.add_node("TabularPreprocessing_training")  # Training data preprocessing
    dag.add_node("PyTorchTraining")  # XGBoost model training

    dag.add_node("DummyDataLoading_calibration")  # Dummy data load for calibration
    dag.add_node(
        "TabularPreprocessing_calibration"
    )  # Tabular preprocessing for calibration
    dag.add_node("PyTorchModelEval_calibration")  # Model evaluation step
    dag.add_node(
        "ModelCalibration_calibration"
    )  # Model calibration step with calibration variant
    dag.add_node("Package")  # Package step
    dag.add_node("Registration")  # MIMS registration step
    dag.add_node("Payload")  # Payload step

    # Define dependencies - training flow
    dag.add_edge("DummyDataLoading_training", "TabularPreprocessing_training")
    dag.add_edge("TabularPreprocessing_training", "PyTorchTraining")

    # Calibration flow with Bedrock batch processing and label ruleset integration
    dag.add_edge("DummyDataLoading_calibration", "TabularPreprocessing_calibration")

    # Evaluation flow
    dag.add_edge("PyTorchTraining", "PyTorchModelEval_calibration")
    dag.add_edge(
        "TabularPreprocessing_calibration", "PyTorchModelEval_calibration"
    )  # Use labeled calibration data

    # Model calibration flow - depends on model evaluation
    dag.add_edge("PyTorchModelEval_calibration", "ModelCalibration_calibration")

    # Output flow
    dag.add_edge("ModelCalibration_calibration", "Package")
    dag.add_edge("PyTorchTraining", "Package")  # Raw model is also input to packaging
    dag.add_edge("PyTorchTraining", "Payload")  # Raw model is also input to packaging
    dag.add_edge("Package", "Registration")
    dag.add_edge("Payload", "Registration")

    logger.info(
        f"Created XGBoost E2E DAG with {len(dag.nodes)} nodes and {len(dag.edges)} edges"
    )
    return dag

# %%
dag = create_dummy_pytorch_training_dag()
# Out:
# 2025-12-02 07:09:29,857 - INFO - Added node: DummyDataLoading_training
# 2025-12-02 07:09:29,857 - INFO - Added node: TabularPreprocessing_training
# 2025-12-02 07:09:29,858 - INFO - Added node: PyTorchTraining
# 2025-12-02 07:09:29,858 - INFO - Added node: DummyDataLoading_calibration
# 2025-12-02 07:09:29,859 - INFO - Added node: TabularPreprocessing_calibration
# 2025-12-02 07:09:29,859 - INFO - Added node: PyTorchModelEval_calibration
# 2025-12-02 07:09:29,859 - INFO - Added node: ModelCalibration_calibration
# 2025-12-02 07:09:29,859 - INFO - Added node: Package
# 2025-12-02 07:09:29,860 - INFO - Added node: Registration
# 2025-12-02 07:09:29,860 - INFO - Added node: Payload
# 2025-12-02 07:09:29,860 - INFO - Added edge: DummyDataLoading_training -> TabularPreprocessing_training
# 2025-12-02 07:09:29,861 - INFO - Added edge: TabularPreprocessing_training -> PyTorchTraining
# 2025-12-02 07:09:29,861 - INFO - Added edge: DummyDataLoading_calibration -> TabularPreprocessing_calibration
# 2025-12-02 07:09:29,862 - INFO - Added edge: PyTorchTraining -> PyTorchModelEval_calibration
# 2025-12-02 07:09:29,863 - INFO - Added edge: TabularPreprocessing_calibration -> PyTorchModelEval_calibration
# 2025-12-02 07:09:29,863 - INFO - Added edge: PyTorchModelEval_calibration -> ModelCalibration_calibration
# 2025-12-02 07:09:29,863 - INFO - Added edge: ModelCalibration_calibration -> Package
# 2025-12-02 07:09:29,864 - INFO - Added edge: PyTorchTraining -> Package
# 2025-12-02 07:09:29,864 - INFO - Added edge: PyTorchTraining -> Payload
# 2025-12-02 07:09:29,864 - INFO - Added edge: Package -> Registration
# 2025-12-02 07:09:29,865 - INFO - Added edge: Payload -> Registration
# 2025-12-02 07:09:29,865 - INFO - Created XGBoost E2E DAG with 10 nodes and 11 edges

# %%
pipeline_parameters = [
    PIPELINE_EXECUTION_TEMP_DIR,
    KMS_ENCRYPTION_KEY_PARAM,
    SECURITY_GROUP_ID,
    VPC_SUBNET,
]

# %%
dag_compiler = PipelineDAGCompiler(
    config_path=config_path,
    sagemaker_session=pipeline_session,
    role=role,
    pipeline_parameters=pipeline_parameters,
)
# Out:
# 2025-12-02 07:09:29,874 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,875 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,875 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:29,876 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,876 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:29,877 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,877 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,877 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:29,878 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,878 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:29,878 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,879 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,880 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:29,880 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,881 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:29,881 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,881 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,882 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:29,882 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,882 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully

# %% [markdown]
# ### Create a Pipeline

# %% [markdown]
# #### DAG Validation and Preview of Config Resolution

# %%
preview_only = True

# %%
if preview_only:
    preview = dag_compiler.preview_resolution(dag)
    logger.info("DAG node resolution preview:")
    for node, config_type in preview.node_config_map.items():
        confidence = preview.resolution_confidence.get(node, 0.0)
        logger.info(f"  {node} → {config_type} (confidence: {confidence:.2f})")

    if preview.recommendations:
        logger.info("Recommendations:")
        for recommendation in preview.recommendations:
            logger.info(f"  - {recommendation}")

    validation = dag_compiler.validate_dag_compatibility(dag)
    logger.info(f"DAG validation: {'VALID' if validation.is_valid else 'INVALID'}")
    if not validation.is_valid:
        if validation.missing_configs:
            logger.warning(f"Missing configs: {validation.missing_configs}")
        if validation.unresolvable_builders:
            logger.warning(f"Unresolvable builders: {validation.unresolvable_builders}")
        if validation.config_errors:
            logger.warning(f"Config errors: {validation.config_errors}")
# Out:
# 2025-12-02 07:09:29,893 - INFO - Previewing resolution for 10 DAG nodes
# 2025-12-02 07:09:29,893 - INFO - Creating template for DAG with 10 nodes
# 2025-12-02 07:09:29,894 - WARNING - Could not import config_class_detector, using fallback implementation
# 2025-12-02 07:09:29,894 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,894 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,895 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:29,896 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,896 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:29,896 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,897 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,897 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:29,897 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,898 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:29,898 - INFO - Successfully discovered 75 config classes using step catalog
# 2025-12-02 07:09:29,899 - INFO - Loading configs from: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:29,899 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,899 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,901 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:29,901 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,901 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:29,902 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:29,902 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:29,903 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:29,903 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:29,903 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:29,904 - INFO - Successfully discovered 75 config classes using step catalog
# 2025-12-02 07:09:29,904 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:29,905 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:29,906 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:29,906 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json with 10 specific configs
# 2025-12-02 07:09:29,907 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-12-02 07:09:29,908 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,908 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,909 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-12-02 07:09:29,909 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,910 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,910 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-12-02 07:09:29,911 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,911 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,912 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-12-02 07:09:29,913 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,913 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,913 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-12-02 07:09:29,914 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,914 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,915 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-12-02 07:09:29,915 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:29,916 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:29,916 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-12-02 07:09:29,917 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-12-02 07:09:29,917 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-12-02 07:09:29,918 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,919 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,920 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-12-02 07:09:29,920 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,921 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:29,921 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:29,922 - INFO - Loaded raw configuration data from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:29,922 - INFO - Initialized registry manager with workspace context: None
# 2025-12-02 07:09:29,923 - INFO - Created specification registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:29,924 - INFO - Created new workspace-aware registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:29,924 - INFO - Created registry manager for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-12-02 07:09:29,924 - INFO - Created dependency resolver for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-12-02 07:09:29,925 - INFO - Validating dynamic pipeline configuration
# 2025-12-02 07:09:29,925 - INFO - Resolving 10 DAG nodes to configurations
# 2025-12-02 07:09:29,925 - INFO - Using metadata from loaded configuration
# 2025-12-02 07:09:29,926 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-12-02 07:09:29,926 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-12-02 07:09:29,926 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-12-02 07:09:29,927 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-12-02 07:09:29,927 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-12-02 07:09:29,927 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-12-02 07:09:29,927 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-12-02 07:09:29,928 - INFO - Found exact key match for node 'Package'
# 2025-12-02 07:09:29,928 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:29,928 - INFO - Found exact key match for node 'Payload'
# 2025-12-02 07:09:29,929 - INFO - Successfully resolved all 10 nodes
# 2025-12-02 07:09:29,936 - INFO - Index built successfully in 0.007s with 90 steps
# 2025-12-02 07:09:30,000 - INFO - Builder discovery complete: 40 builders found
# 2025-12-02 07:09:30,000 - INFO - Using 45 registered step builders from StepCatalog
# 2025-12-02 07:09:30,001 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,001 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,002 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,002 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,003 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-12-02 07:09:30,003 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-12-02 07:09:30,003 - INFO - Configuration validation passed successfully
# 2025-12-02 07:09:30,004 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-1.0.0-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline' to conform to SageMaker constraints
# 2025-12-02 07:09:30,004 - INFO - Initialized template for: lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline
# 2025-12-02 07:09:30,005 - INFO - Successfully created template
# 2025-12-02 07:09:30,005 - INFO - Using metadata.config_types mapping with 10 entries
# 2025-12-02 07:09:30,006 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-12-02 07:09:30,006 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-12-02 07:09:30,007 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-12-02 07:09:30,007 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-12-02 07:09:30,008 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-12-02 07:09:30,008 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-12-02 07:09:30,008 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-12-02 07:09:30,009 - INFO - Found exact key match for node 'Package'
# 2025-12-02 07:09:30,009 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:30,010 - INFO - Found exact key match for node 'Payload'
# 2025-12-02 07:09:30,010 - ERROR - Failed to generate resolution preview: 0
# 2025-12-02 07:09:30,011 - INFO - DAG node resolution preview:
# 2025-12-02 07:09:30,011 - INFO - Recommendations:
# 2025-12-02 07:09:30,011 - INFO -   - Preview failed: 0
# 2025-12-02 07:09:30,011 - INFO - Validating DAG compatibility for 10 nodes
# 2025-12-02 07:09:30,012 - INFO - Creating template for DAG with 10 nodes
# 2025-12-02 07:09:30,012 - INFO - Loading configs from: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,013 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:30,013 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:30,014 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:30,014 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:30,015 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:30,015 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:30,015 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:30,016 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:30,017 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:30,017 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:30,017 - INFO - Successfully discovered 75 config classes using step catalog
# 2025-12-02 07:09:30,018 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,018 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,019 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,020 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json with 10 specific configs
# 2025-12-02 07:09:30,021 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-12-02 07:09:30,021 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,022 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,022 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-12-02 07:09:30,023 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,023 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,024 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-12-02 07:09:30,024 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,025 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,025 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-12-02 07:09:30,026 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,026 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,027 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-12-02 07:09:30,027 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,028 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,028 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-12-02 07:09:30,029 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:30,029 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:30,030 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-12-02 07:09:30,031 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-12-02 07:09:30,031 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-12-02 07:09:30,032 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,033 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,033 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-12-02 07:09:30,034 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,034 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,035 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,035 - INFO - Loaded raw configuration data from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,036 - INFO - Initialized registry manager with workspace context: None
# 2025-12-02 07:09:30,036 - INFO - Created specification registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:30,037 - INFO - Created new workspace-aware registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:30,037 - INFO - Created registry manager for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-12-02 07:09:30,038 - INFO - Created dependency resolver for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-12-02 07:09:30,038 - INFO - Validating dynamic pipeline configuration
# 2025-12-02 07:09:30,039 - INFO - Resolving 10 DAG nodes to configurations
# 2025-12-02 07:09:30,039 - INFO - Using metadata from loaded configuration
# 2025-12-02 07:09:30,040 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-12-02 07:09:30,040 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-12-02 07:09:30,040 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-12-02 07:09:30,041 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-12-02 07:09:30,041 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-12-02 07:09:30,041 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-12-02 07:09:30,042 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-12-02 07:09:30,042 - INFO - Found exact key match for node 'Package'
# 2025-12-02 07:09:30,042 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:30,043 - INFO - Found exact key match for node 'Payload'
# 2025-12-02 07:09:30,043 - INFO - Successfully resolved all 10 nodes
# 2025-12-02 07:09:30,044 - INFO - Using 45 registered step builders from StepCatalog
# 2025-12-02 07:09:30,044 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,044 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,045 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,045 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,045 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-12-02 07:09:30,046 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-12-02 07:09:30,046 - INFO - Configuration validation passed successfully
# 2025-12-02 07:09:30,047 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-1.0.0-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline' to conform to SageMaker constraints
# 2025-12-02 07:09:30,049 - INFO - Initialized template for: lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline
# 2025-12-02 07:09:30,049 - INFO - Successfully created template
# 2025-12-02 07:09:30,049 - INFO - Validation completed: ✅ Validation passed
# 2025-12-02 07:09:30,050 - INFO - DAG validation: VALID

# %% [markdown]
# ### Put it Together: Pipeline Generation from DAG

# %%
# Convert DAG to pipeline and get report
try:
    logger.info(f"Converting DAG to pipeline")
    template_pipeline, report = dag_compiler.compile_with_report(dag=dag)

    # Log report summary
    logger.info(f"Conversion complete: {report.summary()}")
    for node, details in report.resolution_details.items():
        logger.info(f"  {node} → {details['config_type']} ({details['builder_type']})")

    # Log pipeline creation details
    logger.info(f"Pipeline '{template_pipeline.name}' created successfully")
    logger.info(
        f"Pipeline ARN: {template_pipeline.arn if hasattr(template_pipeline, 'arn') else 'Not available until upserted'}"
    )
    logger.info("To upsert the pipeline, call pipeline.upsert()")
except Exception as e:
    logger.error(f"Failed to convert DAG to pipeline: {e}")
    raise
# Out:
# 2025-12-02 07:09:30,055 - INFO - Converting DAG to pipeline
# 2025-12-02 07:09:30,055 - INFO - Compiling DAG with detailed reporting
# 2025-12-02 07:09:30,056 - INFO - Compiling DAG with 10 nodes to pipeline
# 2025-12-02 07:09:30,056 - INFO - Creating template for DAG with 10 nodes
# 2025-12-02 07:09:30,056 - INFO - Loading configs from: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,057 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:30,057 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:30,058 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:30,058 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:30,059 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:30,059 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:30,059 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:30,060 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:30,060 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:30,060 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:30,061 - INFO - Successfully discovered 75 config classes using step catalog
# 2025-12-02 07:09:30,062 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,062 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,063 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,064 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json with 10 specific configs
# 2025-12-02 07:09:30,065 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-12-02 07:09:30,065 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,066 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,066 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-12-02 07:09:30,067 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,067 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,068 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-12-02 07:09:30,068 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,069 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,069 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-12-02 07:09:30,070 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,070 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,071 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-12-02 07:09:30,072 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,072 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,073 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-12-02 07:09:30,073 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:30,074 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:30,074 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-12-02 07:09:30,075 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-12-02 07:09:30,075 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-12-02 07:09:30,076 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,077 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,077 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-12-02 07:09:30,078 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,078 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:30,079 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,080 - INFO - Loaded raw configuration data from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:30,080 - INFO - Initialized registry manager with workspace context: None
# 2025-12-02 07:09:30,080 - INFO - Created specification registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:30,081 - INFO - Created new workspace-aware registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:30,082 - INFO - Created registry manager for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-12-02 07:09:30,083 - INFO - Created dependency resolver for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-12-02 07:09:30,083 - INFO - Skipping configuration validation (requested)
# 2025-12-02 07:09:30,083 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-1.0.0-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline' to conform to SageMaker constraints
# 2025-12-02 07:09:30,084 - INFO - Initialized template for: lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline
# 2025-12-02 07:09:30,084 - INFO - Successfully created template
# 2025-12-02 07:09:30,084 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-1.0.0-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline' to conform to SageMaker constraints
# 2025-12-02 07:09:30,085 - INFO - Generating pipeline: lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline
# 2025-12-02 07:09:30,085 - INFO - Resolving 10 DAG nodes to configurations
# 2025-12-02 07:09:30,085 - INFO - Using metadata from loaded configuration
# 2025-12-02 07:09:30,086 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-12-02 07:09:30,086 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-12-02 07:09:30,086 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-12-02 07:09:30,087 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-12-02 07:09:30,087 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-12-02 07:09:30,087 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-12-02 07:09:30,088 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-12-02 07:09:30,088 - INFO - Found exact key match for node 'Package'
# 2025-12-02 07:09:30,088 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:30,089 - INFO - Found exact key match for node 'Payload'
# 2025-12-02 07:09:30,089 - INFO - Successfully resolved all 10 nodes
# 2025-12-02 07:09:30,090 - INFO - Using 45 registered step builders from StepCatalog
# 2025-12-02 07:09:30,090 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,091 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,091 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,091 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,092 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-12-02 07:09:30,092 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-12-02 07:09:30,093 - INFO - Using provided StepCatalog instance
# 2025-12-02 07:09:30,093 - INFO - Using stored custom pipeline parameters
# 2025-12-02 07:09:30,093 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,094 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,094 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,094 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,095 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-12-02 07:09:30,095 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-12-02 07:09:30,095 - INFO - Input validation successful
# 2025-12-02 07:09:30,096 - INFO - Initializing step builders
# 2025-12-02 07:09:30,096 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,096 - INFO - Using unified DUMMY_DATA_LOADING_SPEC for all job types
# 2025-12-02 07:09:30,097 - INFO - Initializing DummyDataLoadingStepBuilder with region: NA
# 2025-12-02 07:09:30,097 - INFO - Validating DummyDataLoadingConfig...
# 2025-12-02 07:09:30,097 - INFO - DummyDataLoadingConfig validation succeeded.
# 2025-12-02 07:09:30,101 - INFO - Set execution prefix for DummyDataLoading_training
# 2025-12-02 07:09:30,101 - INFO - Initialized builder for step DummyDataLoading_training using StepCatalog
# 2025-12-02 07:09:30,102 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,102 - INFO - Using unified TABULAR_PREPROCESSING_SPEC for all job types
# 2025-12-02 07:09:30,102 - INFO - Initializing TabularPreprocessingStepBuilder with region: NA
# 2025-12-02 07:09:30,103 - INFO - Set execution prefix for TabularPreprocessing_training
# 2025-12-02 07:09:30,104 - INFO - Initialized builder for step TabularPreprocessing_training using StepCatalog
# 2025-12-02 07:09:30,104 - INFO - Using PyTorch training specification
# 2025-12-02 07:09:30,104 - INFO - Initializing PyTorchTrainingStepBuilder with region: NA
# 2025-12-02 07:09:30,105 - INFO - Validating PyTorchTrainingConfig...
# 2025-12-02 07:09:30,105 - INFO - Configuration validation relies on step specifications
# 2025-12-02 07:09:30,105 - INFO - PyTorchTrainingConfig validation succeeded.
# 2025-12-02 07:09:30,106 - INFO - Set execution prefix for PyTorchTraining
# 2025-12-02 07:09:30,106 - INFO - Initialized builder for step PyTorchTraining using StepCatalog
# 2025-12-02 07:09:30,106 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:30,107 - INFO - Using unified DUMMY_DATA_LOADING_SPEC for all job types
# 2025-12-02 07:09:30,107 - INFO - Initializing DummyDataLoadingStepBuilder with region: NA
# 2025-12-02 07:09:30,107 - INFO - Validating DummyDataLoadingConfig...
# 2025-12-02 07:09:30,108 - INFO - DummyDataLoadingConfig validation succeeded.
# 2025-12-02 07:09:30,109 - INFO - Set execution prefix for DummyDataLoading_calibration
# 2025-12-02 07:09:30,109 - INFO - Initialized builder for step DummyDataLoading_calibration using StepCatalog
# 2025-12-02 07:09:30,110 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:30,110 - INFO - Using unified TABULAR_PREPROCESSING_SPEC for all job types
# 2025-12-02 07:09:30,110 - INFO - Initializing TabularPreprocessingStepBuilder with region: NA
# 2025-12-02 07:09:30,111 - INFO - Set execution prefix for TabularPreprocessing_calibration
# 2025-12-02 07:09:30,111 - INFO - Initialized builder for step TabularPreprocessing_calibration using StepCatalog
# 2025-12-02 07:09:30,111 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-12-02 07:09:30,112 - INFO - Initializing PyTorchModelEvalStepBuilder with region: NA
# 2025-12-02 07:09:30,112 - INFO - Validating PyTorchModelEvalConfig...
# 2025-12-02 07:09:30,112 - INFO - PyTorchModelEvalConfig validation succeeded.
# 2025-12-02 07:09:30,113 - INFO - Set execution prefix for PyTorchModelEval_calibration
# 2025-12-02 07:09:30,113 - INFO - Initialized builder for step PyTorchModelEval_calibration using StepCatalog
# 2025-12-02 07:09:30,115 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-12-02 07:09:30,115 - INFO - Using unified MODEL_CALIBRATION_SPEC for all job types
# 2025-12-02 07:09:30,115 - INFO - Initializing ModelCalibrationStepBuilder with region: NA
# 2025-12-02 07:09:30,116 - INFO - Validating ModelCalibrationConfig...
# 2025-12-02 07:09:30,116 - INFO - ModelCalibrationConfig validation succeeded.
# 2025-12-02 07:09:30,117 - INFO - Set execution prefix for ModelCalibration_calibration
# 2025-12-02 07:09:30,117 - INFO - Initialized builder for step ModelCalibration_calibration using StepCatalog
# 2025-12-02 07:09:30,118 - INFO - Initializing PackageStepBuilder with region: NA
# 2025-12-02 07:09:30,118 - INFO - Validating PackageConfig...
# 2025-12-02 07:09:30,118 - INFO - PackageConfig validation succeeded.
# 2025-12-02 07:09:30,119 - INFO - Set execution prefix for Package
# 2025-12-02 07:09:30,119 - INFO - Initialized builder for step Package using StepCatalog
# 2025-12-02 07:09:30,119 - INFO - Initializing RegistrationStepBuilder with region: NA
# 2025-12-02 07:09:30,120 - INFO - Validating RegistrationConfig...
# 2025-12-02 07:09:30,120 - INFO - RegistrationConfig validation succeeded.
# 2025-12-02 07:09:30,120 - INFO - Set execution prefix for Registration
# 2025-12-02 07:09:30,121 - INFO - Initialized builder for step Registration using StepCatalog
# 2025-12-02 07:09:30,121 - INFO - Initializing PayloadStepBuilder with region: NA
# 2025-12-02 07:09:30,121 - INFO - Validating PayloadConfig...
# 2025-12-02 07:09:30,122 - INFO - PayloadConfig validation succeeded.
# 2025-12-02 07:09:30,122 - INFO - Set execution prefix for Payload
# 2025-12-02 07:09:30,122 - INFO - Initialized builder for step Payload using StepCatalog
# 2025-12-02 07:09:30,123 - INFO - Initialized 10 step builders in 0.03 seconds
# 2025-12-02 07:09:30,123 - INFO - Generating pipeline: lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline
# 2025-12-02 07:09:30,123 - INFO - Initializing step connections using specifications
# 2025-12-02 07:09:30,124 - INFO - Matched TabularPreprocessing_training.DATA to DummyDataLoading_training.DATA (score: 1.00)
# 2025-12-02 07:09:30,126 - INFO - Matched TabularPreprocessing_training.SIGNATURE to DummyDataLoading_training.SIGNATURE (score: 1.00)
# 2025-12-02 07:09:30,128 - INFO - Matched PyTorchTraining.input_path to TabularPreprocessing_training.processed_data (score: 0.81)
# 2025-12-02 07:09:30,130 - INFO - Matched PyTorchTraining.model_artifacts_input to TabularPreprocessing_training.processed_data (score: 0.75)
# 2025-12-02 07:09:30,131 - INFO - Matched TabularPreprocessing_calibration.DATA to DummyDataLoading_calibration.DATA (score: 1.00)
# 2025-12-02 07:09:30,131 - INFO - Matched TabularPreprocessing_calibration.SIGNATURE to DummyDataLoading_calibration.SIGNATURE (score: 1.00)
# 2025-12-02 07:09:30,132 - INFO - Matched PyTorchModelEval_calibration.model_input to PyTorchTraining.model_output (score: 1.00)
# 2025-12-02 07:09:30,133 - INFO - Matched PyTorchModelEval_calibration.processed_data to PyTorchTraining.evaluation_output (score: 0.74)
# 2025-12-02 07:09:30,134 - INFO - Matched PyTorchModelEval_calibration.processed_data to TabularPreprocessing_calibration.processed_data (score: 1.00)
# 2025-12-02 07:09:30,135 - INFO - Matched ModelCalibration_calibration.evaluation_data to PyTorchModelEval_calibration.eval_output (score: 1.00)
# 2025-12-02 07:09:30,141 - INFO - Matched Package.calibration_model to ModelCalibration_calibration.calibration_output (score: 1.00)
# 2025-12-02 07:09:30,141 - INFO - Matched Package.model_input to PyTorchTraining.model_output (score: 0.92)
# 2025-12-02 07:09:30,143 - INFO - Matched Payload.model_input to PyTorchTraining.model_output (score: 1.00)
# 2025-12-02 07:09:30,144 - INFO - Matched Payload.custom_payload_input to PyTorchTraining.evaluation_output (score: 0.64)
# 2025-12-02 07:09:30,144 - INFO - Matched Registration.PackagedModel to Package.packaged_model (score: 1.00)
# 2025-12-02 07:09:30,145 - INFO - Matched Registration.GeneratedPayloadSamples to Payload.payload_sample (score: 0.71)
# 2025-12-02 07:09:30,145 - INFO - Build order: ['DummyDataLoading_training', 'DummyDataLoading_calibration', 'TabularPreprocessing_training', 'TabularPreprocessing_calibration', 'PyTorchTraining', 'PyTorchModelEval_calibration', 'Payload', 'ModelCalibration_calibration', 'Package', 'Registration']
# 2025-12-02 07:09:30,145 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:30,146 - INFO - Creating Dummy Data Loading ProcessingStep...
# 2025-12-02 07:09:30,147 - INFO - Added configuration environment variables: {...}
# 2025-12-02 07:09:30,148 - INFO - Final dummy data loading environment variables: {...}
# 2025-12-02 07:09:30,150 - INFO - Defaulting to only available Python version: py3
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingOutputConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingResources.ClusterConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.SecurityGroupIds
# 2025-12-02 07:09:31,192 - INFO - Using user-provided data source from configuration: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/processed_data/ -> /opt/ml/processing/input/data
# 2025-12-02 07:09:31,192 - INFO - No command-line arguments needed for dummy data loading script
# 2025-12-02 07:09:31,193 - INFO - Using script path: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts/dummy_data_loading.py
# 2025-12-02 07:09:31,194 - INFO - Created ProcessingStep with name: DummyDataLoading-Training
# 2025-12-02 07:09:31,194 - INFO - Built step DummyDataLoading_training
# 2025-12-02 07:09:31,195 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:31,195 - INFO - Creating Dummy Data Loading ProcessingStep...
# 2025-12-02 07:09:31,196 - INFO - Added configuration environment variables: {...}
# 2025-12-02 07:09:31,197 - INFO - Final dummy data loading environment variables: {...}
# 2025-12-02 07:09:31,197 - INFO - Defaulting to only available Python version: py3
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingOutputConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingResources.ClusterConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.SecurityGroupIds
# 2025-12-02 07:09:32,492 - INFO - Using user-provided data source from configuration: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/processed_data/test -> /opt/ml/processing/input/data
# 2025-12-02 07:09:32,493 - INFO - No command-line arguments needed for dummy data loading script
# 2025-12-02 07:09:32,493 - INFO - Using script path: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts/dummy_data_loading.py
# 2025-12-02 07:09:32,494 - INFO - Created ProcessingStep with name: DummyDataLoading-Calibration
# 2025-12-02 07:09:32,495 - INFO - Built step DummyDataLoading_calibration
# 2025-12-02 07:09:32,496 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:32,496 - INFO - Registered specification for step 'TabularPreprocessingStepStep' of type 'TabularPreprocessing' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:32,497 - INFO - Registered specification for step 'DummyDataLoading-Training' of type 'DummyDataLoading' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:32,498 - INFO - Best match for DATA: DummyDataLoading-Training.DATA (confidence: 1.000)
# 2025-12-02 07:09:32,498 - INFO - Resolved TabularPreprocessingStepStep.DATA -> DummyDataLoading-Training.DATA
# 2025-12-02 07:09:32,499 - INFO - Best match for SIGNATURE: DummyDataLoading-Training.SIGNATURE (confidence: 1.000)
# 2025-12-02 07:09:32,500 - INFO - Resolved TabularPreprocessingStepStep.SIGNATURE -> DummyDataLoading-Training.SIGNATURE
# 2025-12-02 07:09:32,501 - INFO - Defaulting to only available Python version: py3
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingOutputConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingResources.ClusterConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.SecurityGroupIds
# 2025-12-02 07:09:33,527 - INFO - Setting job_type argument to: training
# 2025-12-02 07:09:33,528 - INFO - Using script path: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts/tabular_preprocessing.py
# 2025-12-02 07:09:33,529 - INFO - Built step TabularPreprocessing_training
# 2025-12-02 07:09:33,529 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:33,530 - INFO - Registered specification for step 'TabularPreprocessingStepStep' of type 'TabularPreprocessing' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:33,530 - INFO - Registered specification for step 'DummyDataLoading-Calibration' of type 'DummyDataLoading' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:33,531 - INFO - Best match for DATA: DummyDataLoading-Calibration.DATA (confidence: 1.000)
# 2025-12-02 07:09:33,531 - INFO - Resolved TabularPreprocessingStepStep.DATA -> DummyDataLoading-Calibration.DATA
# 2025-12-02 07:09:33,532 - INFO - Best match for SIGNATURE: DummyDataLoading-Calibration.SIGNATURE (confidence: 1.000)
# 2025-12-02 07:09:33,533 - INFO - Resolved TabularPreprocessingStepStep.SIGNATURE -> DummyDataLoading-Calibration.SIGNATURE
# 2025-12-02 07:09:33,535 - INFO - Defaulting to only available Python version: py3
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingOutputConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingResources.ClusterConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.SecurityGroupIds
# 2025-12-02 07:09:34,566 - INFO - Setting job_type argument to: calibration
# 2025-12-02 07:09:34,566 - INFO - Using script path: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts/tabular_preprocessing.py
# 2025-12-02 07:09:34,567 - INFO - Built step TabularPreprocessing_calibration
# 2025-12-02 07:09:34,568 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:34,568 - INFO - Creating PyTorch TrainingStep...
# 2025-12-02 07:09:34,569 - INFO - Registered specification for step 'PyTorchTrainingStepStep' of type 'PyTorchTraining' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:34,570 - INFO - Registered specification for step 'TabularPreprocessing-Training' of type 'TabularPreprocessing' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:34,571 - INFO - Best match for input_path: TabularPreprocessing-Training.processed_data (confidence: 0.814)
# 2025-12-02 07:09:34,571 - INFO - Resolved PyTorchTrainingStepStep.input_path -> TabularPreprocessing-Training.processed_data
# 2025-12-02 07:09:34,572 - INFO - Optional dependency not resolved: PyTorchTrainingStepStep.hyperparameters_s3_uri
# 2025-12-02 07:09:34,573 - INFO - Best match for model_artifacts_input: TabularPreprocessing-Training.processed_data (confidence: 0.745)
# 2025-12-02 07:09:34,574 - INFO - Resolved PyTorchTrainingStepStep.model_artifacts_input -> TabularPreprocessing-Training.processed_data
# 2025-12-02 07:09:34,574 - INFO - Created data channels from input_path: [Pipeline Variable: Properties]
# 2025-12-02 07:09:34,574 - INFO - Skipping hyperparameters_s3_uri channel as configured (hyperparameters loaded from script folder)
# 2025-12-02 07:09:34,575 - INFO - Created model_artifacts_input channel from model_artifacts_input: [Pipeline Variable: Properties]
# 2025-12-02 07:09:34,575 - INFO - Final training inputs: [list with 4 items]
# 2025-12-02 07:09:34,575 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:34,576 - INFO - Using generated base output path: [Pipeline Variable: Join]
# 2025-12-02 07:09:34,576 - INFO - SageMaker will organize outputs using base job name: PyTorchTraining-1764659374
# 2025-12-02 07:09:34,576 - INFO - Full job name will be: PyTorchTraining-1764659374-[timestamp]
# 2025-12-02 07:09:34,577 - INFO - Output path structure will be: [Pipeline Variable: Join]/PyTorchTraining-1764659374-[timestamp]/
# 2025-12-02 07:09:34,577 - INFO -   - Model artifacts will be in: [Pipeline Variable: Join]/PyTorchTraining-1764659374-[timestamp]/output/model.tar.gz
# 2025-12-02 07:09:34,577 - INFO -   - Evaluation results will be in: [Pipeline Variable: Join]/PyTorchTraining-1764659374-[timestamp]/output/output.tar.gz
# 2025-12-02 07:09:34,578 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:34,578 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:34,580 - INFO - Using source directory: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:34,580 - INFO - Added CA_REPOSITORY_ARN to environment variables for secure PyPI
# 2025-12-02 07:09:34,580 - INFO - Training environment variables: {...}
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.OutputDataConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.ResourceConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.SecurityGroupIds
# 2025-12-02 07:09:35,871 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/workflow/steps.py:485: UserWarning: Profiling is enabled on the provided estimator. The default profiler rule includes a timestamp which will change each time the pipeline is upserted, causing cache misses. If profiling is not needed, set disable_profiler to True on the estimator.
#   warnings.warn(msg)
# 2025-12-02 07:09:35,952 - INFO - Created TrainingStep with name: PyTorchTraining
# 2025-12-02 07:09:35,953 - INFO - Built step PyTorchTraining
# 2025-12-02 07:09:35,953 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:35,954 - INFO - Creating PyTorchModelEval ProcessingStep...
# 2025-12-02 07:09:35,954 - INFO - Registered specification for step 'PyTorchModelEvalStepStep' of type 'PyTorchModelEval' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:35,955 - INFO - Registered specification for step 'PyTorchTraining' of type 'PyTorchTraining' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:35,955 - INFO - Registered specification for step 'TabularPreprocessing-Calibration' of type 'TabularPreprocessing' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:35,956 - INFO - Best match for model_input: PyTorchTraining.model_output (confidence: 1.000)
# 2025-12-02 07:09:35,956 - INFO - Resolved PyTorchModelEvalStepStep.model_input -> PyTorchTraining.model_output
# 2025-12-02 07:09:35,958 - INFO - Best match for processed_data: TabularPreprocessing-Calibration.processed_data (confidence: 1.000)
# 2025-12-02 07:09:35,958 - INFO - Resolved PyTorchModelEvalStepStep.processed_data -> TabularPreprocessing-Calibration.processed_data
# 2025-12-02 07:09:35,959 - WARNING - Required environment variable 'ID_FIELD' not found in config
# 2025-12-02 07:09:35,960 - WARNING - Required environment variable 'LABEL_FIELD' not found in config
# 2025-12-02 07:09:35,961 - INFO - Added CA_REPOSITORY_ARN to environment variables for secure PyPI
# 2025-12-02 07:09:35,961 - INFO - PyTorch evaluation environment variables: {...}
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingOutputConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingResources.ClusterConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.SecurityGroupIds
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.ResourceConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.SecurityGroupIds
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.Environment
# 2025-12-02 07:09:38,253 - INFO - image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# 2025-12-02 07:09:38,276 - INFO - Setting job_type argument to: calibration
# 2025-12-02 07:09:38,277 - INFO - Using resolved script path: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/pytorch_model_eval.py
# 2025-12-02 07:09:38,277 - INFO - Using entry point: pytorch_model_eval.py
# 2025-12-02 07:09:38,277 - INFO - Using source directory: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/workflow/pipeline_context.py:332: UserWarning: Running within a PipelineSession, there will be No Wait, No Logs, and No Job being started.
#   warnings.warn(
# 2025-12-02 07:09:38,278 - INFO - Created ProcessingStep with name: PyTorchModelEval-Calibration
# 2025-12-02 07:09:38,279 - INFO - Built step PyTorchModelEval_calibration
# 2025-12-02 07:09:38,279 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:38,280 - INFO - Creating MIMS Payload ProcessingStep...
# 2025-12-02 07:09:38,280 - INFO - Registered specification for step 'PayloadStepStep' of type 'Payload' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:38,281 - INFO - Registered specification for step 'PyTorchTraining' of type 'PyTorchTraining' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:38,281 - INFO - Best match for model_input: PyTorchTraining.model_output (confidence: 1.000)
# 2025-12-02 07:09:38,282 - INFO - Resolved PayloadStepStep.model_input -> PyTorchTraining.model_output
# 2025-12-02 07:09:38,283 - INFO - Best match for custom_payload_input: PyTorchTraining.evaluation_output (confidence: 0.637)
# 2025-12-02 07:09:38,284 - INFO - Resolved PayloadStepStep.custom_payload_input -> PyTorchTraining.evaluation_output
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a real number is required, not str
# Call stack:
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2974, in run_cell
#     result = self._run_cell(
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3029, in _run_cell
#     return runner(coro)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3256, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3472, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3552, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_48731/2863464796.py", line 4, in <cell line: 2>
#     template_pipeline, report = dag_compiler.compile_with_report(dag=dag)
#   File "/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/core/compiler/dag_compiler.py", line 460, in compile_with_report
#     pipeline = self.compile(dag, pipeline_name=pipeline_name, **kwargs)
#   File "/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/core/compiler/dag_compiler.py", line 411, in compile
#     pipeline = cast(SageMakerPipeline, template.generate_pipeline())
#   File "/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/core/assembler/pipeline_template_base.py", line 322, in generate_pipeline
#     pipeline = template.generate_pipeline(pipeline_name)
#   File "/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/core/assembler/pipeline_assembler.py", line 499, in generate_pipeline
#     step = self._instantiate_step(step_name)
#   File "/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/core/assembler/pipeline_assembler.py", line 407, in _instantiate_step
#     step = builder.create_step(**kwargs)
#   File "/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/steps/builders/builder_payload_step.py", line 358, in create_step
#     processor = self._create_processor()
#   File "/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/steps/builders/builder_payload_step.py", line 135, in _create_processor
#     env=self._get_environment_variables(),
#   File "/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/steps/builders/builder_payload_step.py", line 169, in _get_environment_variables
#     self.log_info("Added FIELD_DEFAULTS for %d fields", len(self.config.field_defaults))
#   File "/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus/core/base/builder_base.py", line 485, in log_info
#     logger.info(message, *safe_args)
# Message: 'Added FIELD_DEFAULTS for %d fields'
# Arguments: ('2',)
# 2025-12-02 07:09:38,288 - INFO - Payload environment variables configured
# 2025-12-02 07:09:38,288 - INFO - Defaulting to only available Python version: py3
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingOutputConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingResources.ClusterConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.SecurityGroupIds
# 2025-12-02 07:09:39,323 - INFO - No command-line arguments needed for payload script
# 2025-12-02 07:09:39,324 - INFO - Using script path: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts/payload.py
# 2025-12-02 07:09:39,325 - INFO - Created ProcessingStep with name: Payload
# 2025-12-02 07:09:39,325 - INFO - Built step Payload
# 2025-12-02 07:09:39,325 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:39,326 - INFO - Creating ModelCalibration ProcessingStep...
# 2025-12-02 07:09:39,326 - INFO - Registered specification for step 'ModelCalibrationStepStep' of type 'ModelCalibration' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:39,327 - INFO - Registered specification for step 'PyTorchModelEval-Calibration' of type 'PyTorchModelEval' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:39,328 - INFO - Best match for evaluation_data: PyTorchModelEval-Calibration.eval_output (confidence: 1.000)
# 2025-12-02 07:09:39,328 - INFO - Resolved ModelCalibrationStepStep.evaluation_data -> PyTorchModelEval-Calibration.eval_output
# 2025-12-02 07:09:39,330 - INFO - Defaulting to only available Python version: py3
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingOutputConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingResources.ClusterConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.SecurityGroupIds
# 2025-12-02 07:09:40,365 - INFO - Setting job_type argument to: calibration
# 2025-12-02 07:09:40,365 - INFO - Using script path: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts/model_calibration.py
# 2025-12-02 07:09:40,366 - INFO - Created ProcessingStep with name: ModelCalibration-Calibration
# 2025-12-02 07:09:40,366 - INFO - Built step ModelCalibration_calibration
# 2025-12-02 07:09:40,367 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:40,367 - INFO - Creating Packaging ProcessingStep...
# 2025-12-02 07:09:40,368 - INFO - Registered specification for step 'PackageStepStep' of type 'Package' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:40,368 - INFO - Registered specification for step 'ModelCalibration-Calibration' of type 'ModelCalibration' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:40,368 - INFO - Registered specification for step 'PyTorchTraining' of type 'PyTorchTraining' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:40,369 - INFO - Best match for model_input: PyTorchTraining.model_output (confidence: 0.920)
# 2025-12-02 07:09:40,370 - INFO - Resolved PackageStepStep.model_input -> PyTorchTraining.model_output
# 2025-12-02 07:09:40,370 - INFO - Optional dependency not resolved: PackageStepStep.inference_scripts_input
# 2025-12-02 07:09:40,376 - INFO - Best match for calibration_model: ModelCalibration-Calibration.calibration_output (confidence: 1.000)
# 2025-12-02 07:09:40,376 - INFO - Resolved PackageStepStep.calibration_model -> ModelCalibration-Calibration.calibration_output
# 2025-12-02 07:09:40,377 - INFO - Packaging environment variables: {...}
# 2025-12-02 07:09:40,379 - INFO - Defaulting to only available Python version: py3
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingOutputConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingResources.ClusterConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.SecurityGroupIds
# 2025-12-02 07:09:41,408 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:41,409 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:41,409 - INFO - Using source dir: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:41,409 - INFO - [PACKAGING INPUT OVERRIDE] Using local inference scripts path from configuration: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:41,410 - INFO - [PACKAGING INPUT OVERRIDE] This local path will be used regardless of any dependency-resolved values
# 2025-12-02 07:09:41,410 - INFO - Added inference scripts input with local path: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers -> /opt/ml/processing/input/script
# 2025-12-02 07:09:41,410 - INFO - No command-line arguments needed for packaging script
# 2025-12-02 07:09:41,411 - INFO - Using script path: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts/package.py
# 2025-12-02 07:09:41,412 - INFO - Created ProcessingStep with name: Package
# 2025-12-02 07:09:41,412 - INFO - Built step Package
# 2025-12-02 07:09:41,413 - INFO - Using execution_prefix for base output path
# 2025-12-02 07:09:41,413 - INFO - Creating MimsModelRegistrationProcessingStep...
# 2025-12-02 07:09:41,414 - INFO - Registered specification for step 'RegistrationStepStep' of type 'Registration' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:41,414 - INFO - Registered specification for step 'Package' of type 'Package' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:41,414 - INFO - Registered specification for step 'Payload' of type 'Payload' in context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:41,415 - INFO - Best match for PackagedModel: Package.packaged_model (confidence: 1.000)
# 2025-12-02 07:09:41,416 - INFO - Resolved RegistrationStepStep.PackagedModel -> Package.packaged_model
# 2025-12-02 07:09:41,416 - INFO - Best match for GeneratedPayloadSamples: Payload.payload_sample (confidence: 0.710)
# 2025-12-02 07:09:41,417 - INFO - Resolved RegistrationStepStep.GeneratedPayloadSamples -> Payload.payload_sample
# 2025-12-02 07:09:41,417 - INFO - Extracted inputs from dependencies: [list with 2 items]
# 2025-12-02 07:09:41,417 - INFO - Using source for 'PackagedModel' directly without wrapper
# 2025-12-02 07:09:41,418 - INFO - Using source for 'GeneratedPayloadSamples' directly without wrapper
# 2025-12-02 07:09:41,418 - INFO - Created 2 ProcessingInput objects in required order
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingOutputConfig.KmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.ProcessingResources.ClusterConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.NetworkConfig.VpcConfig.SecurityGroupIds
# sagemaker.config INFO - Applied value from config key = SageMaker.ProcessingJob.Environment
# 2025-12-02 07:09:42,434 - INFO - Created MimsModelRegistrationProcessingStep: Registration-NA
# 2025-12-02 07:09:42,435 - INFO - Built step Registration
# 2025-12-02 07:09:42,440 - INFO - Generated pipeline lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline with 10 steps in 12.32 seconds
# 2025-12-02 07:09:42,440 - INFO - Stored 10 step instances
# 2025-12-02 07:09:42,440 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-1.0.0-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline' to conform to SageMaker constraints
# 2025-12-02 07:09:42,441 - INFO - Successfully compiled DAG to pipeline: lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline
# 2025-12-02 07:09:42,441 - INFO - Previewing resolution for 10 DAG nodes
# 2025-12-02 07:09:42,441 - INFO - Creating template for DAG with 10 nodes
# 2025-12-02 07:09:42,442 - INFO - Loading configs from: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,442 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:42,443 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:42,444 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:42,444 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:42,445 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:42,445 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:42,445 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:42,446 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:42,446 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:42,446 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:42,447 - INFO - Successfully discovered 75 config classes using step catalog
# 2025-12-02 07:09:42,448 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,448 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,449 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,450 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json with 10 specific configs
# 2025-12-02 07:09:42,450 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-12-02 07:09:42,451 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,452 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,452 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-12-02 07:09:42,453 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,453 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,454 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-12-02 07:09:42,455 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,455 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,456 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-12-02 07:09:42,456 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,457 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,457 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-12-02 07:09:42,458 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,458 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,459 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-12-02 07:09:42,459 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:42,460 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:42,461 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-12-02 07:09:42,461 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-12-02 07:09:42,462 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-12-02 07:09:42,463 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,463 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,463 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-12-02 07:09:42,464 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,465 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,465 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,466 - INFO - Loaded raw configuration data from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,466 - INFO - Initialized registry manager with workspace context: None
# 2025-12-02 07:09:42,467 - INFO - Created specification registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:42,468 - INFO - Created new workspace-aware registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-12-02 07:09:42,468 - INFO - Created registry manager for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-12-02 07:09:42,468 - INFO - Created dependency resolver for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-12-02 07:09:42,469 - INFO - Validating dynamic pipeline configuration
# 2025-12-02 07:09:42,469 - INFO - Resolving 10 DAG nodes to configurations
# 2025-12-02 07:09:42,469 - INFO - Using metadata from loaded configuration
# 2025-12-02 07:09:42,470 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-12-02 07:09:42,470 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-12-02 07:09:42,470 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-12-02 07:09:42,471 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-12-02 07:09:42,471 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-12-02 07:09:42,471 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-12-02 07:09:42,472 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-12-02 07:09:42,472 - INFO - Found exact key match for node 'Package'
# 2025-12-02 07:09:42,472 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:42,473 - INFO - Found exact key match for node 'Payload'
# 2025-12-02 07:09:42,473 - INFO - Successfully resolved all 10 nodes
# 2025-12-02 07:09:42,474 - INFO - Using 45 registered step builders from StepCatalog
# 2025-12-02 07:09:42,474 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:42,474 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:42,475 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-12-02 07:09:42,475 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-12-02 07:09:42,476 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-12-02 07:09:42,476 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-12-02 07:09:42,476 - INFO - Configuration validation passed successfully
# 2025-12-02 07:09:42,479 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-1.0.0-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline' to conform to SageMaker constraints
# 2025-12-02 07:09:42,479 - INFO - Initialized template for: lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline
# 2025-12-02 07:09:42,479 - INFO - Successfully created template
# 2025-12-02 07:09:42,480 - INFO - Using metadata.config_types mapping with 10 entries
# 2025-12-02 07:09:42,480 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-12-02 07:09:42,480 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-12-02 07:09:42,481 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-12-02 07:09:42,481 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-12-02 07:09:42,481 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-12-02 07:09:42,482 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-12-02 07:09:42,482 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-12-02 07:09:42,482 - INFO - Found exact key match for node 'Package'
# 2025-12-02 07:09:42,483 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:42,483 - INFO - Found exact key match for node 'Payload'
# 2025-12-02 07:09:42,483 - ERROR - Failed to generate resolution preview: 0
# 2025-12-02 07:09:42,484 - INFO - Compilation completed with report: Pipeline 'lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline' created successfully with 10 steps (avg confidence: 0.00)
# 2025-12-02 07:09:42,484 - INFO - Conversion complete: Pipeline 'lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline' created successfully with 10 steps (avg confidence: 0.00)
# 2025-12-02 07:09:42,484 - INFO - Pipeline 'lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline' created successfully
# 2025-12-02 07:09:42,485 - INFO - Pipeline ARN: Not available until upserted
# 2025-12-02 07:09:42,485 - INFO - To upsert the pipeline, call pipeline.upsert()

# %% [markdown]
# ### Pipeline Template
#
# After the pipeline is generated, we can retrieve the pipeline template

# %%
pipeline_template_builder = dag_compiler.get_last_template()

# %% [markdown]
# ## Start Execution

# %%
role_arn = pipeline_session.get_caller_identity_arn()
role_arn
# Out:
# 'arn:aws:iam::601857636239:role/SandboxRole-lukexie-us-east-1'

# %%
pipeline_description = PIPELINE_DESCRIPTION

# %%
PIPELINE_DESCRIPTION
# Out:
# 'BuyerAbuseRnR pytorch Model NA'

# %% [markdown]
# ## Prepare for Execution Document

# %%
from mods_workflow_helper.sagemaker_pipeline_helper import (
    SagemakerPipelineHelper,
    SecurityConfig,
)

# %%
default_execution_doc = SagemakerPipelineHelper.get_pipeline_default_execution_document(
    template_pipeline
)
test_execution_doc = default_execution_doc

# %%
print(json.dumps(test_execution_doc, indent=2))
# Out:
# {
#   "PIPELINE_STEP_CONFIGS": {
#     "PyTorchTraining": {
#       "STEP_CONFIG": {},
#       "STEP_TYPE": "TRAINING_STEP"
#     },
#     "Registration-NA": {
#       "STEP_CONFIG": {
#         "model_domain": "The domain to register your model in (this is where you will find your model on DAWS)",
#         "model_objective": "The objective to register your model in (this is where you will find your model on DAWS)",
#         "source_model_inference_content_types": "Provide a list of types (application/json and text/csv are currently supported) for the content. Ex) ['text/csv']",
#         "source_model_inference_response_types": "Provide a list of types (application/json and text/csv are currently supported) for the response. Ex) ['application/json']",
#         "source_model_inference_input_variable_list": "Provide a dictionary mapping the variable name to the variable type (variable types supported are 'TEXT' and 'NUMERIC') for both input and output vars. Ex) {'INVAR': 'TEXT'}",
#         "source_model_inference_output_variable_list": "Provide a dictionary mapping the variable name to the variable type (variable types supported are 'TEXT' and 'NUMERIC') for both input and output vars. Ex) {'OUTVAR': 'NUMERIC'}",
#         "model_registration_region": "The region that your SageMaker model will be registered in, valid values are NA/EU/FE",
#         "model_owner": "The team id of the team that owns this model. This can be found at https://permissions.amazon.com/ by searching for your team name to get the team id.",
#         "source_model_inference_image_arn": "The image arn for your trained model to be registered. This can be found by calling model.image_uri on a created model or estimator.model_uri/estimator.image_uri on an Estimator object.",
#         "source_model_region": "Optional: The region your model was trained in and the model artifacts are located in. Default is 'us-east-1'",
#         "source_model_environment_variable_map": "Optional: You can provide a dictionary of environment variables to be associated with your model. Ex) {'SAGEMAKER_CONTAINER_LOG_LEVEL': '20'}",
#         "load_testing_info_map": "Optional: You can provide a dictionary of load testing parameters. All the parameters listed are required if providing the load testing map. Ex) {'samplePayloadS3Bucket': 'mods-personal-bucket', 'samplePayloadS3Key': 'sample_payload.csv', 'expectedTPS': '2000', 'maxLatencyInMillisecond': '50', 'instanceTypeList': ['ml.m5.xlarge', 'ml.m5d.2xlarge']}"
#       },
#       "STEP_TYPE": [
#         "PROCESSING_STEP",
#         "MimsModelRegistrationProcessingStep"
#       ]
#     }
#   },
#   "PIPELINE_ADDITIONAL_PARAMS": {}
# }

# %%
# with open(config_dir / 'sample_exe_doc.json', 'w') as f:
#    json.dump(default_execution_doc, f, indent=2)

# %% [markdown]
# ### Fill in Execution Doc

# %%
from cursus.mods.exe_doc.generator import ExecutionDocumentGenerator

# %%
exe_doc_generator = ExecutionDocumentGenerator(
    config_path=config_path,
    sagemaker_session=pipeline_session,
    role=role,
)
# Out:
# 2025-12-02 07:09:42,610 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:42,611 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:42,611 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:42,612 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:42,612 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:42,613 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:42,613 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:42,613 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:42,614 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:42,614 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:42,615 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:42,615 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:42,616 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-12-02 07:09:42,617 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:42,617 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:42,617 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/cursus
# 2025-12-02 07:09:42,618 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-12-02 07:09:42,618 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-12-02 07:09:42,619 - INFO - ✅ Registry info loaded: 43 steps
# 2025-12-02 07:09:42,619 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-12-02 07:09:42,619 - INFO - Successfully discovered 75 config classes using step catalog
# 2025-12-02 07:09:42,620 - INFO - Discovered 75 config classes using step catalog
# 2025-12-02 07:09:42,620 - INFO - Loading configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,620 - INFO - Loading configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,622 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,622 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json with 10 specific configs
# 2025-12-02 07:09:42,623 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-12-02 07:09:42,624 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,624 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,625 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-12-02 07:09:42,625 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,626 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,626 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-12-02 07:09:42,627 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,627 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,628 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-12-02 07:09:42,629 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,629 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,629 - INFO - Creating additional config instance for Payload (PayloadConfig)
# 2025-12-02 07:09:42,630 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,631 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,631 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-12-02 07:09:42,632 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:42,632 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers
# 2025-12-02 07:09:42,633 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-12-02 07:09:42,633 - INFO - Creating additional config instance for Registration (RegistrationConfig)
# 2025-12-02 07:09:42,634 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-12-02 07:09:42,635 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,635 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,636 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-12-02 07:09:42,636 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,637 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers/scripts
# 2025-12-02 07:09:42,637 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,638 - INFO - Loaded 10 configurations from /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-12-02 07:09:42,638 - INFO - Initialized ExecutionDocumentGenerator with 10 configurations

# %%
execution_doc_fill = exe_doc_generator.fill_execution_document(
    dag=dag, execution_document=test_execution_doc
)
# Out:
# 2025-12-02 07:09:42,642 - INFO - Starting execution document generation for DAG with 10 nodes
# 2025-12-02 07:09:42,642 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-12-02 07:09:42,642 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-12-02 07:09:42,643 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-12-02 07:09:42,643 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-12-02 07:09:42,644 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-12-02 07:09:42,644 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-12-02 07:09:42,645 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-12-02 07:09:42,645 - INFO - Found exact key match for node 'Package'
# 2025-12-02 07:09:42,645 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:42,646 - INFO - Found exact key match for node 'Payload'
# 2025-12-02 07:09:42,646 - INFO - Found 1 relevant steps: ['Registration']
# 2025-12-02 07:09:42,646 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:42,646 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:42,647 - INFO - Processing 1 registration steps: ['Registration']
# 2025-12-02 07:09:42,648 - INFO - Found registration configuration: RegistrationConfig
# 2025-12-02 07:09:42,648 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-12-02 07:09:42,648 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-12-02 07:09:42,649 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-12-02 07:09:42,649 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-12-02 07:09:42,649 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-12-02 07:09:42,650 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-12-02 07:09:42,650 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-12-02 07:09:42,650 - INFO - Found exact key match for node 'Package'
# 2025-12-02 07:09:42,650 - INFO - Found exact key match for node 'Registration'
# 2025-12-02 07:09:42,651 - INFO - Found registration step by config type: Registration
# 2025-12-02 07:09:42,651 - INFO - Found exact key match for node 'Payload'
# 2025-12-02 07:09:42,927 - INFO - Retrieved image URI: 763104351884.dkr.ecr.us-east-1.amazonaws.com/pytorch-inference:2.1.0-cpu-py310
# 2025-12-02 07:09:42,927 - INFO - Created execution config for registration step: Registration-NA
# 2025-12-02 07:09:42,928 - INFO - Successfully generated execution document

# %%
# execution_doc_fill = pipeline_builder.fill_execution_document(test_execution_doc)

# %%
# Fill in the execution document using the stored requests
# execution_doc_fill_2 = xgboost_train_eval_pipeline_template_builder.fill_execution_document(test_execution_doc)

# %%
print(json.dumps(execution_doc_fill, indent=2))
# Out:
# {
#   "PIPELINE_STEP_CONFIGS": {
#     "PyTorchTraining": {
#       "STEP_CONFIG": {},
#       "STEP_TYPE": "TRAINING_STEP"
#     },
#     "Registration-NA": {
#       "STEP_CONFIG": {
#         "source_model_inference_image_arn": "763104351884.dkr.ecr.us-east-1.amazonaws.com/pytorch-inference:2.1.0-cpu-py310",
#         "model_domain": "BuyerSellerMessaging",
#         "model_objective": "RnR_BSM_Model_NA",
#         "source_model_inference_content_types": [
#           "text/csv"
#         ],
#         "source_model_inference_response_types": [
#           "application/json"
#         ],
#         "source_model_inference_input_variable_list": [
#           [
#             "net_conc_amt",
#             "NUMERIC"
#           ],
#           [
#             "ttm_conc_amt",
#             "NUMERIC"
#           ],
#           [
#             "ttm_conc_count",
#             "NUMERIC"
#           ],
#           [
#             "concsi",
#             "NUMERIC"
#           ],
#           [
#             "deliverable_flag",
#             "NUMERIC"
#           ],
#           [
#             "undeliverable_flag",
#             "NUMERIC"
#           ],
#           [
#             "unique_message_count",
#             "NUMERIC"
#           ],
#           [
#             "total_ship_track_events_by_order",
#             "NUMERIC"
#           ],
#           [
#             "total_unique_ship_track_events_by_order",
#             "NUMERIC"
#           ],
#           [
#             "dialogue",
#             "TEXT"
#           ],
#           [
#             "shiptrack_event_history_by_order",
#             "TEXT"
#           ]
#         ],
#         "source_model_inference_output_variable_list": {
#           "calibrated-score": "NUMERIC",
#           "custom-output-label": "TEXT",
#           "legacy-score": "NUMERIC",
#           "score-percentile": "NUMERIC"
#         },
#         "source_model_region": "us-east-1",
#         "model_owner": "amzn1.abacus.team.djmdvixm5abr3p75c5ca",
#         "model_registration_region": "NA",
#         "source_model_environment_variable_map": {
#           "SAGEMAKER_CONTAINER_LOG_LEVEL": "20",
#           "SAGEMAKER_PROGRAM": "pytorch_inference_handler.py",
#           "SAGEMAKER_REGION": "us-east-1",
#           "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#         },
#         "load_testing_info_map": {
#           "sample_payload_s3_bucket": "sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um",
#           "expected_tps": 10,
#           "max_latency_in_millisecond": 800,
#           "max_acceptable_error_rate": 0.2,
#           "instance_type_list": [
#             "ml.m5.4xlarge"
#           ]
#         }
#       },
#       "STEP_TYPE": [
#         "PROCESSING_STEP",
#         "MimsModelRegistrationProcessingStep"
#       ]
#     }
#   },
#   "PIPELINE_ADDITIONAL_PARAMS": {}
# }

# %%
test_execution_doc = execution_doc_fill.copy()

# %% [markdown]
# ### Save Execution Doc locally

# %%
PIPELINE_NAME = first_config.pipeline_name

# %%
PIPELINE_VERSION = first_config.pipeline_version

# %%
exe_doc_json_filename = f"execute_doc_{PIPELINE_NAME}_{PIPELINE_VERSION}.json"
exe_doc_file_path = config_dir / exe_doc_json_filename
exe_doc_file_path
# Out:
# PosixPath('/home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/pipeline_config/execute_doc_lukexie-BuyerAbuseRnR-pytorch-NA_1.0.0.json')

# %%
with open(exe_doc_file_path, "w") as f:
    json.dump(test_execution_doc, f, indent=2)

# %% [markdown]
# ## Execute Pipeline

# %% [markdown]
# ### Start Execution

# %%
from mods_workflow_helper.sagemaker_pipeline_helper import SagemakerPipelineHelper

# %%
security_config

# %%
template_pipeline

# %%
SagemakerPipelineHelper.start_pipeline_execution(
    pipeline=template_pipeline,
    secure_config=security_config,
    sagemaker_session=pipeline_session,
    preparation_space_local_root="/tmp",
    pipeline_execution_document=test_execution_doc,
)
# Out:
# 2025-12-02 07:09:43,226 - INFO - Apply execution document provided config {} for step PyTorchTraining.
# 2025-12-02 07:09:43,296 - INFO - Apply execution document provided config {'source_model_inference_image_arn': '763104351884.dkr.ecr.us-east-1.amazonaws.com/pytorch-inference:2.1.0-cpu-py310', 'model_domain': 'BuyerSellerMessaging', 'model_objective': 'RnR_BSM_Model_NA', 'source_model_inference_content_types': ['text/csv'], 'source_model_inference_response_types': ['application/json'], 'source_model_inference_input_variable_list': [['net_conc_amt', 'NUMERIC'], ['ttm_conc_amt', 'NUMERIC'], ['ttm_conc_count', 'NUMERIC'], ['concsi', 'NUMERIC'], ['deliverable_flag', 'NUMERIC'], ['undeliverable_flag', 'NUMERIC'], ['unique_message_count', 'NUMERIC'], ['total_ship_track_events_by_order', 'NUMERIC'], ['total_unique_ship_track_events_by_order', 'NUMERIC'], ['dialogue', 'TEXT'], ['shiptrack_event_history_by_order', 'TEXT']], 'source_model_inference_output_variable_list': {'calibrated-score': 'NUMERIC', 'custom-output-label': 'TEXT', 'legacy-score': 'NUMERIC', 'score-percentile': 'NUMERIC'}, 'source_model_region': 'us-east-1', 'model_owner': 'amzn1.abacus.team.djmdvixm5abr3p75c5ca', 'model_registration_region': 'NA', 'source_model_environment_variable_map': {'SAGEMAKER_CONTAINER_LOG_LEVEL': '20', 'SAGEMAKER_PROGRAM': 'pytorch_inference_handler.py', 'SAGEMAKER_REGION': 'us-east-1', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}, 'load_testing_info_map': {'sample_payload_s3_bucket': 'sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um', 'expected_tps': 10, 'max_latency_in_millisecond': 800, 'max_acceptable_error_rate': 0.2, 'instance_type_list': ['ml.m5.4xlarge']}, 'training_workflow_execution_id': None} for step Registration-NA.
# 2025-12-02 07:09:44,056 - INFO - Final Pipeline execution parameters applied: {'KMS_ENCRYPTION_KEY_PARAM': 'arn:aws:kms:us-east-1:601857636239:key/5e32d636-8848-43ba-bd1f-f1a1c9a06982', 'VPC_SUBNET': 'subnet-0e484e4a41446ca78', 'SECURITY_GROUP_ID': 'sg-0f97baad9c44ab543', 'EXECUTION_S3_PREFIX': 's3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline-2025-12-02-07-09-42'}
# 2025-12-02 07:10:00,416 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:02,238 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:02,293 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:02,342 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:02,659 - INFO - image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# 2025-12-02 07:10:02,681 - WARNING - Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.ResourceConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.SecurityGroupIds
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.Environment
# 2025-12-02 07:10:04,254 - INFO - Uploaded /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers to s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline/code/c5e4ba9efdca035f72a61119c632a5af27810a5632691c206cf656ff81c44af9/sourcedir.tar.gz
# 2025-12-02 07:10:04,305 - INFO - runproc.sh uploaded to s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline/code/602671d92c7eb805628d3775bd01f73cd3ef79558330597dcfd540091de6e14b/runproc.sh
# 2025-12-02 07:10:05,315 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:05,364 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:05,422 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:10,370 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:10,371 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:10,374 - INFO - Add currentOwnerAlias tag to the request for operation: CreatePipeline.
# 2025-12-02 07:10:10,374 - INFO - A creation operation CreatePipeline is detected. Apply owner tag to the request.
# 2025-12-02 07:10:10,888 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:10,957 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:10,998 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:11,064 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:11,356 - INFO - image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# 2025-12-02 07:10:11,376 - WARNING - Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.ResourceConfig.VolumeKmsKeyId
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.Subnets
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.VpcConfig.SecurityGroupIds
# sagemaker.config INFO - Applied value from config key = SageMaker.TrainingJob.Environment
# 2025-12-02 07:10:12,964 - INFO - Uploaded /home/ec2-user/SageMaker/BuyerAbuseModsTemplate/src/buyer_abuse_mods_template/rnr_pytorch_bedrock/dockers to s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline/code/c5e4ba9efdca035f72a61119c632a5af27810a5632691c206cf656ff81c44af9/sourcedir.tar.gz
# 2025-12-02 07:10:13,019 - INFO - runproc.sh uploaded to s3://sandboxdependency-abuse-secureaisandboxteamshare-1l77v9am252um/lukexie-BuyerAbuseRnR-pytorch-NA-1-0-0-pipeline/code/602671d92c7eb805628d3775bd01f73cd3ef79558330597dcfd540091de6e14b/runproc.sh
# 2025-12-02 07:10:14,029 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:14,099 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:14,163 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:14,241 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:14,242 - WARNING - Popping out 'ProcessingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2025-12-02 07:10:14,244 - WARNING - A modification operation UpdatePipeline is detected. Please make sure the resource to be modified is owned or initially created by you; Otherwise your request will be denied by target service due to lack of permission.
