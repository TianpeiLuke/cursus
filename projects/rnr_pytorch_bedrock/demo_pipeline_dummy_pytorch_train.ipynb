# %% [markdown]
# # Cursus: Automatic SageMaker (MODS) Pipeline Compiler
#
# The main contribution of this work is **Cursus**, a **compiler** that automatically generate **[MODS (Model Training Workflow Operation and Development System) Pipeline](https://w.amazon.com/bin/view/CMLS/Overview/MODS/)** base on two set of user inputs
# * The **Pipeline DAG (Directed Acylic Graph)**, which describe pipeline as a graph
# * The **Unified Config JSON**, which provides a central hub to extract all user inputs and their associated step information
#     * Run [demo_config](./demo_config.ipynb) first to generate the Unified Config JSON
#     * The config json will be saved in `./pipeling_config/xxx/` folder
#
# ![mods_pipeline_train_eval_calib](./demo/mods_pipeline_train_eval_calib.png)

# %%
import os
import json
import pandas as pd
import pickle
import sys
import subprocess
from datetime import datetime

from pathlib import Path

# %%
from pydantic import BaseModel, Field, model_validator, field_validator
from typing import List, Optional, Dict, Any, Type, Union, Tuple

# %%
from collections import (
    defaultdict,
    deque
)

# %%
import logging

# %%
logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Environment Setup

# %%
from sagemaker import Session
# Out:
# 2025-11-28 06:59:20,257 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
from sagemaker.workflow.pipeline_context import PipelineSession

# %%
bucket_name='buyer-seller-messaging-reversal'

# %%
pipeline_session = PipelineSession(default_bucket=bucket_name) # IMPORTANT now the session uses the generated sagemaker_config
# Out:
# 2025-11-28 06:59:20,661 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %%
role=PipelineSession().get_caller_identity_arn()
role
# Out:
# 2025-11-28 06:59:20,952 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# 'arn:aws:iam::178936618742:role/AmazonSageMaker-ExecutionRole-Default'

# %%
from pathlib import Path
import sys

# Get parent directory of current notebook
project_root = str(Path().absolute().parent)
if project_root not in sys.path:
    sys.path.insert(0, project_root)  
    print(f"add project root {project_root} into system")
# Out:
# add project root /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines into system

# %% [markdown]
# ## Basic Information

# %%
region_list = [
    'NA',
    'EU',
    'FE'
]

# %%
region_selection = 0

# %%
region = region_list[region_selection]
region
# Out:
# 'NA'

# %%
MODEL_CLASS='pytorch'

# %%
service_name="BuyerAbuseRnR"

# %% [markdown]
# #### Config and Hyperparameter Information

# %%
current_dir = Path.cwd()
config_dir = Path(current_dir) / 'pipeline_config'
print(config_dir)
# Out:
# /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config

# %%
#hyparam_filename = f'hyperparameters_{region}_{MODEL_CLASS}.json' #'hyperparameters.json'

# %%
pipeline_config_name = f'config.json'  #f'config_{region}.json'
pipeline_config_name
# Out:
# 'config.json'

# %%
config_path = config_dir / pipeline_config_name

# %%
config_path
# Out:
# PosixPath('/home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json')

# %% [markdown]
# ## Pipeline Imports

# %%
from enum import Enum
from pydantic import BaseModel

# %% [markdown]
# ## [Optional]: Test Config Load Functionality
#
# Please skip this section if you are not concern about the config information loaded

# %% [markdown]
# ### Hyperparameters

# %%
#from cursus.steps.hyperparams.hyperparameters_xgboost import XGBoostModelHyperparameters

# %%
#hyparam_path = config_dir / hyparam_filename
#with open(hyparam_path, 'r') as file:
#    hyperparam_dict = json.load(file)

# %%
#hyperparams = XGBoostModelHyperparameters(**hyperparam_dict)

# %%
#hyperparams.num_classes

# %%
#hyperparams.is_binary

# %% [markdown]
# ### Import Configs

# %%
from cursus.core.base.config_base import BasePipelineConfig
# Out:
# 2025-11-28 06:59:21,622 - WARNING - Could not import constants from mods_workflow_core, using local definitions
# 2025-11-28 06:59:21,863 - WARNING - CradleDataLoadingStepBuilder not available. This requires secure_ai_sandbox_workflow_python_sdk package. Import error: No module named 'secure_ai_sandbox_workflow_python_sdk'
# 2025-11-28 06:59:21,900 - WARNING - RegistrationStepBuilder not available. This requires secure_ai_sandbox_workflow_python_sdk package. Import error: No module named 'secure_ai_sandbox_workflow_python_sdk'

# %%
#from cursus.steps.configs.config_cradle_data_loading_step import (CradleDataLoadingConfig,
#                                                    MdsDataSourceConfig,
#                                                    EdxDataSourceConfig,
#                                                    DataSourceConfig,
#                                                    DataSourcesSpecificationConfig,
#                                                    JobSplitOptionsConfig,
#                                                    TransformSpecificationConfig,
#                                                    OutputSpecificationConfig,
#                                                    CradleJobSpecificationConfig
#                                                   )

# %%
from cursus.steps.configs.config_dummy_data_loading_step import DummyDataLoadingConfig
from cursus.steps.configs.config_tabular_preprocessing_step import TabularPreprocessingConfig
from cursus.steps.configs.config_bedrock_prompt_template_generation_step import BedrockPromptTemplateGenerationConfig
from cursus.steps.configs.config_bedrock_batch_processing_step import BedrockBatchProcessingConfig
from cursus.steps.configs.config_label_ruleset_generation_step import LabelRulesetGenerationConfig
from cursus.steps.configs.config_label_ruleset_execution_step import LabelRulesetExecutionConfig
from cursus.steps.configs.config_pytorch_training_step import PyTorchTrainingConfig
from cursus.steps.configs.config_pytorch_model_eval_step import PyTorchModelEvalConfig
from cursus.steps.configs.config_model_calibration_step import ModelCalibrationConfig
from cursus.steps.configs.config_package_step import PackageConfig
from cursus.steps.configs.config_payload_step import PayloadConfig

# %% [markdown]
# ### Load Config

# %%
from cursus.steps.configs.utils import serialize_config, merge_and_save_configs, load_configs, verify_configs

# %%
CONFIG_CLASSES = {
        'DummyDataLoadingConfig':                     DummyDataLoadingConfig,
        'BedrockPromptTemplateGenerationConfig':      BedrockPromptTemplateGenerationConfig,
        'BedrockBatchProcessingConfig':               BedrockBatchProcessingConfig,
        'TabularPreprocessingConfig':                 TabularPreprocessingConfig,
        'LabelRulesetGenerationConfig':               LabelRulesetGenerationConfig,
        'LabelRulesetExecutionConfig':                LabelRulesetExecutionConfig,
        'PyTorchTrainingConfig':                      PyTorchTrainingConfig,
        'PyTorchModelEvalConfig':                     PyTorchModelEvalConfig,
        'ModelCalibrationConfig':                     ModelCalibrationConfig,
        'PackageConfig':                              PackageConfig,
        'PayloadConfig':                              PayloadConfig,
    }

# %%
config_path
# Out:
# PosixPath('/home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json')

# %%
# Load configs
loaded_configs = load_configs(config_path, CONFIG_CLASSES)
# Out:
# 2025-11-28 06:59:21,970 - INFO - Loading configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:21,970 - INFO - Loading configuration from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:21,971 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:21,971 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json with 8 specific configs
# 2025-11-28 06:59:21,972 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-11-28 06:59:21,972 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:21,973 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:21,974 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-28 06:59:21,974 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:21,974 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:21,975 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:21,975 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:21,976 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-11-28 06:59:21,976 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:21,976 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:22,075 - INFO - Discovered 61 core config classes
# 2025-11-28 06:59:22,092 - INFO - Discovered 6 core hyperparameter classes
# 2025-11-28 06:59:22,120 - INFO - Discovered 7 base hyperparameter classes from core/base
# 2025-11-28 06:59:22,121 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,122 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,122 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-11-28 06:59:22,123 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,123 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,124 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-11-28 06:59:22,125 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,125 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,126 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-11-28 06:59:22,127 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,127 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,127 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-11-28 06:59:22,128 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker
# 2025-11-28 06:59:22,129 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker
# 2025-11-28 06:59:22,129 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-11-28 06:59:22,130 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-11-28 06:59:22,130 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,131 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,131 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-11-28 06:59:22,132 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,133 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:22,133 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json

# %%
loaded_configs
# Out:
# {'DummyDataLoading_calibration': DummyDataLoadingConfig(author='lukexie', bucket='buyer-seller-messaging-reversal', role='arn:aws:iam::178936618742:role/AmazonSageMaker-ExecutionRole-Default', region='NA', service_name='BuyerAbuseRnR', pipeline_version='0.0.1', model_class='pytorch', current_date='2025-11-28', framework_version='2.1.0', py_version='py310', source_dir='docker', enable_caching=False, use_secure_pypi=False, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='docker/scripts', processing_entry_point='dummy_data_loading.py', processing_script_arguments=None, processing_framework_version='1.2-1', data_source='s3://buyer-seller-messaging-reversal/pipeline/lukexie-BuyerAbuseRnR-pytorch-NA/20251111035543/labelrulesetexecution/processed_data/test', job_type='calibration', max_file_size_mb=1000, supported_formats=['csv', 'parquet', 'json', 'jsonl'], write_data_shards=True, shard_size=10000, output_format='PARQUET'),
#  'DummyDataLoading_training': DummyDataLoadingConfig(author='lukexie', bucket='buyer-seller-messaging-reversal', role='arn:aws:iam::178936618742:role/AmazonSageMaker-ExecutionRole-Default', region='NA', service_name='BuyerAbuseRnR', pipeline_version='0.0.1', model_class='pytorch', current_date='2025-11-28', framework_version='2.1.0', py_version='py310', source_dir='docker', enable_caching=False, use_secure_pypi=False, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='docker/scripts', processing_entry_point='dummy_data_loading.py', processing_script_arguments=None, processing_framework_version='1.2-1', data_source='s3://buyer-seller-messaging-reversal/pipeline/lukexie-BuyerAbuseRnR-pytorch-NA/20251111035543/labelrulesetexecution/processed_data/', job_type='training', max_file_size_mb=1000, supported_formats=['csv', 'parquet', 'json', 'jsonl'], write_data_shards=True, shard_size=10000, output_format='PARQUET'),
#  'ModelCalibration_calibration': ModelCalibrationConfig(author='lukexie', bucket='buyer-seller-messaging-reversal', role='arn:aws:iam::178936618742:role/AmazonSageMaker-ExecutionRole-Default', region='NA', service_name='BuyerAbuseRnR', pipeline_version='0.0.1', model_class='pytorch', current_date='2025-11-28', framework_version='2.1.0', py_version='py310', source_dir='docker', enable_caching=False, use_secure_pypi=False, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='docker/scripts', processing_entry_point='model_calibration.py', processing_script_arguments=None, processing_framework_version='1.2-1', label_field='llm_reversal_flag', score_field='prob_class_1', score_fields=None, calibration_method='gam', monotonic_constraint=True, gam_splines=10, error_threshold=0.05, is_binary=True, num_classes=2, score_field_prefix='prob_class_', calibration_sample_points=1000, multiclass_categories=[0, 1], job_type='calibration'),
#  'Package': PackageConfig(author='lukexie', bucket='buyer-seller-messaging-reversal', role='arn:aws:iam::178936618742:role/AmazonSageMaker-ExecutionRole-Default', region='NA', service_name='BuyerAbuseRnR', pipeline_version='0.0.1', model_class='pytorch', current_date='2025-11-28', framework_version='2.1.0', py_version='py310', source_dir='docker', enable_caching=False, use_secure_pypi=False, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=False, processing_source_dir='docker/scripts', processing_entry_point='package.py', processing_script_arguments=None, processing_framework_version='1.2-1'),
#  'PyTorchModelEval_calibration': PyTorchModelEvalConfig(author='lukexie', bucket='buyer-seller-messaging-reversal', role='arn:aws:iam::178936618742:role/AmazonSageMaker-ExecutionRole-Default', region='NA', service_name='BuyerAbuseRnR', pipeline_version='0.0.1', model_class='pytorch', current_date='2025-11-28', framework_version='2.1.0', py_version='py310', source_dir='docker', enable_caching=False, use_secure_pypi=False, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.g5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='docker', processing_entry_point='pytorch_model_eval.py', processing_script_arguments=None, processing_framework_version='2.1.2', id_name='order_id', label_name='llm_reversal_flag', job_type='calibration', eval_metric_choices=['auroc', 'average_precision', 'f1_score'], ca_repository_arn='arn:aws:codeartifact:us-west-2:149122183214:repository/amazon/secure-pypi', comparison_mode=False, previous_score_field='', comparison_metrics='all', statistical_tests=True, comparison_plots=True),
#  'PyTorchTraining': PyTorchTrainingConfig(author='lukexie', bucket='buyer-seller-messaging-reversal', role='arn:aws:iam::178936618742:role/AmazonSageMaker-ExecutionRole-Default', region='NA', service_name='BuyerAbuseRnR', pipeline_version='0.0.1', model_class='pytorch', current_date='2025-11-28', framework_version='2.1.0', py_version='py310', source_dir='docker', enable_caching=False, use_secure_pypi=False, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', training_entry_point='pytorch_training.py', training_instance_type='ml.p3.16xlarge', training_instance_count=1, training_volume_size=800, ca_repository_arn='arn:aws:codeartifact:us-west-2:149122183214:repository/amazon/secure-pypi', skip_hyperparameters_s3_uri=True, hyperparameters=None),
#  'TabularPreprocessing_calibration': TabularPreprocessingConfig(author='lukexie', bucket='buyer-seller-messaging-reversal', role='arn:aws:iam::178936618742:role/AmazonSageMaker-ExecutionRole-Default', region='NA', service_name='BuyerAbuseRnR', pipeline_version='0.0.1', model_class='pytorch', current_date='2025-11-28', framework_version='2.1.0', py_version='py310', source_dir='docker', enable_caching=False, use_secure_pypi=False, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='docker/scripts', processing_entry_point='tabular_preprocessing.py', processing_script_arguments=None, processing_framework_version='1.2-1', job_type='calibration', label_name=None, train_ratio=0.7, test_val_ratio=0.5, output_format='Parquet'),
#  'TabularPreprocessing_training': TabularPreprocessingConfig(author='lukexie', bucket='buyer-seller-messaging-reversal', role='arn:aws:iam::178936618742:role/AmazonSageMaker-ExecutionRole-Default', region='NA', service_name='BuyerAbuseRnR', pipeline_version='0.0.1', model_class='pytorch', current_date='2025-11-28', framework_version='2.1.0', py_version='py310', source_dir='docker', enable_caching=False, use_secure_pypi=False, max_runtime_seconds=172800, project_root_folder='rnr_pytorch_bedrock', processing_instance_count=1, processing_volume_size=500, processing_instance_type_large='ml.m5.12xlarge', processing_instance_type_small='ml.m5.4xlarge', use_large_processing_instance=True, processing_source_dir='docker/scripts', processing_entry_point='tabular_preprocessing.py', processing_script_arguments=None, processing_framework_version='1.2-1', job_type='training', label_name='llm_reversal_flag', train_ratio=0.7, test_val_ratio=0.5, output_format='Parquet')}

# %%
len(loaded_configs)
# Out:
# 8

# %%
[str(k) for k in loaded_configs.keys()]
# Out:
# ['DummyDataLoading_calibration',
#  'DummyDataLoading_training',
#  'ModelCalibration_calibration',
#  'Package',
#  'PyTorchModelEval_calibration',
#  'PyTorchTraining',
#  'TabularPreprocessing_calibration',
#  'TabularPreprocessing_training']

# %%
first_config = next(iter(loaded_configs.values()))

# %%
PIPELINE_VERSION = first_config.pipeline_version

# %%
PIPELINE_DESCRIPTION = first_config.pipeline_description

# %%
PIPELINE_NAME = first_config.pipeline_name

# %% [markdown]
# ## Parameter Setup

# %%
import boto3
from sagemaker.workflow.pipeline_context import PipelineSession

# Initialize boto3 clients
ec2_client = boto3.client('ec2')
kms_client = boto3.client('kms')
sts_client = boto3.client('sts')

# Get account and region info
account_id = sts_client.get_caller_identity()['Account']
region = boto3.Session().region_name
# Out:
# 2025-11-28 06:59:22,192 - INFO - Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole

# %% [markdown]
# ### Find VPC Subnet - Get default VPC subnets or list all

# %%
response = ec2_client.describe_subnets(
    Filters=[{'Name': 'default-for-az', 'Values': ['true']}]
)
vpc_subnet_id = response['Subnets'][0]['SubnetId'] if response['Subnets'] else None

# OR list all subnets and choose one
#all_subnets = ec2_client.describe_subnets()
#for subnet in all_subnets['Subnets']:
#    print(f"Subnet ID: {subnet['SubnetId']}, VPC: {subnet['VpcId']}, AZ: {subnet['AvailabilityZone']}")

# %% [markdown]
# ### Find Security Group - Get default or list all

# %%
response = ec2_client.describe_security_groups(
    Filters=[{'Name': 'group-name', 'Values': ['default']}]
)
security_group_id = response['SecurityGroups'][0]['GroupId'] if response['SecurityGroups'] else None

# OR list all security groups
#all_sgs = ec2_client.describe_security_groups()
#for sg in all_sgs['SecurityGroups']:
#    print(f"SG ID: {sg['GroupId']}, Name: {sg['GroupName']}, VPC: {sg.get('VpcId')}")

# %% [markdown]
# ### Find KMS Key - List KMS keys for SageMaker

# %%
response = kms_client.list_aliases()
for alias in response['Aliases']:
    if 'sagemaker' in alias['AliasName'].lower():
        print(f"KMS Alias: {alias['AliasName']}, Key ID: {alias.get('TargetKeyId')}")

# OR get account's default KMS key ARN
kms_key_id = f"arn:aws:kms:{region}:{account_id}:alias/aws/sagemaker"

# %%
print(f"\nFound values:")
print(f"VPC Subnet: {vpc_subnet_id}")
print(f"Security Group: {security_group_id}")
print(f"KMS Key: {kms_key_id}")
# Out:
# Found values:
# VPC Subnet: subnet-45db3e4b
# Security Group: sg-e116c4be
# KMS Key: arn:aws:kms:us-east-1:178936618742:alias/aws/sagemaker

# %% [markdown]
# ### Execution Id

# %%
execution_id = datetime.now().strftime("%Y%m%d%H%M%S")

# %% [markdown]
# ### Define Parameter String

# %%
from sagemaker.network import NetworkConfig
from sagemaker.processing import ProcessingInput
from sagemaker.workflow.functions import Join
from sagemaker.workflow.parameters import ParameterString

# %%
# Predefined Pipeline Parameters
PIPELINE_EXECUTION_TEMP_DIR = ParameterString(name="EXECUTION_S3_PREFIX", default_value=f"s3://{bucket_name}/pipeline/{PIPELINE_NAME}/{execution_id}")
KMS_ENCRYPTION_KEY_PARAM = ParameterString(name="KMS_ENCRYPTION_KEY_PARAM", default_value=kms_key_id)
VPC_SUBNET = ParameterString(
    name="VPC_SUBNET",
    default_value=vpc_subnet_id
)  # TODO: test if we can replace it with multiple subnets
SECURITY_GROUP_ID = ParameterString(name="SECURITY_GROUP_ID", default_value=security_group_id)
PROCESSING_JOB_SHARED_NETWORK_CONFIG = NetworkConfig(
    enable_network_isolation=False,
    security_group_ids=[SECURITY_GROUP_ID],
    subnets=[VPC_SUBNET],
    encrypt_inter_container_traffic=True,
)

# %% [markdown]
# ## Import Packages

# %%
from abc import ABC, abstractmethod
from typing import Dict, List, Any, Optional, Type
from pathlib import Path
import logging
import os
import importlib

# %%
import sagemaker
from sagemaker import Session
from sagemaker.workflow.pipeline import Pipeline
from sagemaker.workflow.parameters import ParameterString
from sagemaker.workflow.parameters import Parameter
from sagemaker.workflow.properties import Properties
from sagemaker.workflow.pipeline_context import PipelineSession # Crucial import

# %% [markdown]
# ## Demo: An End-to-End Pipeline based on PipelineDAG Compiler
# Let us use the following simpler DAG (without registration as example)
#
#
# In this demo there are several user input
# * the **Unified JSON file** in `config_path`
# * the **Registry Manager**: an object that handles the map between step logical name to `step.properties`
# * the **Dependency Resolver**: an object than handles the *automatic dependency resolution* between steps
# * the other fields
#     * `sagemaker_session`: pipelne session
#     * `role`: IAM Role
#     * `notebook_root`: track the root path
#
#
# In this pipeline template, we inherit from base class `PipelineTemplateBase`.
#
# The **major tasks** are
# * *`Config` Classes Import*
# * *Configuration Validation*
# * *Step Builder Retrieval and Step Builder Map Creation*
# * *Configuration Map Creation*
# * **Pipeline DAG Generation**: ideally, user should create this DAG and use it as input
# * **Automatic Pipeline Assemble**: Call `pipeline_assembler`

# %% [markdown]
# ### DAG to Template Compiler

# %%
from cursus.api.dag.base_dag import PipelineDAG
from cursus.core.compiler.dag_compiler import compile_dag_to_pipeline, PipelineDAGCompiler
from cursus.core.compiler.validation import ConversionReport
from cursus.steps.configs.utils import load_configs

# %%
def create_bedrock_batch_pytorch_with_label_ruleset_e2e_dag() -> PipelineDAG:
    """
    Create a DAG for Bedrock Batch-enhanced PyTorch E2E pipeline with Label Ruleset steps.

    This DAG represents a complete end-to-end workflow that uses:
    1. Bedrock prompt template generation and batch processing for LLM-enhanced data
    2. Label ruleset generation and execution for transparent label transformation
    3. PyTorch training, followed by calibration, packaging, and registration

    The label ruleset steps sit between Bedrock processing and training/evaluation,
    providing transparent, rule-based label transformation that's easy to modify.

    Returns:
        PipelineDAG: The directed acyclic graph for the pipeline
    """
    dag = PipelineDAG()

    # Add all nodes - incorporating Bedrock batch processing and label ruleset steps
    dag.add_node("DummyDataLoading_training")  # Dummy data load for training
    dag.add_node("TabularPreprocessing_training")  # Tabular preprocessing for training
    #dag.add_node(
    #    "BedrockPromptTemplateGeneration"
    #)  # Bedrock prompt template generation (shared)
    #dag.add_node(
    #    "BedrockBatchProcessing_training"
    #)  # Bedrock batch processing step for training
    #dag.add_node(
    #    "LabelRulesetGeneration"
    #)  # Label ruleset generation (shared for training and calibration)
    #dag.add_node(
    #    "LabelRulesetExecution_training"
    #)  # Label ruleset execution for training data
    dag.add_node("PyTorchTraining")  # PyTorch training step
    #dag.add_node(
    #    "ModelCalibration_calibration"
    #)  # Model calibration step with calibration variant
    #dag.add_node("Package")  # Package step
    #dag.add_node("Registration")  # MIMS registration step
    #dag.add_node("Payload")  # Payload step
    #dag.add_node("DummyDataLoading_calibration")  # Dummy data load for calibration
    #dag.add_node(
    #    "TabularPreprocessing_calibration"
    #)  # Tabular preprocessing for calibration
    #dag.add_node(
    #    "BedrockBatchProcessing_calibration"
    #)  # Bedrock batch processing step for calibration
    #dag.add_node(
    #    "LabelRulesetExecution_calibration"
    #)  # Label ruleset execution for calibration data
    #dag.add_node("PyTorchModelEval_calibration")  # Model evaluation step

    # Training flow with Bedrock batch processing and label ruleset integration
    dag.add_edge("DummyDataLoading_training", "TabularPreprocessing_training")
    dag.add_edge(
        "TabularPreprocessing_training", "PyTorchTraining"
    )  # Data input
    
    # Bedrock batch processing flow for training - two inputs to BedrockBatchProcessing_training
    dag.add_edge(
        "TabularPreprocessing_training", "BedrockBatchProcessing_training"
    )  # Data input
    dag.add_edge(
        "BedrockPromptTemplateGeneration", "BedrockBatchProcessing_training"
    )  # Template input

    # Label ruleset execution for training - two inputs to LabelRulesetExecution_training
    dag.add_edge(
        "BedrockBatchProcessing_training", "LabelRulesetExecution_training"
    )  # Data input
    dag.add_edge(
        "LabelRulesetGeneration", "LabelRulesetExecution_training"
    )  # Ruleset input

    # Labeled data flows to PyTorch training
    dag.add_edge("LabelRulesetExecution_training", "PyTorchTraining")

    # Calibration flow with Bedrock batch processing and label ruleset integration
    #dag.add_edge("DummyDataLoading_calibration", "TabularPreprocessing_calibration")

    # Bedrock batch processing flow for calibration - two inputs to BedrockBatchProcessing_calibration
    #dag.add_edge(
    #    "TabularPreprocessing_calibration", "BedrockBatchProcessing_calibration"
    #)  # Data input
    #dag.add_edge(
    #    "BedrockPromptTemplateGeneration", "BedrockBatchProcessing_calibration"
    #)  # Template input

    # Label ruleset execution for calibration - two inputs to LabelRulesetExecution_calibration
    #dag.add_edge(
    #    "BedrockBatchProcessing_calibration", "LabelRulesetExecution_calibration"
    #)  # Data input
    #dag.add_edge(
    #    "LabelRulesetGeneration", "LabelRulesetExecution_calibration"
    #)  # Ruleset input

    # Evaluation flow
    #dag.add_edge("PyTorchTraining", "PyTorchModelEval_calibration")
    #dag.add_edge(
    #    "LabelRulesetExecution_calibration", "PyTorchModelEval_calibration"
    #)  # Use labeled calibration data

    # Model calibration flow - depends on model evaluation
    #dag.add_edge("PyTorchModelEval_calibration", "ModelCalibration_calibration")

    # Output flow
    #dag.add_edge("ModelCalibration_calibration", "Package")
    #dag.add_edge("PyTorchTraining", "Package")  # Raw model is also input to packaging
    #dag.add_edge("PyTorchTraining", "Payload")  # Payload test uses the raw model
    #dag.add_edge("Package", "Registration")
    #dag.add_edge("Payload", "Registration")

    logger.info(
        f"Created Bedrock Batch-PyTorch with Label Ruleset E2E DAG with {len(dag.nodes)} nodes and {len(dag.edges)} edges"
    )
    return dag

# %%
def create_bedrock_batch_pytorch_with_label_ruleset_e2e_dag() -> PipelineDAG:
    """
    Create a complete end-to-end XGBoost pipeline DAG.
    
    This DAG represents the same workflow as the legacy demo_config.ipynb
    but in a structured, reusable format.
    
    Returns:
        PipelineDAG: The directed acyclic graph for the pipeline
    """
    dag = PipelineDAG()
    
    # Add all nodes - matching the structure from demo_config.ipynb
    dag.add_node("DummyDataLoading_training")      # Training data loading
    dag.add_node("TabularPreprocessing_training")   # Training data preprocessing
    dag.add_node("PyTorchTraining")                 # XGBoost model training

    dag.add_node("DummyDataLoading_calibration")  # Dummy data load for calibration
    dag.add_node(
        "TabularPreprocessing_calibration"
    )  # Tabular preprocessing for calibration
    dag.add_node("PyTorchModelEval_calibration")  # Model evaluation step
    dag.add_node(
        "ModelCalibration_calibration"
    )  # Model calibration step with calibration variant
    dag.add_node("Package")  # Package step
    
    # Define dependencies - training flow
    dag.add_edge("DummyDataLoading_training", "TabularPreprocessing_training")
    dag.add_edge("TabularPreprocessing_training", "PyTorchTraining")

    # Calibration flow with Bedrock batch processing and label ruleset integration
    dag.add_edge("DummyDataLoading_calibration", "TabularPreprocessing_calibration")

    # Evaluation flow
    dag.add_edge("PyTorchTraining", "PyTorchModelEval_calibration")
    dag.add_edge(
        "TabularPreprocessing_calibration", "PyTorchModelEval_calibration"
    )  # Use labeled calibration data
    # Model calibration flow - depends on model evaluation
    dag.add_edge("PyTorchModelEval_calibration", "ModelCalibration_calibration")

    # Output flow
    dag.add_edge("ModelCalibration_calibration", "Package")
    dag.add_edge("PyTorchTraining", "Package")  # Raw model is also input to packaging
    
    logger.info(f"Created XGBoost E2E DAG with {len(dag.nodes)} nodes and {len(dag.edges)} edges")
    return dag

# %%
dag = create_bedrock_batch_pytorch_with_label_ruleset_e2e_dag()
# Out:
# 2025-11-28 06:59:23,052 - INFO - Added node: DummyDataLoading_training
# 2025-11-28 06:59:23,052 - INFO - Added node: TabularPreprocessing_training
# 2025-11-28 06:59:23,052 - INFO - Added node: PyTorchTraining
# 2025-11-28 06:59:23,053 - INFO - Added node: DummyDataLoading_calibration
# 2025-11-28 06:59:23,053 - INFO - Added node: TabularPreprocessing_calibration
# 2025-11-28 06:59:23,054 - INFO - Added node: PyTorchModelEval_calibration
# 2025-11-28 06:59:23,054 - INFO - Added node: ModelCalibration_calibration
# 2025-11-28 06:59:23,054 - INFO - Added node: Package
# 2025-11-28 06:59:23,055 - INFO - Added edge: DummyDataLoading_training -> TabularPreprocessing_training
# 2025-11-28 06:59:23,055 - INFO - Added edge: TabularPreprocessing_training -> PyTorchTraining
# 2025-11-28 06:59:23,055 - INFO - Added edge: DummyDataLoading_calibration -> TabularPreprocessing_calibration
# 2025-11-28 06:59:23,056 - INFO - Added edge: PyTorchTraining -> PyTorchModelEval_calibration
# 2025-11-28 06:59:23,056 - INFO - Added edge: TabularPreprocessing_calibration -> PyTorchModelEval_calibration
# 2025-11-28 06:59:23,056 - INFO - Created XGBoost E2E DAG with 8 nodes and 5 edges

# %%
pipeline_parameters = [
    PIPELINE_EXECUTION_TEMP_DIR,
    KMS_ENCRYPTION_KEY_PARAM,
    SECURITY_GROUP_ID,
    VPC_SUBNET,
]

# %%
dag_compiler = PipelineDAGCompiler(
    config_path=config_path,
    sagemaker_session=pipeline_session,
    role=role,
    pipeline_parameters=pipeline_parameters
)
# Out:
# 2025-11-28 06:59:23,067 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,067 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,068 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-28 06:59:23,068 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,068 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,069 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,069 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,069 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-11-28 06:59:23,070 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,070 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,071 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,071 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,072 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-28 06:59:23,072 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,073 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,073 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,074 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,074 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-11-28 06:59:23,075 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,075 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully

# %% [markdown]
# ### Create a Pipeline

# %% [markdown]
# #### DAG Validation and Preview of Config Resolution

# %%
preview_only = True

# %%
if preview_only:
    preview = dag_compiler.preview_resolution(dag)
    logger.info("DAG node resolution preview:")
    for node, config_type in preview.node_config_map.items():
        confidence = preview.resolution_confidence.get(node, 0.0)
        logger.info(f"  {node} → {config_type} (confidence: {confidence:.2f})")
        
    if preview.recommendations:
        logger.info("Recommendations:")
        for recommendation in preview.recommendations:
            logger.info(f"  - {recommendation}")
        
    validation = dag_compiler.validate_dag_compatibility(dag)
    logger.info(f"DAG validation: {'VALID' if validation.is_valid else 'INVALID'}")
    if not validation.is_valid:
        if validation.missing_configs:
            logger.warning(f"Missing configs: {validation.missing_configs}")
        if validation.unresolvable_builders:
            logger.warning(f"Unresolvable builders: {validation.unresolvable_builders}")
        if validation.config_errors:
            logger.warning(f"Config errors: {validation.config_errors}")
# Out:
# 2025-11-28 06:59:23,084 - INFO - Previewing resolution for 8 DAG nodes
# 2025-11-28 06:59:23,085 - INFO - Creating template for DAG with 8 nodes
# 2025-11-28 06:59:23,085 - WARNING - Could not import config_class_detector, using fallback implementation
# 2025-11-28 06:59:23,085 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,086 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,087 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-28 06:59:23,087 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,087 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,088 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,088 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,088 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-11-28 06:59:23,089 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,090 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,090 - INFO - Successfully discovered 74 config classes using step catalog
# 2025-11-28 06:59:23,091 - INFO - Loading configs from: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,091 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,091 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,092 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-28 06:59:23,093 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,093 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,093 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,094 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,094 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-11-28 06:59:23,094 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,095 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,095 - INFO - Successfully discovered 74 config classes using step catalog
# 2025-11-28 06:59:23,096 - INFO - Loading configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,097 - INFO - Loading configuration from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,098 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,098 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json with 8 specific configs
# 2025-11-28 06:59:23,099 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-11-28 06:59:23,099 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,100 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,100 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-11-28 06:59:23,101 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,101 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,102 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-11-28 06:59:23,102 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,103 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,103 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-11-28 06:59:23,104 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,104 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,105 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-11-28 06:59:23,106 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker
# 2025-11-28 06:59:23,106 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker
# 2025-11-28 06:59:23,107 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-11-28 06:59:23,107 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-11-28 06:59:23,108 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,108 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,109 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-11-28 06:59:23,110 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,110 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,111 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,111 - INFO - Loaded raw configuration data from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,112 - INFO - Initialized registry manager with workspace context: None
# 2025-11-28 06:59:23,112 - INFO - Created specification registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-11-28 06:59:23,114 - INFO - Created new workspace-aware registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-11-28 06:59:23,114 - INFO - Created registry manager for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-11-28 06:59:23,115 - INFO - Created dependency resolver for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-11-28 06:59:23,115 - INFO - Validating dynamic pipeline configuration
# 2025-11-28 06:59:23,115 - INFO - Resolving 8 DAG nodes to configurations
# 2025-11-28 06:59:23,116 - INFO - Using metadata from loaded configuration
# 2025-11-28 06:59:23,116 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-11-28 06:59:23,117 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-28 06:59:23,117 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-11-28 06:59:23,117 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-11-28 06:59:23,118 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-28 06:59:23,118 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-11-28 06:59:23,118 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-28 06:59:23,119 - INFO - Found exact key match for node 'Package'
# 2025-11-28 06:59:23,119 - INFO - Successfully resolved all 8 nodes
# 2025-11-28 06:59:23,126 - INFO - Index built successfully in 0.007s with 86 steps
# 2025-11-28 06:59:23,149 - WARNING - Error loading class RegistrationStepBuilder from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/steps/builders/builder_registration_step.py (relative module: ..steps.builders.builder_registration_step): No module named 'secure_ai_sandbox_workflow_python_sdk'
# 2025-11-28 06:59:23,179 - WARNING - Error loading class CradleDataLoadingStepBuilder from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/steps/builders/builder_cradle_data_loading_step.py (relative module: ..steps.builders.builder_cradle_data_loading_step): No module named 'secure_ai_sandbox_workflow_python_sdk'
# 2025-11-28 06:59:23,191 - INFO - Builder discovery complete: 36 builders found
# 2025-11-28 06:59:23,191 - INFO - Using 40 registered step builders from StepCatalog
# 2025-11-28 06:59:23,192 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,192 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,193 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,194 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,194 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-11-28 06:59:23,194 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-11-28 06:59:23,195 - INFO - Configuration validation passed successfully
# 2025-11-28 06:59:23,195 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-0.0.1-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-0-0-1-pipeline' to conform to SageMaker constraints
# 2025-11-28 06:59:23,196 - INFO - Initialized template for: lukexie-BuyerAbuseRnR-pytorch-NA-0-0-1-pipeline
# 2025-11-28 06:59:23,196 - INFO - Successfully created template
# 2025-11-28 06:59:23,197 - INFO - Using metadata.config_types mapping with 8 entries
# 2025-11-28 06:59:23,197 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-11-28 06:59:23,198 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-28 06:59:23,198 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-11-28 06:59:23,198 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-11-28 06:59:23,199 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-28 06:59:23,199 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-11-28 06:59:23,199 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-28 06:59:23,200 - INFO - Found exact key match for node 'Package'
# 2025-11-28 06:59:23,200 - ERROR - Failed to generate resolution preview: 0
# 2025-11-28 06:59:23,201 - INFO - DAG node resolution preview:
# 2025-11-28 06:59:23,202 - INFO - Recommendations:
# 2025-11-28 06:59:23,202 - INFO -   - Preview failed: 0
# 2025-11-28 06:59:23,202 - INFO - Validating DAG compatibility for 8 nodes
# 2025-11-28 06:59:23,202 - INFO - Creating template for DAG with 8 nodes
# 2025-11-28 06:59:23,203 - INFO - Loading configs from: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,203 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,204 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,205 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-28 06:59:23,205 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,205 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,206 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,206 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,206 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-11-28 06:59:23,207 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,207 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,207 - INFO - Successfully discovered 74 config classes using step catalog
# 2025-11-28 06:59:23,208 - INFO - Loading configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,208 - INFO - Loading configuration from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,210 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,210 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json with 8 specific configs
# 2025-11-28 06:59:23,211 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-11-28 06:59:23,211 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,212 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,212 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-11-28 06:59:23,213 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,213 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,214 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-11-28 06:59:23,214 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,215 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,216 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-11-28 06:59:23,216 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,217 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,217 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-11-28 06:59:23,218 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker
# 2025-11-28 06:59:23,218 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker
# 2025-11-28 06:59:23,219 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-11-28 06:59:23,219 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-11-28 06:59:23,220 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,221 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,221 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-11-28 06:59:23,222 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,222 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,223 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,224 - INFO - Loaded raw configuration data from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,224 - INFO - Initialized registry manager with workspace context: None
# 2025-11-28 06:59:23,224 - INFO - Created specification registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-11-28 06:59:23,225 - INFO - Created new workspace-aware registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-11-28 06:59:23,226 - INFO - Created registry manager for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-11-28 06:59:23,226 - INFO - Created dependency resolver for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-11-28 06:59:23,226 - INFO - Validating dynamic pipeline configuration
# 2025-11-28 06:59:23,227 - INFO - Resolving 8 DAG nodes to configurations
# 2025-11-28 06:59:23,227 - INFO - Using metadata from loaded configuration
# 2025-11-28 06:59:23,227 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-11-28 06:59:23,228 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-28 06:59:23,228 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-11-28 06:59:23,228 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-11-28 06:59:23,229 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-28 06:59:23,229 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-11-28 06:59:23,229 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-28 06:59:23,230 - INFO - Found exact key match for node 'Package'
# 2025-11-28 06:59:23,230 - INFO - Successfully resolved all 8 nodes
# 2025-11-28 06:59:23,231 - INFO - Using 40 registered step builders from StepCatalog
# 2025-11-28 06:59:23,231 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,231 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,232 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,232 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,232 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-11-28 06:59:23,233 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-11-28 06:59:23,233 - INFO - Configuration validation passed successfully
# 2025-11-28 06:59:23,236 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-0.0.1-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-0-0-1-pipeline' to conform to SageMaker constraints
# 2025-11-28 06:59:23,236 - INFO - Initialized template for: lukexie-BuyerAbuseRnR-pytorch-NA-0-0-1-pipeline
# 2025-11-28 06:59:23,236 - INFO - Successfully created template
# 2025-11-28 06:59:23,237 - INFO - Validation completed: ✅ Validation passed
# 2025-11-28 06:59:23,237 - INFO - DAG validation: VALID

# %% [markdown]
# ### Put it Together: Pipeline Generation from DAG

# %%
# Convert DAG to pipeline and get report
try:
    logger.info(f"Converting DAG to pipeline")
    template_pipeline, report = dag_compiler.compile_with_report(
        dag=dag
    )
        
    # Log report summary
    logger.info(f"Conversion complete: {report.summary()}")
    for node, details in report.resolution_details.items():
        logger.info(f"  {node} → {details['config_type']} ({details['builder_type']})")
        
    # Log pipeline creation details
    logger.info(f"Pipeline '{template_pipeline.name}' created successfully")
    logger.info(f"Pipeline ARN: {template_pipeline.arn if hasattr(template_pipeline, 'arn') else 'Not available until upserted'}")
    logger.info("To upsert the pipeline, call pipeline.upsert()")       
except Exception as e:
    logger.error(f"Failed to convert DAG to pipeline: {e}")
    raise
# Out:
# 2025-11-28 06:59:23,242 - INFO - Converting DAG to pipeline
# 2025-11-28 06:59:23,243 - INFO - Compiling DAG with detailed reporting
# 2025-11-28 06:59:23,243 - INFO - Compiling DAG with 8 nodes to pipeline
# 2025-11-28 06:59:23,244 - INFO - Creating template for DAG with 8 nodes
# 2025-11-28 06:59:23,244 - INFO - Loading configs from: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,245 - INFO - 🔧 BuilderAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,245 - INFO - 🔧 BuilderAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,246 - INFO - ✅ BuilderAutoDiscovery basic initialization complete
# 2025-11-28 06:59:23,246 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,247 - INFO - 🎉 BuilderAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,247 - INFO - 🔍 ScriptAutoDiscovery.__init__ starting - package_root: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus
# 2025-11-28 06:59:23,248 - INFO - 🔍 ScriptAutoDiscovery.__init__ - workspace_dirs: []
# 2025-11-28 06:59:23,248 - INFO - 🔍 ScriptAutoDiscovery.__init__ - priority_workspace_dir: None
# 2025-11-28 06:59:23,248 - INFO - ✅ Registry info loaded: 41 steps
# 2025-11-28 06:59:23,249 - INFO - 🎉 ScriptAutoDiscovery initialization completed successfully
# 2025-11-28 06:59:23,249 - INFO - Successfully discovered 74 config classes using step catalog
# 2025-11-28 06:59:23,250 - INFO - Loading configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,251 - INFO - Loading configuration from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,252 - INFO - Successfully loaded configuration from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,252 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json with 8 specific configs
# 2025-11-28 06:59:23,253 - INFO - Creating additional config instance for DummyDataLoading_calibration (DummyDataLoadingConfig)
# 2025-11-28 06:59:23,253 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,254 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,255 - INFO - Creating additional config instance for DummyDataLoading_training (DummyDataLoadingConfig)
# 2025-11-28 06:59:23,256 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,256 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,257 - INFO - Creating additional config instance for ModelCalibration_calibration (ModelCalibrationConfig)
# 2025-11-28 06:59:23,257 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,258 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,258 - INFO - Creating additional config instance for Package (PackageConfig)
# 2025-11-28 06:59:23,259 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,260 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,260 - INFO - Creating additional config instance for PyTorchModelEval_calibration (PyTorchModelEvalConfig)
# 2025-11-28 06:59:23,261 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker
# 2025-11-28 06:59:23,261 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker
# 2025-11-28 06:59:23,262 - INFO - Creating additional config instance for PyTorchTraining (PyTorchTrainingConfig)
# 2025-11-28 06:59:23,263 - INFO - Creating additional config instance for TabularPreprocessing_calibration (TabularPreprocessingConfig)
# 2025-11-28 06:59:23,264 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,264 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,265 - INFO - Creating additional config instance for TabularPreprocessing_training (TabularPreprocessingConfig)
# 2025-11-28 06:59:23,265 - INFO - Package location discovery succeeded (bundled): /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,266 - INFO - Hybrid resolution completed successfully via Package Location Discovery: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts
# 2025-11-28 06:59:23,266 - INFO - Successfully loaded configs from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,267 - INFO - Loaded raw configuration data from /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/pipeline_config/config.json
# 2025-11-28 06:59:23,268 - INFO - Initialized registry manager with workspace context: None
# 2025-11-28 06:59:23,268 - INFO - Created specification registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-11-28 06:59:23,269 - INFO - Created new workspace-aware registry for context 'lukexie-BuyerAbuseRnR-pytorch-NA'
# 2025-11-28 06:59:23,270 - INFO - Created registry manager for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-11-28 06:59:23,270 - INFO - Created dependency resolver for context: lukexie-BuyerAbuseRnR-pytorch-NA
# 2025-11-28 06:59:23,271 - INFO - Skipping configuration validation (requested)
# 2025-11-28 06:59:23,271 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-0.0.1-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-0-0-1-pipeline' to conform to SageMaker constraints
# 2025-11-28 06:59:23,271 - INFO - Initialized template for: lukexie-BuyerAbuseRnR-pytorch-NA-0-0-1-pipeline
# 2025-11-28 06:59:23,272 - INFO - Successfully created template
# 2025-11-28 06:59:23,273 - INFO - Pipeline name 'lukexie-BuyerAbuseRnR-pytorch-NA-0.0.1-pipeline' sanitized to 'lukexie-BuyerAbuseRnR-pytorch-NA-0-0-1-pipeline' to conform to SageMaker constraints
# 2025-11-28 06:59:23,273 - INFO - Generating pipeline: lukexie-BuyerAbuseRnR-pytorch-NA-0-0-1-pipeline
# 2025-11-28 06:59:23,274 - INFO - Resolving 8 DAG nodes to configurations
# 2025-11-28 06:59:23,274 - INFO - Using metadata from loaded configuration
# 2025-11-28 06:59:23,274 - INFO - Found exact key match for node 'DummyDataLoading_training'
# 2025-11-28 06:59:23,275 - INFO - Found exact key match for node 'TabularPreprocessing_training'
# 2025-11-28 06:59:23,275 - INFO - Found exact key match for node 'PyTorchTraining'
# 2025-11-28 06:59:23,275 - INFO - Found exact key match for node 'DummyDataLoading_calibration'
# 2025-11-28 06:59:23,276 - INFO - Found exact key match for node 'TabularPreprocessing_calibration'
# 2025-11-28 06:59:23,276 - INFO - Found exact key match for node 'PyTorchModelEval_calibration'
# 2025-11-28 06:59:23,276 - INFO - Found exact key match for node 'ModelCalibration_calibration'
# 2025-11-28 06:59:23,277 - INFO - Found exact key match for node 'Package'
# 2025-11-28 06:59:23,277 - INFO - Successfully resolved all 8 nodes
# 2025-11-28 06:59:23,279 - INFO - Using 40 registered step builders from StepCatalog
# 2025-11-28 06:59:23,279 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,280 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,280 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,281 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,281 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-11-28 06:59:23,282 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-11-28 06:59:23,282 - INFO - Using provided StepCatalog instance
# 2025-11-28 06:59:23,283 - INFO - Using stored custom pipeline parameters
# 2025-11-28 06:59:23,283 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,284 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,284 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,285 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,286 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-11-28 06:59:23,286 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-11-28 06:59:23,286 - INFO - Input validation successful
# 2025-11-28 06:59:23,287 - INFO - Initializing step builders
# 2025-11-28 06:59:23,287 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_training': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,288 - INFO - Using unified DUMMY_DATA_LOADING_SPEC for all job types
# 2025-11-28 06:59:23,289 - INFO - Initializing DummyDataLoadingStepBuilder with region: NA
# 2025-11-28 06:59:23,289 - INFO - Validating DummyDataLoadingConfig...
# 2025-11-28 06:59:23,289 - INFO - DummyDataLoadingConfig validation succeeded.
# 2025-11-28 06:59:23,290 - INFO - Set execution prefix for DummyDataLoading_training
# 2025-11-28 06:59:23,290 - INFO - Initialized builder for step DummyDataLoading_training using StepCatalog
# 2025-11-28 06:59:23,291 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_training': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,292 - INFO - Using unified TABULAR_PREPROCESSING_SPEC for all job types
# 2025-11-28 06:59:23,292 - INFO - Initializing TabularPreprocessingStepBuilder with region: NA
# 2025-11-28 06:59:23,292 - INFO - Set execution prefix for TabularPreprocessing_training
# 2025-11-28 06:59:23,293 - INFO - Initialized builder for step TabularPreprocessing_training using StepCatalog
# 2025-11-28 06:59:23,293 - INFO - Using PyTorch training specification
# 2025-11-28 06:59:23,294 - INFO - Initializing PyTorchTrainingStepBuilder with region: NA
# 2025-11-28 06:59:23,294 - INFO - Validating PyTorchTrainingConfig...
# 2025-11-28 06:59:23,294 - INFO - Configuration validation relies on step specifications
# 2025-11-28 06:59:23,295 - INFO - PyTorchTrainingConfig validation succeeded.
# 2025-11-28 06:59:23,295 - INFO - Set execution prefix for PyTorchTraining
# 2025-11-28 06:59:23,295 - INFO - Initialized builder for step PyTorchTraining using StepCatalog
# 2025-11-28 06:59:23,296 - INFO - Successfully loaded builder class using base name 'DummyDataLoading' for 'DummyDataLoading_calibration': DummyDataLoadingStepBuilder
# 2025-11-28 06:59:23,296 - INFO - Using unified DUMMY_DATA_LOADING_SPEC for all job types
# 2025-11-28 06:59:23,296 - INFO - Initializing DummyDataLoadingStepBuilder with region: NA
# 2025-11-28 06:59:23,297 - INFO - Validating DummyDataLoadingConfig...
# 2025-11-28 06:59:23,297 - INFO - DummyDataLoadingConfig validation succeeded.
# 2025-11-28 06:59:23,299 - INFO - Set execution prefix for DummyDataLoading_calibration
# 2025-11-28 06:59:23,300 - INFO - Initialized builder for step DummyDataLoading_calibration using StepCatalog
# 2025-11-28 06:59:23,300 - INFO - Successfully loaded builder class using base name 'TabularPreprocessing' for 'TabularPreprocessing_calibration': TabularPreprocessingStepBuilder
# 2025-11-28 06:59:23,301 - INFO - Using unified TABULAR_PREPROCESSING_SPEC for all job types
# 2025-11-28 06:59:23,301 - INFO - Initializing TabularPreprocessingStepBuilder with region: NA
# 2025-11-28 06:59:23,302 - INFO - Set execution prefix for TabularPreprocessing_calibration
# 2025-11-28 06:59:23,302 - INFO - Initialized builder for step TabularPreprocessing_calibration using StepCatalog
# 2025-11-28 06:59:23,303 - INFO - Successfully loaded builder class using base name 'PyTorchModelEval' for 'PyTorchModelEval_calibration': PyTorchModelEvalStepBuilder
# 2025-11-28 06:59:23,303 - INFO - Initializing PyTorchModelEvalStepBuilder with region: NA
# 2025-11-28 06:59:23,303 - INFO - Validating PyTorchModelEvalConfig...
# 2025-11-28 06:59:23,304 - INFO - PyTorchModelEvalConfig validation succeeded.
# 2025-11-28 06:59:23,305 - INFO - Set execution prefix for PyTorchModelEval_calibration
# 2025-11-28 06:59:23,305 - INFO - Initialized builder for step PyTorchModelEval_calibration using StepCatalog
# 2025-11-28 06:59:23,306 - INFO - Successfully loaded builder class using base name 'ModelCalibration' for 'ModelCalibration_calibration': ModelCalibrationStepBuilder
# 2025-11-28 06:59:23,306 - INFO - Using unified MODEL_CALIBRATION_SPEC for all job types
# 2025-11-28 06:59:23,307 - INFO - Initializing ModelCalibrationStepBuilder with region: NA
# 2025-11-28 06:59:23,307 - INFO - Validating ModelCalibrationConfig...
# 2025-11-28 06:59:23,308 - INFO - ModelCalibrationConfig validation succeeded.
# 2025-11-28 06:59:23,308 - INFO - Set execution prefix for ModelCalibration_calibration
# 2025-11-28 06:59:23,309 - INFO - Initialized builder for step ModelCalibration_calibration using StepCatalog
# 2025-11-28 06:59:23,309 - INFO - Initializing PackageStepBuilder with region: NA
# 2025-11-28 06:59:23,309 - INFO - Validating PackageConfig...
# 2025-11-28 06:59:23,310 - INFO - PackageConfig validation succeeded.
# 2025-11-28 06:59:23,311 - INFO - Set execution prefix for Package
# 2025-11-28 06:59:23,311 - INFO - Initialized builder for step Package using StepCatalog
# 2025-11-28 06:59:23,312 - INFO - Initialized 8 step builders in 0.02 seconds
# 2025-11-28 06:59:23,312 - INFO - Generating pipeline: lukexie-BuyerAbuseRnR-pytorch-NA-0-0-1-pipeline
# 2025-11-28 06:59:23,312 - INFO - Initializing step connections using specifications
# 2025-11-28 06:59:23,314 - INFO - Matched TabularPreprocessing_training.DATA to DummyDataLoading_training.DATA (score: 1.00)
# 2025-11-28 06:59:23,315 - INFO - Matched TabularPreprocessing_training.SIGNATURE to DummyDataLoading_training.SIGNATURE (score: 1.00)
# 2025-11-28 06:59:23,316 - INFO - Matched PyTorchTraining.input_path to TabularPreprocessing_training.processed_data (score: 0.81)
# 2025-11-28 06:59:23,318 - INFO - Matched PyTorchTraining.model_artifacts_input to TabularPreprocessing_training.processed_data (score: 0.75)
# 2025-11-28 06:59:23,319 - INFO - Matched TabularPreprocessing_calibration.DATA to DummyDataLoading_calibration.DATA (score: 1.00)
# 2025-11-28 06:59:23,320 - INFO - Matched TabularPreprocessing_calibration.SIGNATURE to DummyDataLoading_calibration.SIGNATURE (score: 1.00)
# 2025-11-28 06:59:23,321 - INFO - Matched PyTorchModelEval_calibration.model_input to PyTorchTraining.model_output (score: 1.00)
# 2025-11-28 06:59:23,322 - INFO - Matched PyTorchModelEval_calibration.processed_data to PyTorchTraining.evaluation_output (score: 0.74)
# 2025-11-28 06:59:23,323 - INFO - Matched PyTorchModelEval_calibration.processed_data to TabularPreprocessing_calibration.processed_data (score: 1.00)
# 2025-11-28 06:59:23,324 - INFO - Build order: ['DummyDataLoading_training', 'DummyDataLoading_calibration', 'ModelCalibration_calibration', 'Package', 'TabularPreprocessing_training', 'TabularPreprocessing_calibration', 'PyTorchTraining', 'PyTorchModelEval_calibration']
# 2025-11-28 06:59:23,324 - INFO - Using execution_prefix for base output path
# 2025-11-28 06:59:23,324 - INFO - Creating Dummy Data Loading ProcessingStep...
# 2025-11-28 06:59:23,326 - INFO - Added configuration environment variables: {...}
# 2025-11-28 06:59:23,326 - INFO - Final dummy data loading environment variables: {...}
# 2025-11-28 06:59:23,328 - INFO - Defaulting to only available Python version: py3
# 2025-11-28 06:59:23,351 - INFO - Using user-provided data source from configuration: s3://buyer-seller-messaging-reversal/pipeline/lukexie-BuyerAbuseRnR-pytorch-NA/20251111035543/labelrulesetexecution/processed_data/ -> /opt/ml/processing/input/data
# 2025-11-28 06:59:23,351 - INFO - No command-line arguments needed for dummy data loading script
# 2025-11-28 06:59:23,352 - INFO - Using script path: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts/dummy_data_loading.py
# 2025-11-28 06:59:23,353 - INFO - Created ProcessingStep with name: DummyDataLoading-Training
# 2025-11-28 06:59:23,353 - INFO - Built step DummyDataLoading_training
# 2025-11-28 06:59:23,353 - INFO - Using execution_prefix for base output path
# 2025-11-28 06:59:23,354 - INFO - Creating Dummy Data Loading ProcessingStep...
# 2025-11-28 06:59:23,355 - INFO - Added configuration environment variables: {...}
# 2025-11-28 06:59:23,356 - INFO - Final dummy data loading environment variables: {...}
# 2025-11-28 06:59:23,357 - INFO - Defaulting to only available Python version: py3
# 2025-11-28 06:59:23,377 - INFO - Using user-provided data source from configuration: s3://buyer-seller-messaging-reversal/pipeline/lukexie-BuyerAbuseRnR-pytorch-NA/20251111035543/labelrulesetexecution/processed_data/test -> /opt/ml/processing/input/data
# 2025-11-28 06:59:23,377 - INFO - No command-line arguments needed for dummy data loading script
# 2025-11-28 06:59:23,378 - INFO - Using script path: /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/rnr_pytorch_bedrock/docker/scripts/dummy_data_loading.py
# 2025-11-28 06:59:23,378 - INFO - Created ProcessingStep with name: DummyDataLoading-Calibration
# 2025-11-28 06:59:23,379 - INFO - Built step DummyDataLoading_calibration
# 2025-11-28 06:59:23,379 - INFO - Using execution_prefix for base output path
# 2025-11-28 06:59:23,380 - INFO - Creating ModelCalibration ProcessingStep...
# 2025-11-28 06:59:23,381 - INFO - Defaulting to only available Python version: py3
# 2025-11-28 06:59:23,400 - ERROR - Error building step ModelCalibration_calibration: Required input 'evaluation_data' not provided
# 2025-11-28 06:59:23,401 - ERROR - Error instantiating step ModelCalibration_calibration: Failed to build step ModelCalibration_calibration: Required input 'evaluation_data' not provided
# 2025-11-28 06:59:23,401 - ERROR - Failed to compile DAG to pipeline: Failed to instantiate step ModelCalibration_calibration: Failed to build step ModelCalibration_calibration: Required input 'evaluation_data' not provided
# 2025-11-28 06:59:23,402 - ERROR - Failed to compile DAG with report: DAG compilation failed: Failed to instantiate step ModelCalibration_calibration: Failed to build step ModelCalibration_calibration: Required input 'evaluation_data' not provided
# 2025-11-28 06:59:23,402 - ERROR - Failed to convert DAG to pipeline: DAG compilation with report failed: DAG compilation failed: Failed to instantiate step ModelCalibration_calibration: Failed to build step ModelCalibration_calibration: Required input 'evaluation_data' not provided
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/core/assemb │
# │ ler/pipeline_assembler.py:435 in _instantiate_step                                               │
# │                                                                                                  │
# │   432 │   │   }                                                                                  │
# │   433 │   │                                                                                      │
# │   434 │   │   try:                                                                               │
# │ ❱ 435 │   │   │   step = builder.create_step(**kwargs)                                           │
# │   436 │   │   │   logger.info(f"Built step {step_name}")                                         │
# │   437 │   │   │                                                                                  │
# │   438 │   │   │   # Note: Cradle data loading request collection removed as part of Phase 2 cl   │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/steps/build │
# │ ers/builder_model_calibration_step.py:431 in create_step                                         │
# │                                                                                                  │
# │   428 │   │                                                                                      │
# │   429 │   │   # Create processor and get inputs/outputs                                          │
# │   430 │   │   processor = self._get_processor()                                                  │
# │ ❱ 431 │   │   proc_inputs = self._get_inputs(inputs)                                             │
# │   432 │   │   proc_outputs = self._get_outputs(outputs)                                          │
# │   433 │   │   job_args = self._get_job_arguments()                                               │
# │   434                                                                                            │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/steps/build │
# │ ers/builder_model_calibration_step.py:256 in _get_inputs                                         │
# │                                                                                                  │
# │   253 │   │   │                                                                                  │
# │   254 │   │   │   # Make sure required inputs are present                                        │
# │   255 │   │   │   if dependency_spec.required and logical_name not in inputs:                    │
# │ ❱ 256 │   │   │   │   raise ValueError(f"Required input '{logical_name}' not provided")          │
# │   257 │   │   │                                                                                  │
# │   258 │   │   │   # Get container path from contract                                             │
# │   259 │   │   │   container_path = None                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Required input 'evaluation_data' not provided
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/core/assemb │
# │ ler/pipeline_assembler.py:527 in generate_pipeline                                               │
# │                                                                                                  │
# │   524 │   │   # Instantiate steps in topological order                                           │
# │   525 │   │   for step_name in build_order:                                                      │
# │   526 │   │   │   try:                                                                           │
# │ ❱ 527 │   │   │   │   step = self._instantiate_step(step_name)                                   │
# │   528 │   │   │   │   self.step_instances[step_name] = step                                      │
# │   529 │   │   │   except Exception as e:                                                         │
# │   530 │   │   │   │   logger.error(f"Error instantiating step {step_name}: {e}")                 │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/core/assemb │
# │ ler/pipeline_assembler.py:445 in _instantiate_step                                               │
# │                                                                                                  │
# │   442 │   │   │   return step                                                                    │
# │   443 │   │   except Exception as e:                                                             │
# │   444 │   │   │   logger.error(f"Error building step {step_name}: {e}")                          │
# │ ❱ 445 │   │   │   raise ValueError(f"Failed to build step {step_name}: {e}") from e              │
# │   446 │                                                                                          │
# │   447 │   @classmethod                                                                           │
# │   448 │   def create_with_components(                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Failed to build step ModelCalibration_calibration: Required input 'evaluation_data' not provided
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/core/compil │
# │ er/dag_compiler.py:420 in compile                                                                │
# │                                                                                                  │
# │   417 │   │   │   from typing import cast                                                        │
# │   418 │   │   │   from sagemaker.workflow.pipeline import Pipeline as SageMakerPipeline          │
# │   419 │   │   │                                                                                  │
# │ ❱ 420 │   │   │   pipeline = cast(SageMakerPipeline, template.generate_pipeline())               │
# │   421 │   │   │                                                                                  │
# │   422 │   │   │   # Store the template after generate_pipeline() has updated its internal stat   │
# │   423 │   │   │   self._last_template = template                                                 │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/core/assemb │
# │ ler/pipeline_template_base.py:330 in generate_pipeline                                           │
# │                                                                                                  │
# │   327 │   │   )                                                                                  │
# │   328 │   │                                                                                      │
# │   329 │   │   # Generate the pipeline                                                            │
# │ ❱ 330 │   │   pipeline = template.generate_pipeline(pipeline_name)                               │
# │   331 │   │                                                                                      │
# │   332 │   │   # Store pipeline metadata                                                          │
# │   333 │   │   self._store_pipeline_metadata(template)                                            │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/core/assemb │
# │ ler/pipeline_assembler.py:531 in generate_pipeline                                               │
# │                                                                                                  │
# │   528 │   │   │   │   self.step_instances[step_name] = step                                      │
# │   529 │   │   │   except Exception as e:                                                         │
# │   530 │   │   │   │   logger.error(f"Error instantiating step {step_name}: {e}")                 │
# │ ❱ 531 │   │   │   │   raise ValueError(f"Failed to instantiate step {step_name}: {e}") from e    │
# │   532 │   │                                                                                      │
# │   533 │   │   # Create the pipeline                                                              │
# │   534 │   │   steps = [self.step_instances[name] for name in build_order]                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Failed to instantiate step ModelCalibration_calibration: Failed to build step
# ModelCalibration_calibration: Required input 'evaluation_data' not provided
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/core/compil │
# │ er/dag_compiler.py:469 in compile_with_report                                                    │
# │                                                                                                  │
# │   466 │   │   │   self.logger.info(f"Compiling DAG with detailed reporting")                     │
# │   467 │   │   │                                                                                  │
# │   468 │   │   │   # Compile pipeline                                                             │
# │ ❱ 469 │   │   │   pipeline = self.compile(dag, pipeline_name=pipeline_name, **kwargs)            │
# │   470 │   │   │                                                                                  │
# │   471 │   │   │   # Generate report                                                              │
# │   472 │   │   │   dag_nodes = list(dag.nodes)                                                    │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/core/compil │
# │ er/dag_compiler.py:449 in compile                                                                │
# │                                                                                                  │
# │   446 │   │                                                                                      │
# │   447 │   │   except Exception as e:                                                             │
# │   448 │   │   │   self.logger.error(f"Failed to compile DAG to pipeline: {e}")                   │
# │ ❱ 449 │   │   │   raise PipelineAPIError(f"DAG compilation failed: {e}") from e                  │
# │   450 │                                                                                          │
# │   451 │   def compile_with_report(                                                               │
# │   452 │   │   self, dag: PipelineDAG, pipeline_name: Optional[str] = None, **kwargs: Any         │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# PipelineAPIError: DAG compilation failed: Failed to instantiate step ModelCalibration_calibration: Failed to build
# step ModelCalibration_calibration: Required input 'evaluation_data' not provided
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 2>:4                                                                              │
# │                                                                                                  │
# │    1 # Convert DAG to pipeline and get report                                                    │
# │    2 try:                                                                                        │
# │    3 │   logger.info(f"Converting DAG to pipeline")                                              │
# │ ❱  4 │   template_pipeline, report = dag_compiler.compile_with_report(                           │
# │    5 │   │   dag=dag                                                                             │
# │    6 │   )                                                                                       │
# │    7                                                                                             │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/AmazonSageMaker-lukexie-sagemaker-bsm-repo/pipelines/cursus/core/compil │
# │ er/dag_compiler.py:532 in compile_with_report                                                    │
# │                                                                                                  │
# │   529 │   │                                                                                      │
# │   530 │   │   except Exception as e:                                                             │
# │   531 │   │   │   self.logger.error(f"Failed to compile DAG with report: {e}")                   │
# │ ❱ 532 │   │   │   raise PipelineAPIError(f"DAG compilation with report failed: {e}") from e      │
# │   533 │                                                                                          │
# │   534 │   def create_template(                                                                   │
# │   535 │   │   self, dag: PipelineDAG, **kwargs: Any                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# PipelineAPIError: DAG compilation with report failed: DAG compilation failed: Failed to instantiate step
# ModelCalibration_calibration: Failed to build step ModelCalibration_calibration: Required input 'evaluation_data'
# not provided

# %% [markdown]
# ### Pipeline Template
#
# After the pipeline is generated, we can retrieve the pipeline template

# %%
pipeline_template_builder = dag_compiler.get_last_template()

# %% [markdown]
# ## Start Execution

# %%
role_arn = pipeline_session.get_caller_identity_arn()
role_arn

# %%
pipeline_description=PIPELINE_DESCRIPTION

# %%
PIPELINE_DESCRIPTION

# %% [markdown]
# ### Upsert

# %%
template_pipeline.upsert(
                role_arn=role_arn, description=pipeline_description
            )

# %% [markdown]
# ### Start

# %%
pipeline_execution_parameters={
    "EXECUTION_S3_PREFIX": f"s3://{bucket_name}/pipeline/{PIPELINE_NAME}/{execution_id}",
    "KMS_ENCRYPTION_KEY_PARAM": kms_key_id,
    "VPC_SUBNET": vpc_subnet_id,
    "SECURITY_GROUP_ID": security_group_id,
}

# %%
pipeline_execution = template_pipeline.start(
                parameters=pipeline_execution_parameters
            )
